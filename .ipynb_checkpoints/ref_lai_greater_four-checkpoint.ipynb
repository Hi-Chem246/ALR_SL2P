# %%
# Import the necessary packages and libraries #
import scipy
import scipy.io as sio
import matplotlib.pyplot as plt
import numpy
import numpy.matlib
import pandas 
import sklearn
from sklearn import preprocessing
from sklearn import linear_model
import tensorflow
from tensorflow import keras 
import os
from sklearn.neighbors import DistanceMetric

# %%
# Sets the precision of the data in the Pandas Dataframes 

pandas.set_option("precision", 10)

# %%
# Removes any Tensorflow warnings 

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
# Import the MatLab data #

matlabData = sio.loadmat(file_name='./data/s2_sl2p_uniform_10_replicates_sobol_prosail_inout.mat', variable_names=['Input', 'Output'])

# %%
# Extract the input and output data 

bands = pandas.DataFrame(data=matlabData['Input']['Rho_Toc'][0][0])
angles = pandas.DataFrame(data=matlabData['Input']['Angles'][0][0])
LAI = pandas.Series(data=matlabData['Output']['LAI'][0][0].flatten())
FAPAR = pandas.Series(data=matlabData['Output']['FAPAR'][0][0].flatten())
FCOVER = pandas.Series(data=matlabData['Output']['FCOVER'][0][0].flatten())

# %%
# Standardize the calibration data 

cal_data = pandas.concat([bands, angles, LAI, FAPAR, FCOVER], axis=1, join='outer')

cal_data.columns = ['B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'A1', 'A2', 'A3', 'LAI', 'FAPAR', 'FCOVER']

cal_data
# Out:
#                   B0            B1            B2            B3            B4  \
# 0       0.1312746755  0.0743505601  0.1729546392  0.2952160738  0.3209243927
# 1       0.1019407701  0.0868185076  0.1599851769  0.3680334831  0.4389734403
# 2       0.0577228876  0.0543735427  0.0726863963  0.1146353863  0.1262129829
# 3       0.0608335819  0.0423475494  0.0917885392  0.1738484853  0.1980468499
# 4       0.0789422177  0.1359804109  0.1677317262  0.2554469658  0.2962514793
# ...              ...           ...           ...           ...           ...
# 122875  0.0642385315  0.0276301255  0.0866383370  0.3106952678  0.4255780128
# 122876  0.0913131658  0.0504649365  0.1222839075  0.3081750760  0.4047671458
# 122877  0.0621419307  0.0380236717  0.0921177459  0.2614424931  0.3577263614
# 122878  0.0514800307  0.0288523379  0.0690024543  0.4158467721  0.6343113015
# 122879  0.0668233773  0.0250243879  0.0907567987  0.4369922465  0.6772450624
#
#                   B5            B6            B7            A1            A2  \
# 0       0.3303722287  0.1873586099  0.1113007554  0.9638065534  0.5275411500
# 1       0.4759755142  0.3043390179  0.1996883219  0.9995852344  0.5284670738
# 2       0.1300015294  0.1048168652  0.0853760008  0.9807097061  0.6843199822
# 3       0.2153382831  0.1396374825  0.0906137034  0.9865515976  0.7869673865
# 4       0.3108466204  0.3167107908  0.2088934617  0.9999190888  0.8237423248
# ...              ...           ...           ...           ...           ...
# 122875  0.4466691326  0.1173674161  0.0414608341  0.9641458993  0.8501574022
# 122876  0.4293059492  0.1725548796  0.1005631041  0.9616583754  0.8710934328
# 122877  0.3626203975  0.1294881968  0.0624406803  0.9757927762  0.8637999983
# 122878  0.6354447032  0.1810943898  0.0474550174  0.9606931097  0.8268533675
# 122879  0.6972009957  0.2347272437  0.0863371443  0.9591264867  0.8382274319
#
#                   A3  LAI         FAPAR        FCOVER
# 0      -0.5752876765    1  0.4391203617  0.4803244610
# 1      -0.4777431279    1  0.5296906764  0.5338211214
# 2       0.6909005295    1  0.2406051357  0.2324486617
# 3       0.8590635747    1  0.3515168619  0.3732491055
# 4      -0.9085753290    1  0.2890892994  0.2565897729
# ...              ...  ...           ...           ...
# 122875 -0.9266152189   10  0.9454688738  0.9530549586
# 122876  0.9265827175   10  0.8085248415  0.8034524935
# 122877 -0.9813994186   10  0.8185069725  0.8122050332
# 122878 -0.8694016324   10  0.9810850825  0.9992241257
# 122879  0.9967558231   10  0.9762029807  0.9928982883
#
# [122880 rows x 14 columns]

# %%
# Standardize the calibration data 

cal_data_scaled = pandas.DataFrame(sklearn.preprocessing.StandardScaler().fit_transform(cal_data))

cal_data_scaled.columns = ['B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'A1', 'A2', 'A3', 'LAI', 'FAPAR', 'FCOVER']

cal_data_scaled
# Out:
#                   B0            B1            B2            B3            B4  \
# 0       1.1600887942  1.1894959571  1.1005309674 -0.7574953553 -1.2136760897
# 1       0.3768666595  1.6844505369  0.8279254564 -0.1275628723 -0.4502226101
# 2      -0.8037611472  0.3964451147 -1.0070101806 -2.3196717910 -2.4729247349
# 3      -0.7207048794 -0.0809646948 -0.6055016769 -1.8074281556 -2.0083566857
# 4      -0.2372000684  3.6360876602  0.9907504054 -1.1015319421 -1.3732421509
# ...              ...           ...           ...           ...           ...
# 122875 -0.6297919312 -0.6652193518 -0.7137539294 -0.6235871705 -0.5368542767
# 122876  0.0931071377  0.2412806393  0.0354813671 -0.6453889716 -0.6714434932
# 122877 -0.6857716627 -0.2526146846 -0.5985820716 -1.0496655348 -0.9756683152
# 122878 -0.9704468859 -0.6166997679 -1.0844430668  0.2860627172  0.8130774569
# 122879 -0.5607759421 -0.7686623410 -0.6271878617  0.4689890443  1.0907411044
#
#                   B5            B6            B7            A1            A2  \
# 0      -1.2551477212 -0.5123998591  0.0482701907 -1.5351947333 -1.2590753240
# 1      -0.3312429285  0.9573384489  1.5671047307  1.3154921199 -1.2529678973
# 2      -2.5265712936 -1.5494518415 -0.3972156885 -0.1884263875 -0.2249564670
# 3      -1.9850791466 -1.1119666599 -0.3072120391  0.2770296632  0.4521095310
# 4      -1.3790446724  1.1127770292  1.7252840412  1.3420921626  0.6946783564
# ...              ...           ...           ...           ...           ...
# 122875 -0.5172023756 -1.3917671005 -1.1518452670 -1.5081571622  0.8689131637
# 122876 -0.6273779690 -0.6983934776 -0.1362434958 -1.7063520463  1.0070079804
# 122877 -1.0505215854 -1.2394819780 -0.7913317214 -0.5801855863  0.9589002217
# 122878  0.6806459689 -0.5911033299 -1.0488424022 -1.7832601421  0.7151989067
# 122879  1.0725116772  0.0827382237 -0.3806995885 -1.9080817293  0.7902226473
#
#                   A3           LAI         FAPAR        FCOVER
# 0      -0.7795178075 -1.5666989036 -1.8949148320 -1.6291084301
# 1      -0.6517039023 -1.5666989036 -1.4265332698 -1.3709908078
# 2       0.8795852552 -1.5666989036 -2.9215301414 -2.8250917213
# 3       1.0999315055 -1.5666989036 -2.3479536034 -2.1457394865
# 4      -1.2162290029 -1.5666989036 -2.6707957989 -2.7086125584
# ...              ...           ...           ...           ...
# 122875 -1.2398669079  1.5666989036  0.7236507314  0.6517829598
# 122876  1.1884027264  1.5666989036  0.0154489326 -0.0700384081
# 122877 -1.3116513655  1.5666989036  0.0670712121 -0.0278080201
# 122878 -1.1648991929  1.5666989036  0.9078388454  0.8745459430
# 122879  1.2803514698  1.5666989036  0.8825912079  0.8440242224
#
# [122880 rows x 14 columns]

# %%
# Create subset id's 

rep = 10

subsets = numpy.arange(0, int(cal_data_scaled.shape[0]/10))

subset_ids = numpy.matlib.repmat(subsets, 1, rep)

cal_data_scaled['subset_id'] = subset_ids[0]

cal_data_scaled.columns = ['B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'A1', 'A2', 'A3', 'LAI', 'FAPAR', 'FCOVER', 'subset_id']

cal_data_scaled
# Out:
#                   B0            B1            B2            B3            B4  \
# 0       1.1600887942  1.1894959571  1.1005309674 -0.7574953553 -1.2136760897
# 1       0.3768666595  1.6844505369  0.8279254564 -0.1275628723 -0.4502226101
# 2      -0.8037611472  0.3964451147 -1.0070101806 -2.3196717910 -2.4729247349
# 3      -0.7207048794 -0.0809646948 -0.6055016769 -1.8074281556 -2.0083566857
# 4      -0.2372000684  3.6360876602  0.9907504054 -1.1015319421 -1.3732421509
# ...              ...           ...           ...           ...           ...
# 122875 -0.6297919312 -0.6652193518 -0.7137539294 -0.6235871705 -0.5368542767
# 122876  0.0931071377  0.2412806393  0.0354813671 -0.6453889716 -0.6714434932
# 122877 -0.6857716627 -0.2526146846 -0.5985820716 -1.0496655348 -0.9756683152
# 122878 -0.9704468859 -0.6166997679 -1.0844430668  0.2860627172  0.8130774569
# 122879 -0.5607759421 -0.7686623410 -0.6271878617  0.4689890443  1.0907411044
#
#                   B5            B6            B7            A1            A2  \
# 0      -1.2551477212 -0.5123998591  0.0482701907 -1.5351947333 -1.2590753240
# 1      -0.3312429285  0.9573384489  1.5671047307  1.3154921199 -1.2529678973
# 2      -2.5265712936 -1.5494518415 -0.3972156885 -0.1884263875 -0.2249564670
# 3      -1.9850791466 -1.1119666599 -0.3072120391  0.2770296632  0.4521095310
# 4      -1.3790446724  1.1127770292  1.7252840412  1.3420921626  0.6946783564
# ...              ...           ...           ...           ...           ...
# 122875 -0.5172023756 -1.3917671005 -1.1518452670 -1.5081571622  0.8689131637
# 122876 -0.6273779690 -0.6983934776 -0.1362434958 -1.7063520463  1.0070079804
# 122877 -1.0505215854 -1.2394819780 -0.7913317214 -0.5801855863  0.9589002217
# 122878  0.6806459689 -0.5911033299 -1.0488424022 -1.7832601421  0.7151989067
# 122879  1.0725116772  0.0827382237 -0.3806995885 -1.9080817293  0.7902226473
#
#                   A3           LAI         FAPAR        FCOVER  subset_id
# 0      -0.7795178075 -1.5666989036 -1.8949148320 -1.6291084301          0
# 1      -0.6517039023 -1.5666989036 -1.4265332698 -1.3709908078          1
# 2       0.8795852552 -1.5666989036 -2.9215301414 -2.8250917213          2
# 3       1.0999315055 -1.5666989036 -2.3479536034 -2.1457394865          3
# 4      -1.2162290029 -1.5666989036 -2.6707957989 -2.7086125584          4
# ...              ...           ...           ...           ...        ...
# 122875 -1.2398669079  1.5666989036  0.7236507314  0.6517829598      12283
# 122876  1.1884027264  1.5666989036  0.0154489326 -0.0700384081      12284
# 122877 -1.3116513655  1.5666989036  0.0670712121 -0.0278080201      12285
# 122878 -1.1648991929  1.5666989036  0.9078388454  0.8745459430      12286
# 122879  1.2803514698  1.5666989036  0.8825912079  0.8440242224      12287
#
# [122880 rows x 15 columns]

# %%
# Sample data to create reference database 
# Select samples that have an LAI greater than or equal to four 

ref_data = cal_data_scaled[cal_data['LAI'] >= 4].sample(n=100, ignore_index=False)

ref_data
# Out:
#                   B0            B1            B2            B3            B4  \
# 118669 -0.1601481952 -0.4761421031 -0.1287799537  0.7113098984  0.7463378283
# 103399 -1.0055117573 -0.6449015632 -1.0979156053  0.0737253320  0.5995740739
# 48439  -0.1511312544 -0.3953444703 -0.2406610557 -0.8110643354 -1.0642099461
# 89310   0.4874656321 -0.4513849357  0.4391468371  0.2914913772  0.2911943328
# 47432  -0.7495481687 -0.3086157340 -0.7474673054  0.2088268733  0.5412834461
# ...              ...           ...           ...           ...           ...
# 113993  0.0348968756 -0.6323488282  0.0376850556  0.6676966060  0.6737150188
# 69669   2.2954943444 -0.0258242077  2.0007626991  2.0176879723  1.5760185902
# 89219   0.3377311585 -0.4674750132  0.3698692670  0.5512173574  0.3102783228
# 57912   1.1553155662 -0.2425441636  1.1089833352  1.2097407921  0.9548216213
# 113850 -0.0196597763 -0.6567243157 -0.0003021648  0.9141398730  1.2643668956
#
#                   B5            B6            B7            A1            A2  \
# 118669  0.8016189273 -0.2848782987 -0.8546058074 -0.8672450160 -2.2079625616
# 103399  0.6275040991 -0.8385451053 -1.1372884450 -0.3765471231  1.0106191250
# 48439  -1.1527538512 -1.1127796177 -0.6738471876  0.6212226985 -1.2675152706
# 89310   0.4561430657  0.7304510260  0.5460184430  0.3060409420  0.4831269226
# 47432   0.5316058461  1.1998008164  0.6985995113  0.6123996958  0.6977944894
# ...              ...           ...           ...           ...           ...
# 113993  0.7257060045  0.1541850599 -0.4734670817  0.9099604599  1.1780094963
# 69669   1.4095264701  1.0703851933  0.4406072134  0.5365215398  0.9739655659
# 89219   0.3341659359 -1.2451340290 -1.3257914808 -0.4630940284 -2.2035679349
# 57912   0.9791312362  0.5797369289  0.0106037291 -0.6276470848  0.8050961596
# 113850  1.4877844227  1.0642195493  0.4117250052 -0.2320680892  0.9329671549
#
#                   A3           LAI         FAPAR        FCOVER  subset_id
# 118669 -0.5966619446  1.5666989036  0.8300694231  0.8287052154       8077
# 103399  1.0843893516  1.2185435917  0.8949434037  0.8542352358       5095
# 48439  -0.7588860171 -0.5222329679 -0.5535126590 -0.4955362231      11575
# 89310  -1.0451714340  0.8703882798  0.5580405281  0.5664057772       3294
# 47432  -1.1662324837 -0.5222329679  0.4828978532  0.4482681115      10568
# ...              ...           ...           ...           ...        ...
# 113993 -1.2346633944  1.5666989036  0.8554015856  0.8604151718       3401
# 69669  -1.3346357270  0.1740776560  0.6239921825  0.7400751353       8229
# 89219   0.7172778678  0.8703882798  0.7872296583  0.8166234258       3203
# 57912  -1.1092770518 -0.1740776560  0.5961492608  0.6492563654       8760
# 113850  1.0977380948  1.5666989036  0.8576957341  0.8500157259       3258
#
# [100 rows x 15 columns]

# %%
# List of indices to remove from the calibration database 

index_list = ref_data.index.values

# %%
# Resets the indices in the reference data so that they start from zero

ref_data = ref_data.reset_index(drop=True)

# %%
# Removes the indices from calibration database that are in the reference database 

cal_data_scaled = cal_data_scaled.drop(index_list)

# %%
# Resets the indices in the calibration data so that they start from zero

cal_data_scaled = cal_data_scaled.reset_index(drop=True)

# %%
# Creates the training and validation sets from the calibration data

features_training, features_valid = sklearn.model_selection.train_test_split(cal_data_scaled, test_size=0.3, train_size=0.7, random_state=None, shuffle=True, stratify=None)

# %%
# Resets the indices in the training data so that they start from zero

features_training = features_training.reset_index(drop=True)

# %%
# Resets the indices in the validation data so that they start from zero

features_valid = features_valid.reset_index(drop=True)

# %%
# Extracts the LAI, FAPAR, and FCOVER data to be used for training

LAI_feature_training = features_training['LAI']
FAPAR_feature_training = features_training['FAPAR']
FCOVER_feature_training = features_training['FCOVER']

# %%
# Extracts the LAI, FAPAR, and FCOVER data to be used for validation

LAI_feature_valid = features_valid['LAI']
FAPAR_feature_valid = features_valid['FAPAR']
FCOVER_feature_valid = features_valid['FCOVER']

# %%
# Removes that isn't needed for training and validation 
features_training = features_training.drop(['LAI', 'FAPAR', 'FCOVER','subset_id'], axis=1)
features_valid = features_valid.drop(['LAI', 'FAPAR', 'FCOVER','subset_id'], axis=1)

# %%
# Creates a model for LAI, FAPAR, and FCOVER using LARs regression 

LAI_feature_model = sklearn.linear_model.Lars(n_nonzero_coefs=4)
LAI_feature_model = LAI_feature_model.fit(features_training, LAI_feature_training)

FAPAR_feature_model = sklearn.linear_model.Lars(n_nonzero_coefs=4)
FAPAR_feature_model = FAPAR_feature_model.fit(features_training, FAPAR_feature_training)

FCOVER_feature_model = sklearn.linear_model.Lars(n_nonzero_coefs=4)
FCOVER_feature_model = FCOVER_feature_model.fit(features_training, FCOVER_feature_training)

# %%
# Makes predictions on the validation data using the LARS models

LAI_feature_predicted = pandas.Series(LAI_feature_model.predict(features_valid))
FAPAR_feature_predicted = pandas.Series(FAPAR_feature_model.predict(features_valid))
FCOVER_feature_predicted = pandas.Series(FCOVER_feature_model.predict(features_valid))

# %%
# Extracts the features from the LARS Model

LAI_features = numpy.nonzero(LAI_feature_model.coef_)[0]
FAPAR_features = numpy.nonzero(FAPAR_feature_model.coef_)[0]
FCOVER_features = numpy.nonzero(FCOVER_feature_model.coef_)[0]

LAI_features = features_valid.columns[LAI_features]
FAPAR_features = features_valid.columns[FAPAR_features]
FCOVER_features = features_valid.columns[FCOVER_features]

# %%
# Creates arrays containing the calibration and reference data 

ref_array = numpy.array(ref_data[LAI_features])

cal_array = numpy.array(cal_data_scaled[LAI_features])

# %%
# Calls function from sci-kit learn for calculating the euclidean distance 

dist = DistanceMetric.get_metric('euclidean')

# %%
# Calculates the probability for each sample in the calibration data

probs = numpy.exp(-numpy.amin(dist.pairwise(cal_array,ref_array),1))

# %%
# Initialize the probability column in the calibration database 

cal_data_scaled['prob'] = probs 

cal_data_scaled.columns = ['B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'A1', 'A2', 'A3', 'LAI', 'FAPAR', 'FCOVER', 'subset_id', 'prob']

# %%
# Function to normalize the probabilities 

def normalize(data):
    norm_prob = numpy.array(data['prob'])/sum(data['prob'])
    data['prob'] = norm_prob 
    return data

# %%
normalize(cal_data_scaled)
# Out:
#                   B0            B1            B2            B3            B4  \
# 0       1.1600887942  1.1894959571  1.1005309674 -0.7574953553 -1.2136760897
# 1       0.3768666595  1.6844505369  0.8279254564 -0.1275628723 -0.4502226101
# 2      -0.8037611472  0.3964451147 -1.0070101806 -2.3196717910 -2.4729247349
# 3      -0.7207048794 -0.0809646948 -0.6055016769 -1.8074281556 -2.0083566857
# 4      -0.2372000684  3.6360876602  0.9907504054 -1.1015319421 -1.3732421509
# ...              ...           ...           ...           ...           ...
# 122775 -0.6297919312 -0.6652193518 -0.7137539294 -0.6235871705 -0.5368542767
# 122776  0.0931071377  0.2412806393  0.0354813671 -0.6453889716 -0.6714434932
# 122777 -0.6857716627 -0.2526146846 -0.5985820716 -1.0496655348 -0.9756683152
# 122778 -0.9704468859 -0.6166997679 -1.0844430668  0.2860627172  0.8130774569
# 122779 -0.5607759421 -0.7686623410 -0.6271878617  0.4689890443  1.0907411044
#
#                   B5            B6            B7            A1            A2  \
# 0      -1.2551477212 -0.5123998591  0.0482701907 -1.5351947333 -1.2590753240
# 1      -0.3312429285  0.9573384489  1.5671047307  1.3154921199 -1.2529678973
# 2      -2.5265712936 -1.5494518415 -0.3972156885 -0.1884263875 -0.2249564670
# 3      -1.9850791466 -1.1119666599 -0.3072120391  0.2770296632  0.4521095310
# 4      -1.3790446724  1.1127770292  1.7252840412  1.3420921626  0.6946783564
# ...              ...           ...           ...           ...           ...
# 122775 -0.5172023756 -1.3917671005 -1.1518452670 -1.5081571622  0.8689131637
# 122776 -0.6273779690 -0.6983934776 -0.1362434958 -1.7063520463  1.0070079804
# 122777 -1.0505215854 -1.2394819780 -0.7913317214 -0.5801855863  0.9589002217
# 122778  0.6806459689 -0.5911033299 -1.0488424022 -1.7832601421  0.7151989067
# 122779  1.0725116772  0.0827382237 -0.3806995885 -1.9080817293  0.7902226473
#
#                   A3           LAI         FAPAR        FCOVER  subset_id  \
# 0      -0.7795178075 -1.5666989036 -1.8949148320 -1.6291084301          0
# 1      -0.6517039023 -1.5666989036 -1.4265332698 -1.3709908078          1
# 2       0.8795852552 -1.5666989036 -2.9215301414 -2.8250917213          2
# 3       1.0999315055 -1.5666989036 -2.3479536034 -2.1457394865          3
# 4      -1.2162290029 -1.5666989036 -2.6707957989 -2.7086125584          4
# ...              ...           ...           ...           ...        ...
# 122775 -1.2398669079  1.5666989036  0.7236507314  0.6517829598      12283
# 122776  1.1884027264  1.5666989036  0.0154489326 -0.0700384081      12284
# 122777 -1.3116513655  1.5666989036  0.0670712121 -0.0278080201      12285
# 122778 -1.1648991929  1.5666989036  0.9078388454  0.8745459430      12286
# 122779  1.2803514698  1.5666989036  0.8825912079  0.8440242224      12287
#
#                 prob
# 0       0.0000039705
# 1       0.0000013683
# 2       0.0000052268
# 3       0.0000097118
# 4       0.0000002383
# ...              ...
# 122775  0.0000108585
# 122776  0.0000088211
# 122777  0.0000102390
# 122778  0.0000113167
# 122779  0.0000097659
#
# [122780 rows x 16 columns]

# %%
# Initialize the probability column in the calibration database 

cal_data_scaled.columns = ['B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'A1', 'A2', 'A3', 'LAI', 'FAPAR', 'FCOVER', 'subset_id', 'prob']

# %%
# Assign max probability in each subset to every member of that subset 

cal_data_scaled['prob'] = cal_data_scaled.groupby('subset_id')['prob'].transform('max')

# %%
normalize(cal_data_scaled)
# Out:
#                   B0            B1            B2            B3            B4  \
# 0       1.1600887942  1.1894959571  1.1005309674 -0.7574953553 -1.2136760897
# 1       0.3768666595  1.6844505369  0.8279254564 -0.1275628723 -0.4502226101
# 2      -0.8037611472  0.3964451147 -1.0070101806 -2.3196717910 -2.4729247349
# 3      -0.7207048794 -0.0809646948 -0.6055016769 -1.8074281556 -2.0083566857
# 4      -0.2372000684  3.6360876602  0.9907504054 -1.1015319421 -1.3732421509
# ...              ...           ...           ...           ...           ...
# 122775 -0.6297919312 -0.6652193518 -0.7137539294 -0.6235871705 -0.5368542767
# 122776  0.0931071377  0.2412806393  0.0354813671 -0.6453889716 -0.6714434932
# 122777 -0.6857716627 -0.2526146846 -0.5985820716 -1.0496655348 -0.9756683152
# 122778 -0.9704468859 -0.6166997679 -1.0844430668  0.2860627172  0.8130774569
# 122779 -0.5607759421 -0.7686623410 -0.6271878617  0.4689890443  1.0907411044
#
#                   B5            B6            B7            A1            A2  \
# 0      -1.2551477212 -0.5123998591  0.0482701907 -1.5351947333 -1.2590753240
# 1      -0.3312429285  0.9573384489  1.5671047307  1.3154921199 -1.2529678973
# 2      -2.5265712936 -1.5494518415 -0.3972156885 -0.1884263875 -0.2249564670
# 3      -1.9850791466 -1.1119666599 -0.3072120391  0.2770296632  0.4521095310
# 4      -1.3790446724  1.1127770292  1.7252840412  1.3420921626  0.6946783564
# ...              ...           ...           ...           ...           ...
# 122775 -0.5172023756 -1.3917671005 -1.1518452670 -1.5081571622  0.8689131637
# 122776 -0.6273779690 -0.6983934776 -0.1362434958 -1.7063520463  1.0070079804
# 122777 -1.0505215854 -1.2394819780 -0.7913317214 -0.5801855863  0.9589002217
# 122778  0.6806459689 -0.5911033299 -1.0488424022 -1.7832601421  0.7151989067
# 122779  1.0725116772  0.0827382237 -0.3806995885 -1.9080817293  0.7902226473
#
#                   A3           LAI         FAPAR        FCOVER  subset_id  \
# 0      -0.7795178075 -1.5666989036 -1.8949148320 -1.6291084301          0
# 1      -0.6517039023 -1.5666989036 -1.4265332698 -1.3709908078          1
# 2       0.8795852552 -1.5666989036 -2.9215301414 -2.8250917213          2
# 3       1.0999315055 -1.5666989036 -2.3479536034 -2.1457394865          3
# 4      -1.2162290029 -1.5666989036 -2.6707957989 -2.7086125584          4
# ...              ...           ...           ...           ...        ...
# 122775 -1.2398669079  1.5666989036  0.7236507314  0.6517829598      12283
# 122776  1.1884027264  1.5666989036  0.0154489326 -0.0700384081      12284
# 122777 -1.3116513655  1.5666989036  0.0670712121 -0.0278080201      12285
# 122778 -1.1648991929  1.5666989036  0.9078388454  0.8745459430      12286
# 122779  1.2803514698  1.5666989036  0.8825912079  0.8440242224      12287
#
#                 prob
# 0       0.0000056506
# 1       0.0000073596
# 2       0.0000069431
# 3       0.0000093162
# 4       0.0000081086
# ...              ...
# 122775  0.0000082954
# 122776  0.0000067389
# 122777  0.0000078221
# 122778  0.0000086880
# 122779  0.0000082502
#
# [122780 rows x 16 columns]

# %%
# Find median probability 

median_prob = numpy.median(cal_data_scaled['prob'])

print(median_prob)
# Out:
# 8.333197879493806e-06

# %%
# Set weight that are below the median to zero 

cal_data_scaled['prob'] = cal_data_scaled['prob'].where(cal_data_scaled['prob'] > median_prob, 0.0)

# %%
cal_data_scaled
# Out:
#                   B0            B1            B2            B3            B4  \
# 0       1.1600887942  1.1894959571  1.1005309674 -0.7574953553 -1.2136760897
# 1       0.3768666595  1.6844505369  0.8279254564 -0.1275628723 -0.4502226101
# 2      -0.8037611472  0.3964451147 -1.0070101806 -2.3196717910 -2.4729247349
# 3      -0.7207048794 -0.0809646948 -0.6055016769 -1.8074281556 -2.0083566857
# 4      -0.2372000684  3.6360876602  0.9907504054 -1.1015319421 -1.3732421509
# ...              ...           ...           ...           ...           ...
# 122775 -0.6297919312 -0.6652193518 -0.7137539294 -0.6235871705 -0.5368542767
# 122776  0.0931071377  0.2412806393  0.0354813671 -0.6453889716 -0.6714434932
# 122777 -0.6857716627 -0.2526146846 -0.5985820716 -1.0496655348 -0.9756683152
# 122778 -0.9704468859 -0.6166997679 -1.0844430668  0.2860627172  0.8130774569
# 122779 -0.5607759421 -0.7686623410 -0.6271878617  0.4689890443  1.0907411044
#
#                   B5            B6            B7            A1            A2  \
# 0      -1.2551477212 -0.5123998591  0.0482701907 -1.5351947333 -1.2590753240
# 1      -0.3312429285  0.9573384489  1.5671047307  1.3154921199 -1.2529678973
# 2      -2.5265712936 -1.5494518415 -0.3972156885 -0.1884263875 -0.2249564670
# 3      -1.9850791466 -1.1119666599 -0.3072120391  0.2770296632  0.4521095310
# 4      -1.3790446724  1.1127770292  1.7252840412  1.3420921626  0.6946783564
# ...              ...           ...           ...           ...           ...
# 122775 -0.5172023756 -1.3917671005 -1.1518452670 -1.5081571622  0.8689131637
# 122776 -0.6273779690 -0.6983934776 -0.1362434958 -1.7063520463  1.0070079804
# 122777 -1.0505215854 -1.2394819780 -0.7913317214 -0.5801855863  0.9589002217
# 122778  0.6806459689 -0.5911033299 -1.0488424022 -1.7832601421  0.7151989067
# 122779  1.0725116772  0.0827382237 -0.3806995885 -1.9080817293  0.7902226473
#
#                   A3           LAI         FAPAR        FCOVER  subset_id  \
# 0      -0.7795178075 -1.5666989036 -1.8949148320 -1.6291084301          0
# 1      -0.6517039023 -1.5666989036 -1.4265332698 -1.3709908078          1
# 2       0.8795852552 -1.5666989036 -2.9215301414 -2.8250917213          2
# 3       1.0999315055 -1.5666989036 -2.3479536034 -2.1457394865          3
# 4      -1.2162290029 -1.5666989036 -2.6707957989 -2.7086125584          4
# ...              ...           ...           ...           ...        ...
# 122775 -1.2398669079  1.5666989036  0.7236507314  0.6517829598      12283
# 122776  1.1884027264  1.5666989036  0.0154489326 -0.0700384081      12284
# 122777 -1.3116513655  1.5666989036  0.0670712121 -0.0278080201      12285
# 122778 -1.1648991929  1.5666989036  0.9078388454  0.8745459430      12286
# 122779  1.2803514698  1.5666989036  0.8825912079  0.8440242224      12287
#
#                 prob
# 0       0.0000000000
# 1       0.0000000000
# 2       0.0000000000
# 3       0.0000093162
# 4       0.0000000000
# ...              ...
# 122775  0.0000000000
# 122776  0.0000000000
# 122777  0.0000000000
# 122778  0.0000086880
# 122779  0.0000000000
#
# [122780 rows x 16 columns]

# %%
# Creates the training and validation sets from the calibration data

training_data, valid_data = sklearn.model_selection.train_test_split(cal_data_scaled, test_size=0.3, train_size=0.7, random_state=None, shuffle=True, stratify=None)

# %%
# Resets the indices in the training data so that they start from zero

training_data = training_data.reset_index(drop=True)

# %%
# Resets the indices in the validation data so that they start from zero

valid_data = valid_data.reset_index(drop=True)

# %%
# Extracts the LAI, FAPAR, and FCOVER data to be used for training

LAI_training = training_data['LAI']
FAPAR_training = training_data['FAPAR']
FCOVER_training = training_data['FCOVER']

# %%
# Extracts the LAI, FAPAR, and FCOVER data to be used for validation

LAI_valid = valid_data['LAI']
FAPAR_valid = valid_data['FAPAR']
FCOVER_valid = valid_data['FCOVER']

# %%
# Extracts the probabilites for training and validation 

training_weights = numpy.array(training_data['prob'])
valid_weights = numpy.array(valid_data['prob'])

# %%
# Removes that isn't needed for training and validation 
# Explicitly subset the inputs
training_data = training_data.drop(['LAI', 'FAPAR', 'FCOVER','subset_id','prob'], axis=1)
valid_data = valid_data.drop(['LAI', 'FAPAR', 'FCOVER','subset_id','prob'], axis=1)

# %%
LAI_callback = tensorflow.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
FAPAR_callback = tensorflow.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
FCOVER_callback = tensorflow.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

# %%
# Creation of the Neural Network models for LAI, FAPAR, and FCOVER 

LAI_model = tensorflow.keras.models.Sequential([
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu, 
                                  input_shape=[len(training_data.keys())]),
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu),
    tensorflow.keras.layers.Dense(1)
])

LAI_model.compile(
    optimizer=tensorflow.keras.optimizers.Nadam(),
    loss='mse',
    metrics=['mse', 'mae'])

FAPAR_model = tensorflow.keras.models.Sequential([
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu, 
                                  input_shape=[len(training_data.keys())]),
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu),
    tensorflow.keras.layers.Dense(1)
])

FAPAR_model.compile(
    optimizer=tensorflow.keras.optimizers.Nadam(),
    loss='mse',
    metrics=['mse', 'mae'])

FCOVER_model = tensorflow.keras.models.Sequential([
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu, 
                                  input_shape=[len(training_data.keys())]),
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu),
    tensorflow.keras.layers.Dense(1)
])

FCOVER_model.compile(
    optimizer=tensorflow.keras.optimizers.Nadam(),
    loss='mse',
    metrics=['mse', 'mae'])

# %%
# Runs NN Model for LAI

LAI_history = LAI_model.fit(x = numpy.array(training_data), y = numpy.array(LAI_training), 
                            sample_weight = training_weights,
                            epochs = 120,
                            validation_data = (numpy.array(valid_data), numpy.array(LAI_valid), valid_weights),
                            callbacks=[LAI_callback]
                           )
# Out:
# Train on 85946 samples, validate on 36834 samples
# Epoch 1/120
# 85946/85946 [==============================] - 16s 184us/sample - loss: 1.4968e-06 - mse: 0.3954 - mae: 0.4966 - val_loss: 9.0152e-07 - val_mse: 0.2506 - val_mae: 0.3888
# Epoch 2/120
# 85946/85946 [==============================] - 12s 143us/sample - loss: 7.9846e-07 - mse: 0.2104 - mae: 0.3573 - val_loss: 7.2513e-07 - val_mse: 0.1871 - val_mae: 0.3345
# Epoch 3/120
# 85946/85946 [==============================] - 11s 127us/sample - loss: 6.6411e-07 - mse: 0.1697 - mae: 0.3196 - val_loss: 6.3391e-07 - val_mse: 0.1596 - val_mae: 0.3087
# Epoch 4/120
# 85946/85946 [==============================] - 11s 127us/sample - loss: 5.9078e-07 - mse: 0.1504 - mae: 0.2985 - val_loss: 5.6913e-07 - val_mse: 0.1437 - val_mae: 0.2908
# Epoch 5/120
# 85946/85946 [==============================] - 11s 126us/sample - loss: 5.3999e-07 - mse: 0.1379 - mae: 0.2840 - val_loss: 5.2353e-07 - val_mse: 0.1343 - val_mae: 0.2789
# Epoch 6/120
# 85946/85946 [==============================] - 11s 127us/sample - loss: 5.0047e-07 - mse: 0.1300 - mae: 0.2745 - val_loss: 4.9910e-07 - val_mse: 0.1285 - val_mae: 0.2734
# Epoch 7/120
# 85946/85946 [==============================] - 11s 126us/sample - loss: 4.7167e-07 - mse: 0.1240 - mae: 0.2678 - val_loss: 4.7726e-07 - val_mse: 0.1233 - val_mae: 0.2649
# Epoch 8/120
# 85946/85946 [==============================] - 11s 126us/sample - loss: 4.5001e-07 - mse: 0.1197 - mae: 0.2623 - val_loss: 4.4880e-07 - val_mse: 0.1165 - val_mae: 0.2575
# Epoch 9/120
# 85946/85946 [==============================] - 11s 128us/sample - loss: 4.3407e-07 - mse: 0.1161 - mae: 0.2584 - val_loss: 4.3498e-07 - val_mse: 0.1112 - val_mae: 0.2548
# Epoch 10/120
# 85946/85946 [==============================] - 11s 127us/sample - loss: 4.2013e-07 - mse: 0.1151 - mae: 0.2563 - val_loss: 4.1595e-07 - val_mse: 0.1127 - val_mae: 0.2536
# Epoch 11/120
# 85946/85946 [==============================] - 11s 129us/sample - loss: 4.1033e-07 - mse: 0.1117 - mae: 0.2527 - val_loss: 4.2562e-07 - val_mse: 0.1139 - val_mae: 0.2527
# Epoch 12/120
# 85946/85946 [==============================] - 11s 128us/sample - loss: 4.0478e-07 - mse: 0.1107 - mae: 0.2512 - val_loss: 4.1307e-07 - val_mse: 0.1156 - val_mae: 0.2531
# Epoch 13/120
# 85946/85946 [==============================] - 11s 127us/sample - loss: 3.9729e-07 - mse: 0.1088 - mae: 0.2489 - val_loss: 4.2027e-07 - val_mse: 0.1169 - val_mae: 0.2551
# Epoch 14/120
# 85946/85946 [==============================] - 11s 128us/sample - loss: 3.9337e-07 - mse: 0.1075 - mae: 0.2473 - val_loss: 4.0413e-07 - val_mse: 0.1116 - val_mae: 0.2513
# Epoch 15/120
# 85946/85946 [==============================] - 11s 127us/sample - loss: 3.8716e-07 - mse: 0.1052 - mae: 0.2451 - val_loss: 3.7403e-07 - val_mse: 0.0998 - val_mae: 0.2392
# Epoch 16/120
# 85946/85946 [==============================] - 11s 127us/sample - loss: 3.8281e-07 - mse: 0.1036 - mae: 0.2434 - val_loss: 3.8540e-07 - val_mse: 0.0966 - val_mae: 0.2392
# Epoch 17/120
# 85946/85946 [==============================] - 11s 126us/sample - loss: 3.7918e-07 - mse: 0.1017 - mae: 0.2415 - val_loss: 3.6894e-07 - val_mse: 0.0960 - val_mae: 0.2365
# Epoch 18/120
# 85946/85946 [==============================] - 11s 130us/sample - loss: 3.7582e-07 - mse: 0.1006 - mae: 0.2405 - val_loss: 3.7005e-07 - val_mse: 0.1014 - val_mae: 0.2398
# Epoch 19/120
# 85946/85946 [==============================] - 11s 128us/sample - loss: 3.7205e-07 - mse: 0.0999 - mae: 0.2397 - val_loss: 3.6498e-07 - val_mse: 0.0970 - val_mae: 0.2357
# Epoch 20/120
# 85946/85946 [==============================] - 11s 127us/sample - loss: 3.6834e-07 - mse: 0.0985 - mae: 0.2383 - val_loss: 3.8271e-07 - val_mse: 0.1034 - val_mae: 0.2428
# Epoch 21/120
# 85946/85946 [==============================] - 13s 149us/sample - loss: 3.6702e-07 - mse: 0.0978 - mae: 0.2373 - val_loss: 3.6008e-07 - val_mse: 0.0930 - val_mae: 0.2331
# Epoch 22/120
# 85946/85946 [==============================] - 15s 177us/sample - loss: 3.6447e-07 - mse: 0.0973 - mae: 0.2369 - val_loss: 3.5361e-07 - val_mse: 0.0930 - val_mae: 0.2331
# Epoch 23/120
# 85946/85946 [==============================] - 10s 117us/sample - loss: 3.6138e-07 - mse: 0.0964 - mae: 0.2355 - val_loss: 3.7100e-07 - val_mse: 0.0987 - val_mae: 0.2403
# Epoch 24/120
# 85946/85946 [==============================] - 10s 121us/sample - loss: 3.5885e-07 - mse: 0.0959 - mae: 0.2348 - val_loss: 3.7009e-07 - val_mse: 0.0948 - val_mae: 0.2355
# Epoch 25/120
# 85946/85946 [==============================] - 25s 291us/sample - loss: 3.5866e-07 - mse: 0.0955 - mae: 0.2342 - val_loss: 3.7141e-07 - val_mse: 0.0993 - val_mae: 0.2368
# Epoch 26/120
# 85946/85946 [==============================] - 20s 236us/sample - loss: 3.5640e-07 - mse: 0.0949 - mae: 0.2337 - val_loss: 3.4984e-07 - val_mse: 0.0916 - val_mae: 0.2296
# Epoch 27/120
# 85946/85946 [==============================] - 13s 156us/sample - loss: 3.5332e-07 - mse: 0.0940 - mae: 0.2321 - val_loss: 3.5594e-07 - val_mse: 0.0927 - val_mae: 0.2306
# Epoch 28/120
# 85946/85946 [==============================] - 18s 206us/sample - loss: 3.5293e-07 - mse: 0.0938 - mae: 0.2318 - val_loss: 3.4453e-07 - val_mse: 0.0898 - val_mae: 0.2279
# Epoch 29/120
# 85946/85946 [==============================] - 13s 150us/sample - loss: 3.5076e-07 - mse: 0.0934 - mae: 0.2313 - val_loss: 3.5196e-07 - val_mse: 0.0944 - val_mae: 0.2313
# Epoch 30/120
# 85946/85946 [==============================] - 12s 144us/sample - loss: 3.4846e-07 - mse: 0.0921 - mae: 0.2299 - val_loss: 3.5445e-07 - val_mse: 0.0943 - val_mae: 0.2366
# Epoch 31/120
# 85946/85946 [==============================] - 12s 138us/sample - loss: 3.4879e-07 - mse: 0.0917 - mae: 0.2296 - val_loss: 3.6556e-07 - val_mse: 0.0942 - val_mae: 0.2338
# Epoch 32/120
# 85946/85946 [==============================] - 11s 122us/sample - loss: 3.4663e-07 - mse: 0.0919 - mae: 0.2295 - val_loss: 3.3757e-07 - val_mse: 0.0864 - val_mae: 0.2251
# Epoch 33/120
# 85946/85946 [==============================] - 10s 116us/sample - loss: 3.4525e-07 - mse: 0.0906 - mae: 0.2279 - val_loss: 3.5387e-07 - val_mse: 0.0891 - val_mae: 0.2301
# Epoch 34/120
# 85946/85946 [==============================] - 11s 132us/sample - loss: 3.4373e-07 - mse: 0.0905 - mae: 0.2274 - val_loss: 3.3629e-07 - val_mse: 0.0886 - val_mae: 0.2262
# Epoch 35/120
# 85946/85946 [==============================] - 12s 140us/sample - loss: 3.4337e-07 - mse: 0.0894 - mae: 0.2263 - val_loss: 3.3974e-07 - val_mse: 0.0921 - val_mae: 0.2276
# Epoch 36/120
# 85946/85946 [==============================] - 16s 181us/sample - loss: 3.4159e-07 - mse: 0.0897 - mae: 0.2267 - val_loss: 3.4461e-07 - val_mse: 0.0889 - val_mae: 0.2284
# Epoch 37/120
# 85946/85946 [==============================] - 10s 120us/sample - loss: 3.4113e-07 - mse: 0.0893 - mae: 0.2262 - val_loss: 3.3659e-07 - val_mse: 0.0909 - val_mae: 0.2257
# Epoch 38/120
# 85946/85946 [==============================] - 10s 117us/sample - loss: 3.3915e-07 - mse: 0.0889 - mae: 0.2256 - val_loss: 3.4186e-07 - val_mse: 0.0888 - val_mae: 0.2256
# Epoch 39/120
# 85946/85946 [==============================] - 10s 117us/sample - loss: 3.3940e-07 - mse: 0.0885 - mae: 0.2251 - val_loss: 3.3056e-07 - val_mse: 0.0847 - val_mae: 0.2211
# Epoch 40/120
# 85946/85946 [==============================] - 10s 117us/sample - loss: 3.3800e-07 - mse: 0.0885 - mae: 0.2254 - val_loss: 3.3983e-07 - val_mse: 0.0876 - val_mae: 0.2236
# Epoch 41/120
# 85946/85946 [==============================] - 10s 116us/sample - loss: 3.3645e-07 - mse: 0.0881 - mae: 0.2243 - val_loss: 3.5099e-07 - val_mse: 0.0903 - val_mae: 0.2271
# Epoch 42/120
# 85946/85946 [==============================] - 10s 117us/sample - loss: 3.3638e-07 - mse: 0.0880 - mae: 0.2242 - val_loss: 3.3229e-07 - val_mse: 0.0864 - val_mae: 0.2226
# Epoch 43/120
# 85946/85946 [==============================] - 10s 118us/sample - loss: 3.3617e-07 - mse: 0.0876 - mae: 0.2239 - val_loss: 3.2830e-07 - val_mse: 0.0875 - val_mae: 0.2209
# Epoch 44/120
# 85946/85946 [==============================] - 10s 121us/sample - loss: 3.3403e-07 - mse: 0.0870 - mae: 0.2232 - val_loss: 3.2308e-07 - val_mse: 0.0853 - val_mae: 0.2207
# Epoch 45/120
# 85946/85946 [==============================] - 10s 120us/sample - loss: 3.3386e-07 - mse: 0.0872 - mae: 0.2233 - val_loss: 3.3421e-07 - val_mse: 0.0842 - val_mae: 0.2247
# Epoch 46/120
# 85946/85946 [==============================] - 10s 115us/sample - loss: 3.3126e-07 - mse: 0.0864 - mae: 0.2220 - val_loss: 3.5628e-07 - val_mse: 0.0915 - val_mae: 0.2293
# Epoch 47/120
# 85946/85946 [==============================] - 10s 116us/sample - loss: 3.3076e-07 - mse: 0.0860 - mae: 0.2215 - val_loss: 3.3820e-07 - val_mse: 0.0880 - val_mae: 0.2237
# Epoch 48/120
# 85946/85946 [==============================] - 10s 121us/sample - loss: 3.3086e-07 - mse: 0.0861 - mae: 0.2216 - val_loss: 3.2544e-07 - val_mse: 0.0856 - val_mae: 0.2204
# Epoch 49/120
# 85946/85946 [==============================] - 10s 118us/sample - loss: 3.3015e-07 - mse: 0.0855 - mae: 0.2211 - val_loss: 3.2368e-07 - val_mse: 0.0828 - val_mae: 0.2197
# Epoch 50/120
# 85946/85946 [==============================] - 10s 119us/sample - loss: 3.2808e-07 - mse: 0.0850 - mae: 0.2207 - val_loss: 3.3106e-07 - val_mse: 0.0865 - val_mae: 0.2239
# Epoch 51/120
# 85946/85946 [==============================] - 10s 119us/sample - loss: 3.2754e-07 - mse: 0.0845 - mae: 0.2197 - val_loss: 3.2264e-07 - val_mse: 0.0835 - val_mae: 0.2204
# Epoch 52/120
# 85946/85946 [==============================] - 10s 117us/sample - loss: 3.2660e-07 - mse: 0.0848 - mae: 0.2199 - val_loss: 3.2129e-07 - val_mse: 0.0830 - val_mae: 0.2186
# Epoch 53/120
# 85946/85946 [==============================] - 10s 117us/sample - loss: 3.2685e-07 - mse: 0.0844 - mae: 0.2199 - val_loss: 3.2976e-07 - val_mse: 0.0822 - val_mae: 0.2178
# Epoch 54/120
# 85946/85946 [==============================] - 10s 117us/sample - loss: 3.2650e-07 - mse: 0.0840 - mae: 0.2192 - val_loss: 3.1660e-07 - val_mse: 0.0823 - val_mae: 0.2166
# Epoch 55/120
# 85946/85946 [==============================] - 10s 117us/sample - loss: 3.2474e-07 - mse: 0.0837 - mae: 0.2189 - val_loss: 3.1567e-07 - val_mse: 0.0816 - val_mae: 0.2156
# Epoch 56/120
# 85946/85946 [==============================] - 10s 117us/sample - loss: 3.2325e-07 - mse: 0.0839 - mae: 0.2189 - val_loss: 3.2680e-07 - val_mse: 0.0801 - val_mae: 0.2162
# Epoch 57/120
# 85946/85946 [==============================] - 10s 117us/sample - loss: 3.2324e-07 - mse: 0.0836 - mae: 0.2187 - val_loss: 3.1439e-07 - val_mse: 0.0811 - val_mae: 0.2167
# Epoch 58/120
# 85946/85946 [==============================] - 10s 119us/sample - loss: 3.2312e-07 - mse: 0.0838 - mae: 0.2187 - val_loss: 3.2465e-07 - val_mse: 0.0819 - val_mae: 0.2169
# Epoch 59/120
# 85946/85946 [==============================] - 10s 119us/sample - loss: 3.2171e-07 - mse: 0.0832 - mae: 0.2177 - val_loss: 3.5403e-07 - val_mse: 0.0892 - val_mae: 0.2238
# Epoch 60/120
# 85946/85946 [==============================] - 10s 119us/sample - loss: 3.1974e-07 - mse: 0.0828 - mae: 0.2175 - val_loss: 3.5089e-07 - val_mse: 0.0865 - val_mae: 0.2206
# Epoch 61/120
# 85946/85946 [==============================] - 10s 120us/sample - loss: 3.2025e-07 - mse: 0.0823 - mae: 0.2170 - val_loss: 3.0930e-07 - val_mse: 0.0818 - val_mae: 0.2176
# Epoch 62/120
# 85946/85946 [==============================] - 10s 117us/sample - loss: 3.2099e-07 - mse: 0.0828 - mae: 0.2174 - val_loss: 3.1835e-07 - val_mse: 0.0836 - val_mae: 0.2203
# Epoch 63/120
# 85946/85946 [==============================] - 10s 116us/sample - loss: 3.2010e-07 - mse: 0.0824 - mae: 0.2169 - val_loss: 3.2254e-07 - val_mse: 0.0825 - val_mae: 0.2158

# %%
# Runs NN Model for FAPAR

FAPAR_history = FAPAR_model.fit(x = numpy.array(training_data), y = numpy.array(FAPAR_training),
                                sample_weight = training_weights,
                                epochs = 20, 
                                validation_data = (numpy.array(valid_data), numpy.array(FAPAR_valid), valid_weights),
                                callbacks=[FAPAR_callback]
                               )
# Out:
# Train on 85946 samples, validate on 36834 samples
# Epoch 1/20
# 85946/85946 [==============================] - 13s 148us/sample - loss: 3.4749e-07 - mse: 0.1020 - mae: 0.2190 - val_loss: 1.6893e-07 - val_mse: 0.0503 - val_mae: 0.1613
# Epoch 2/20
# 85946/85946 [==============================] - 10s 117us/sample - loss: 1.4606e-07 - mse: 0.0431 - mae: 0.1504 - val_loss: 1.2770e-07 - val_mse: 0.0375 - val_mae: 0.1407
# Epoch 3/20
# 85946/85946 [==============================] - 10s 117us/sample - loss: 1.1737e-07 - mse: 0.0337 - mae: 0.1341 - val_loss: 1.0548e-07 - val_mse: 0.0301 - val_mae: 0.1271
# Epoch 4/20
# 85946/85946 [==============================] - 10s 116us/sample - loss: 9.9291e-08 - mse: 0.0284 - mae: 0.1229 - val_loss: 9.0700e-08 - val_mse: 0.0264 - val_mae: 0.1189
# Epoch 5/20
# 85946/85946 [==============================] - 10s 117us/sample - loss: 8.8104e-08 - mse: 0.0255 - mae: 0.1160 - val_loss: 8.3810e-08 - val_mse: 0.0250 - val_mae: 0.1142
# Epoch 6/20
# 85946/85946 [==============================] - 11s 129us/sample - loss: 8.1950e-08 - mse: 0.0238 - mae: 0.1115 - val_loss: 8.0640e-08 - val_mse: 0.0225 - val_mae: 0.1079
# Epoch 7/20
# 85946/85946 [==============================] - 10s 118us/sample - loss: 7.8559e-08 - mse: 0.0227 - mae: 0.1086 - val_loss: 7.7335e-08 - val_mse: 0.0215 - val_mae: 0.1052
# Epoch 8/20
# 85946/85946 [==============================] - 10s 117us/sample - loss: 7.5739e-08 - mse: 0.0220 - mae: 0.1066 - val_loss: 7.2758e-08 - val_mse: 0.0206 - val_mae: 0.1030
# Epoch 9/20
# 85946/85946 [==============================] - 10s 117us/sample - loss: 7.3697e-08 - mse: 0.0214 - mae: 0.1045 - val_loss: 7.1458e-08 - val_mse: 0.0204 - val_mae: 0.1023
# Epoch 10/20
# 85946/85946 [==============================] - 10s 117us/sample - loss: 7.1902e-08 - mse: 0.0209 - mae: 0.1033 - val_loss: 6.9270e-08 - val_mse: 0.0200 - val_mae: 0.1012
# Epoch 11/20
# 85946/85946 [==============================] - 10s 118us/sample - loss: 7.0634e-08 - mse: 0.0204 - mae: 0.1019 - val_loss: 6.7757e-08 - val_mse: 0.0197 - val_mae: 0.1000
# Epoch 12/20
# 85946/85946 [==============================] - 10s 118us/sample - loss: 6.9403e-08 - mse: 0.0201 - mae: 0.1008 - val_loss: 6.7402e-08 - val_mse: 0.0192 - val_mae: 0.0988
# Epoch 13/20
# 85946/85946 [==============================] - 10s 117us/sample - loss: 6.8339e-08 - mse: 0.0197 - mae: 0.0999 - val_loss: 6.8820e-08 - val_mse: 0.0207 - val_mae: 0.1021
# Epoch 14/20
# 85946/85946 [==============================] - 10s 117us/sample - loss: 6.7358e-08 - mse: 0.0195 - mae: 0.0990 - val_loss: 6.9998e-08 - val_mse: 0.0191 - val_mae: 0.0979
# Epoch 15/20
# 85946/85946 [==============================] - 10s 118us/sample - loss: 6.6513e-08 - mse: 0.0192 - mae: 0.0982 - val_loss: 6.4481e-08 - val_mse: 0.0185 - val_mae: 0.0965
# Epoch 16/20
# 85946/85946 [==============================] - 10s 116us/sample - loss: 6.5631e-08 - mse: 0.0190 - mae: 0.0975 - val_loss: 6.4020e-08 - val_mse: 0.0185 - val_mae: 0.0954
# Epoch 17/20
# 85946/85946 [==============================] - 10s 118us/sample - loss: 6.4780e-08 - mse: 0.0188 - mae: 0.0968 - val_loss: 6.5502e-08 - val_mse: 0.0184 - val_mae: 0.0961
# Epoch 18/20
# 85946/85946 [==============================] - 10s 121us/sample - loss: 6.4107e-08 - mse: 0.0186 - mae: 0.0963 - val_loss: 6.2597e-08 - val_mse: 0.0184 - val_mae: 0.0955
# Epoch 19/20
# 85946/85946 [==============================] - 10s 117us/sample - loss: 6.3224e-08 - mse: 0.0185 - mae: 0.0956 - val_loss: 6.6183e-08 - val_mse: 0.0201 - val_mae: 0.0988
# Epoch 20/20
# 85946/85946 [==============================] - 10s 117us/sample - loss: 6.2434e-08 - mse: 0.0183 - mae: 0.0951 - val_loss: 6.3172e-08 - val_mse: 0.0177 - val_mae: 0.0934

# %%
# Runs NN Model for FCOVER

FCOVER_history = FCOVER_model.fit(x = numpy.array(training_data), y = numpy.array(FCOVER_training),
                                  sample_weight = training_weights,
                                  epochs = 20, 
                                  validation_data = (numpy.array(valid_data), numpy.array(FCOVER_valid), valid_weights),
                                  callbacks=[FCOVER_callback]
                                 )
# Out:
# Train on 85946 samples, validate on 36834 samples
# Epoch 1/20
# 85946/85946 [==============================] - 13s 147us/sample - loss: 4.1945e-07 - mse: 0.1334 - mae: 0.2423 - val_loss: 1.6177e-07 - val_mse: 0.0501 - val_mae: 0.1611
# Epoch 2/20
# 85946/85946 [==============================] - 10s 117us/sample - loss: 1.3378e-07 - mse: 0.0419 - mae: 0.1460 - val_loss: 1.1226e-07 - val_mse: 0.0346 - val_mae: 0.1339
# Epoch 3/20
# 85946/85946 [==============================] - 10s 117us/sample - loss: 9.9195e-08 - mse: 0.0294 - mae: 0.1252 - val_loss: 8.8332e-08 - val_mse: 0.0257 - val_mae: 0.1190
# Epoch 4/20
# 85946/85946 [==============================] - 10s 117us/sample - loss: 8.3867e-08 - mse: 0.0245 - mae: 0.1155 - val_loss: 7.7494e-08 - val_mse: 0.0227 - val_mae: 0.1112
# Epoch 5/20
# 85946/85946 [==============================] - 10s 118us/sample - loss: 7.5697e-08 - mse: 0.0221 - mae: 0.1098 - val_loss: 7.0322e-08 - val_mse: 0.0205 - val_mae: 0.1054
# Epoch 6/20
# 85946/85946 [==============================] - 11s 132us/sample - loss: 7.0630e-08 - mse: 0.0206 - mae: 0.1055 - val_loss: 6.6509e-08 - val_mse: 0.0196 - val_mae: 0.1026
# Epoch 7/20
# 85946/85946 [==============================] - 12s 139us/sample - loss: 6.6900e-08 - mse: 0.0196 - mae: 0.1025 - val_loss: 6.4778e-08 - val_mse: 0.0183 - val_mae: 0.0987
# Epoch 8/20
# 85946/85946 [==============================] - 11s 124us/sample - loss: 6.4326e-08 - mse: 0.0188 - mae: 0.1001 - val_loss: 6.0796e-08 - val_mse: 0.0179 - val_mae: 0.0985
# Epoch 9/20
# 85946/85946 [==============================] - 11s 124us/sample - loss: 6.2337e-08 - mse: 0.0183 - mae: 0.0985 - val_loss: 6.0052e-08 - val_mse: 0.0174 - val_mae: 0.0969
# Epoch 10/20
# 85946/85946 [==============================] - 11s 123us/sample - loss: 6.0862e-08 - mse: 0.0177 - mae: 0.0972 - val_loss: 5.9936e-08 - val_mse: 0.0172 - val_mae: 0.0960
# Epoch 11/20
# 85946/85946 [==============================] - 11s 123us/sample - loss: 5.9500e-08 - mse: 0.0173 - mae: 0.0959 - val_loss: 5.7722e-08 - val_mse: 0.0166 - val_mae: 0.0945
# Epoch 12/20
# 85946/85946 [==============================] - 11s 126us/sample - loss: 5.8378e-08 - mse: 0.0170 - mae: 0.0949 - val_loss: 5.6975e-08 - val_mse: 0.0164 - val_mae: 0.0937
# Epoch 13/20
# 85946/85946 [==============================] - 11s 127us/sample - loss: 5.7255e-08 - mse: 0.0167 - mae: 0.0941 - val_loss: 5.5493e-08 - val_mse: 0.0159 - val_mae: 0.0917
# Epoch 14/20
# 85946/85946 [==============================] - 11s 124us/sample - loss: 5.6335e-08 - mse: 0.0164 - mae: 0.0931 - val_loss: 5.4930e-08 - val_mse: 0.0160 - val_mae: 0.0922
# Epoch 15/20
# 85946/85946 [==============================] - 11s 123us/sample - loss: 5.5751e-08 - mse: 0.0162 - mae: 0.0924 - val_loss: 5.4054e-08 - val_mse: 0.0153 - val_mae: 0.0899
# Epoch 16/20
# 85946/85946 [==============================] - 12s 140us/sample - loss: 5.5065e-08 - mse: 0.0160 - mae: 0.0918 - val_loss: 5.3854e-08 - val_mse: 0.0161 - val_mae: 0.0915
# Epoch 17/20
# 85946/85946 [==============================] - 13s 146us/sample - loss: 5.4548e-08 - mse: 0.0158 - mae: 0.0912 - val_loss: 5.3221e-08 - val_mse: 0.0151 - val_mae: 0.0894
# Epoch 18/20
# 85946/85946 [==============================] - 11s 130us/sample - loss: 5.3769e-08 - mse: 0.0155 - mae: 0.0904 - val_loss: 5.2982e-08 - val_mse: 0.0154 - val_mae: 0.0897
# Epoch 19/20
# 85946/85946 [==============================] - 11s 123us/sample - loss: 5.3325e-08 - mse: 0.0154 - mae: 0.0898 - val_loss: 5.2206e-08 - val_mse: 0.0149 - val_mae: 0.0882
# Epoch 20/20
# 85946/85946 [==============================] - 13s 149us/sample - loss: 5.2850e-08 - mse: 0.0152 - mae: 0.0893 - val_loss: 5.2041e-08 - val_mse: 0.0145 - val_mae: 0.0874

# %%
# These are all plots for the RMSE of the NN as training was run

# %%
LAI_rmse = plt.plot(numpy.sqrt(LAI_history.history['mse']))
plt.xlabel("Epoch Number")
plt.ylabel("RMSE")
plt.title("LAI RMSE")
plt.show()

# %%
FAPAR_rmse = plt.plot(numpy.sqrt(FAPAR_history.history['mse']))
plt.xlabel("Epoch Number")
plt.ylabel("RMSE")
plt.title("FAPAR RMSE")
plt.show()

# %%
FCOVER_rmse = plt.plot(numpy.sqrt(FCOVER_history.history['mse']))
plt.xlabel("Epoch Number")
plt.ylabel("RMSE")
plt.title("FCOVER RMSE")
plt.show()

# %%
# Makes predictions on the validation data using the 

LAI_predictions = pandas.Series(LAI_model.predict(numpy.array(valid_data)).flatten())
FAPAR_predictions = pandas.Series(FAPAR_model.predict(numpy.array(valid_data)).flatten())
FCOVER_predictions = pandas.Series(FCOVER_model.predict(numpy.array(valid_data)).flatten())

# %%
# Creates a model for LAI, FAPAR, and FCOVER using LARs regression 

LAImodel = sklearn.linear_model.Lars(n_nonzero_coefs=4)
LAImodel = LAImodel.fit(training_data, LAI_training)

FAPARmodel = sklearn.linear_model.Lars(n_nonzero_coefs=4)
FAPARmodel = FAPARmodel.fit(training_data, FAPAR_training)

FCOVERmodel = sklearn.linear_model.Lars(n_nonzero_coefs=4)
FCOVERmodel = FCOVERmodel.fit(training_data, FCOVER_training)

# %%
# Makes predictions on the validation data using the LARS models

LAI_predicted = pandas.Series(LAImodel.predict(valid_data))
FAPAR_predicted = pandas.Series(FAPARmodel.predict(valid_data))
FCOVER_predicted = pandas.Series(FCOVERmodel.predict(valid_data))

# %%
# Function that creates the density plots 

def plotting_function(var, input_var, resp_var, title, xlabel, ylabel, alg, ax=None):
    ax = ax
    input_var = input_var*cal_data[var].std() + cal_data[var].mean()
    resp_var = resp_var*cal_data[var].std() + cal_data[var].mean()
    xy = numpy.vstack([input_var, resp_var])
    z = scipy.stats.gaussian_kde(xy)(xy)
    idx = z.argsort()
    x = input_var[idx]
    y = resp_var[idx]
    z = z[idx]
    rmse = sklearn.metrics.mean_squared_error(x, y, squared=False)
    r_sqr = sklearn.metrics.r2_score(x, y)
    ax.scatter(x, y, c = z)
    plt.colorbar(mappable=ax.scatter(x, y, c = z), ax=ax)
    ax.set_title(title + '-' + alg + ' - RMSE: {}'.format(rmse) + ' - $R^2$: {}'.format(r_sqr))
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)

# %%
def lai_greater_four(var, input_var, resp_var, title, xlabel, ylabel, alg, ax=None):
    ax=ax
    input_var = input_var*cal_data[var].std() + cal_data[var].mean()
    resp_var = resp_var*cal_data[var].std() + cal_data[var].mean()
    indices = numpy.where(numpy.array(resp_var) > 4)[0]
    input_var = input_var[indices]
    resp_var = resp_var[indices]
    xy = numpy.vstack([input_var, resp_var])
    z = scipy.stats.gaussian_kde(xy)(xy)
    x = input_var
    y = resp_var
    rmse = sklearn.metrics.mean_squared_error(x, y, squared=False)
    r_sqr = sklearn.metrics.r2_score(x, y)
    ax.scatter(x, y, c = z)
    plt.colorbar(mappable=ax.scatter(x, y, c = z), ax=ax)
    ax.set_title(title + '-' + alg + ' - RMSE: {}'.format(rmse) + ' - $R^2$: {}'.format(r_sqr))
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3,figsize=(25,15))

plotting_function('LAI',LAI_valid, LAI_predicted, 'LAI','Input LAI','Predicted LAI','LARS', ax1)
  
plotting_function('FAPAR',FAPAR_valid, FAPAR_predicted, 'FAPAR','Input FAPAR','Predicted FAPAR','LARS', ax2)

plotting_function('FCOVER',FCOVER_valid, FCOVER_predicted, 'FCOVER','Input FCOVER','Predicted FCOVER','LARS', ax3)

fig.suptitle('Reference LAI Greater than Four - LARS', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Reference LAI Greater than Four - LARS')

# %%
fig, (ax4) = plt.subplots(1,1,figsize=(25,15))

lai_greater_four('LAI',LAI_valid, LAI_predicted, 'LAI','Input LAI','Predicted LAI','LARS', ax4)

fig.suptitle('Reference LAI Greater than Four - Only LAI Values Greater than Four - LARS', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Reference LAI Greater than Four - Only LAI Values Greater than Four - LARS')

# %%
fig, (ax5, ax6, ax7) = plt.subplots(1,3,figsize=(25,15))

plotting_function('LAI', LAI_valid, LAI_predictions, 'LAI','Input LAI','Predicted LAI','NNet',ax5)
plotting_function('FAPAR', FAPAR_valid, FAPAR_predictions, 'FAPAR','Input FAPAR','Predicted FAPAR','NNet',ax6)
plotting_function('FCOVER', FCOVER_valid, FCOVER_predictions, 'FCOVER','Input FCOVER','Predicted FCOVER','NNet',ax7)

fig.suptitle('Reference LAI Greater than Four - Neural Network - with weights', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Reference LAI Greater than Four - Neural Network - with weights')

# %%
fig, (ax8) = plt.subplots(1,1,figsize=(25,15))

lai_greater_four('LAI', LAI_valid, LAI_predictions, 'LAI','Input LAI','Predicted LAI','NNet',ax8)

fig.suptitle('Reference LAI Greater than Four - Only Values of LAI Greater than Four - Neural Network - with weights', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Reference LAI Greater than Four - Only Values of LAI Greater than Four - Neural Network - with weights')

# %%
# Creation of the Neural Network models for LAI, FAPAR, and FCOVER 

LAI_model_no_weights = tensorflow.keras.models.Sequential([
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu, 
                                  input_shape=[len(training_data.keys())]),
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu),
    tensorflow.keras.layers.Dense(1)
])

LAI_model_no_weights.compile(
    optimizer=tensorflow.keras.optimizers.Nadam(),
    loss='mse',
    metrics=['mse', 'mae'])

FAPAR_model_no_weights = tensorflow.keras.models.Sequential([
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu, 
                                  input_shape=[len(training_data.keys())]),
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu),
    tensorflow.keras.layers.Dense(1)
])

FAPAR_model_no_weights.compile(
    optimizer=tensorflow.keras.optimizers.Nadam(),
    loss='mse',
    metrics=['mse', 'mae'])

FCOVER_model_no_weights = tensorflow.keras.models.Sequential([
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu, 
                                  input_shape=[len(training_data.keys())]),
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu),
    tensorflow.keras.layers.Dense(1)
])

FCOVER_model_no_weights.compile(
    optimizer=tensorflow.keras.optimizers.Nadam(),
    loss='mse',
    metrics=['mse', 'mae'])

# %%
# Runs NN Model for LAI

LAI_history_no_weights = LAI_model_no_weights.fit(x = numpy.array(training_data), y = numpy.array(LAI_training), 
                            epochs = 120,
                            validation_data = (numpy.array(valid_data), numpy.array(LAI_valid)) 
                           )
# Out:
# Train on 85946 samples, validate on 36834 samples
# Epoch 1/120
# 85946/85946 [==============================] - 11s 132us/sample - loss: 0.3536 - mse: 0.3536 - mae: 0.4762 - val_loss: 0.2129 - val_mse: 0.2129 - val_mae: 0.3631
# Epoch 2/120
# 85946/85946 [==============================] - 10s 113us/sample - loss: 0.1775 - mse: 0.1775 - mae: 0.3294 - val_loss: 0.1539 - val_mse: 0.1539 - val_mae: 0.3040
# Epoch 3/120
# 85946/85946 [==============================] - 12s 139us/sample - loss: 0.1440 - mse: 0.1440 - mae: 0.2947 - val_loss: 0.1368 - val_mse: 0.1368 - val_mae: 0.2856
# Epoch 4/120
# 85946/85946 [==============================] - 12s 136us/sample - loss: 0.1318 - mse: 0.1318 - mae: 0.2813 - val_loss: 0.1278 - val_mse: 0.1278 - val_mae: 0.2778
# Epoch 5/120
# 85946/85946 [==============================] - 11s 127us/sample - loss: 0.1223 - mse: 0.1223 - mae: 0.2702 - val_loss: 0.1168 - val_mse: 0.1168 - val_mae: 0.2638
# Epoch 6/120
# 85946/85946 [==============================] - 9s 106us/sample - loss: 0.1129 - mse: 0.1129 - mae: 0.2594 - val_loss: 0.1080 - val_mse: 0.1080 - val_mae: 0.2560
# Epoch 7/120
# 85946/85946 [==============================] - 9s 107us/sample - loss: 0.1058 - mse: 0.1058 - mae: 0.2507 - val_loss: 0.1032 - val_mse: 0.1032 - val_mae: 0.2499
# Epoch 8/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.1009 - mse: 0.1009 - mae: 0.2445 - val_loss: 0.0969 - val_mse: 0.0969 - val_mae: 0.2385
# Epoch 9/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0970 - mse: 0.0970 - mae: 0.2396 - val_loss: 0.0953 - val_mse: 0.0953 - val_mae: 0.2368
# Epoch 10/120
# 85946/85946 [==============================] - 9s 106us/sample - loss: 0.0943 - mse: 0.0943 - mae: 0.2361 - val_loss: 0.0919 - val_mse: 0.0919 - val_mae: 0.2344
# Epoch 11/120
# 85946/85946 [==============================] - 9s 107us/sample - loss: 0.0924 - mse: 0.0924 - mae: 0.2334 - val_loss: 0.0901 - val_mse: 0.0901 - val_mae: 0.2291
# Epoch 12/120
# 85946/85946 [==============================] - 11s 128us/sample - loss: 0.0904 - mse: 0.0904 - mae: 0.2307 - val_loss: 0.0890 - val_mse: 0.0890 - val_mae: 0.2297
# Epoch 13/120
# 85946/85946 [==============================] - 11s 131us/sample - loss: 0.0890 - mse: 0.0890 - mae: 0.2287 - val_loss: 0.0858 - val_mse: 0.0858 - val_mae: 0.2248
# Epoch 14/120
# 85946/85946 [==============================] - 11s 129us/sample - loss: 0.0872 - mse: 0.0872 - mae: 0.2263 - val_loss: 0.0879 - val_mse: 0.0879 - val_mae: 0.2261
# Epoch 15/120
# 85946/85946 [==============================] - 11s 133us/sample - loss: 0.0866 - mse: 0.0866 - mae: 0.2256 - val_loss: 0.0862 - val_mse: 0.0862 - val_mae: 0.2250
# Epoch 16/120
# 85946/85946 [==============================] - 13s 149us/sample - loss: 0.0853 - mse: 0.0853 - mae: 0.2242 - val_loss: 0.0852 - val_mse: 0.0852 - val_mae: 0.2239
# Epoch 17/120
# 85946/85946 [==============================] - 11s 126us/sample - loss: 0.0844 - mse: 0.0844 - mae: 0.2228 - val_loss: 0.0860 - val_mse: 0.0860 - val_mae: 0.2237
# Epoch 18/120
# 85946/85946 [==============================] - 10s 122us/sample - loss: 0.0836 - mse: 0.0836 - mae: 0.2219 - val_loss: 0.0850 - val_mse: 0.0850 - val_mae: 0.2268
# Epoch 19/120
# 85946/85946 [==============================] - 12s 136us/sample - loss: 0.0827 - mse: 0.0827 - mae: 0.2205 - val_loss: 0.0825 - val_mse: 0.0825 - val_mae: 0.2213
# Epoch 20/120
# 85946/85946 [==============================] - 13s 146us/sample - loss: 0.0815 - mse: 0.0815 - mae: 0.2189 - val_loss: 0.0816 - val_mse: 0.0816 - val_mae: 0.2182
# Epoch 21/120
# 85946/85946 [==============================] - 13s 156us/sample - loss: 0.0809 - mse: 0.0809 - mae: 0.2182 - val_loss: 0.0834 - val_mse: 0.0834 - val_mae: 0.2233
# Epoch 22/120
# 85946/85946 [==============================] - 10s 118us/sample - loss: 0.0803 - mse: 0.0803 - mae: 0.2174 - val_loss: 0.0789 - val_mse: 0.0789 - val_mae: 0.2144
# Epoch 23/120
# 85946/85946 [==============================] - 10s 111us/sample - loss: 0.0801 - mse: 0.0801 - mae: 0.2170 - val_loss: 0.0827 - val_mse: 0.0827 - val_mae: 0.2203
# Epoch 24/120
# 85946/85946 [==============================] - 10s 113us/sample - loss: 0.0794 - mse: 0.0794 - mae: 0.2161 - val_loss: 0.0785 - val_mse: 0.0785 - val_mae: 0.2167
# Epoch 25/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0791 - mse: 0.0791 - mae: 0.2159 - val_loss: 0.0803 - val_mse: 0.0803 - val_mae: 0.2169
# Epoch 26/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0788 - mse: 0.0788 - mae: 0.2154 - val_loss: 0.0762 - val_mse: 0.0762 - val_mae: 0.2124
# Epoch 27/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0781 - mse: 0.0781 - mae: 0.2145 - val_loss: 0.0790 - val_mse: 0.0790 - val_mae: 0.2154
# Epoch 28/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0780 - mse: 0.0780 - mae: 0.2144 - val_loss: 0.0781 - val_mse: 0.0781 - val_mae: 0.2135
# Epoch 29/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0779 - mse: 0.0779 - mae: 0.2141 - val_loss: 0.0789 - val_mse: 0.0789 - val_mae: 0.2166
# Epoch 30/120
# 85946/85946 [==============================] - 9s 110us/sample - loss: 0.0774 - mse: 0.0774 - mae: 0.2135 - val_loss: 0.0756 - val_mse: 0.0756 - val_mae: 0.2119
# Epoch 31/120
# 85946/85946 [==============================] - 9s 110us/sample - loss: 0.0772 - mse: 0.0772 - mae: 0.2132 - val_loss: 0.0763 - val_mse: 0.0763 - val_mae: 0.2109
# Epoch 32/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0769 - mse: 0.0769 - mae: 0.2127 - val_loss: 0.0735 - val_mse: 0.0735 - val_mae: 0.2083
# Epoch 33/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0767 - mse: 0.0767 - mae: 0.2123 - val_loss: 0.0767 - val_mse: 0.0767 - val_mae: 0.2117
# Epoch 34/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0764 - mse: 0.0764 - mae: 0.2118 - val_loss: 0.0755 - val_mse: 0.0755 - val_mae: 0.2092
# Epoch 35/120
# 85946/85946 [==============================] - 9s 110us/sample - loss: 0.0761 - mse: 0.0761 - mae: 0.2114 - val_loss: 0.0738 - val_mse: 0.0738 - val_mae: 0.2076
# Epoch 36/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0760 - mse: 0.0760 - mae: 0.2112 - val_loss: 0.0762 - val_mse: 0.0762 - val_mae: 0.2116
# Epoch 37/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0758 - mse: 0.0758 - mae: 0.2107 - val_loss: 0.0766 - val_mse: 0.0766 - val_mae: 0.2096
# Epoch 38/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0755 - mse: 0.0755 - mae: 0.2105 - val_loss: 0.0756 - val_mse: 0.0756 - val_mae: 0.2115
# Epoch 39/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0753 - mse: 0.0753 - mae: 0.2101 - val_loss: 0.0727 - val_mse: 0.0727 - val_mae: 0.2078
# Epoch 40/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0750 - mse: 0.0750 - mae: 0.2097 - val_loss: 0.0759 - val_mse: 0.0759 - val_mae: 0.2080
# Epoch 41/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0747 - mse: 0.0747 - mae: 0.2092 - val_loss: 0.0792 - val_mse: 0.0792 - val_mae: 0.2162
# Epoch 42/120
# 85946/85946 [==============================] - 9s 110us/sample - loss: 0.0747 - mse: 0.0747 - mae: 0.2093 - val_loss: 0.0775 - val_mse: 0.0775 - val_mae: 0.2132
# Epoch 43/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0746 - mse: 0.0746 - mae: 0.2091 - val_loss: 0.0814 - val_mse: 0.0814 - val_mae: 0.2173
# Epoch 44/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0741 - mse: 0.0741 - mae: 0.2082 - val_loss: 0.0741 - val_mse: 0.0741 - val_mae: 0.2100
# Epoch 45/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0742 - mse: 0.0742 - mae: 0.2086 - val_loss: 0.0720 - val_mse: 0.0720 - val_mae: 0.2050
# Epoch 46/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0742 - mse: 0.0742 - mae: 0.2085 - val_loss: 0.0740 - val_mse: 0.0740 - val_mae: 0.2070
# Epoch 47/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0740 - mse: 0.0740 - mae: 0.2082 - val_loss: 0.0723 - val_mse: 0.0723 - val_mae: 0.2059
# Epoch 48/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0740 - mse: 0.0740 - mae: 0.2081 - val_loss: 0.0729 - val_mse: 0.0729 - val_mae: 0.2063
# Epoch 49/120
# 85946/85946 [==============================] - 9s 110us/sample - loss: 0.0735 - mse: 0.0735 - mae: 0.2074 - val_loss: 0.0757 - val_mse: 0.0757 - val_mae: 0.2079
# Epoch 50/120
# 85946/85946 [==============================] - 10s 111us/sample - loss: 0.0735 - mse: 0.0735 - mae: 0.2074 - val_loss: 0.0727 - val_mse: 0.0727 - val_mae: 0.2071
# Epoch 51/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0733 - mse: 0.0733 - mae: 0.2071 - val_loss: 0.0732 - val_mse: 0.0732 - val_mae: 0.2068
# Epoch 52/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0732 - mse: 0.0732 - mae: 0.2069 - val_loss: 0.0732 - val_mse: 0.0732 - val_mae: 0.2044
# Epoch 53/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0728 - mse: 0.0728 - mae: 0.2063 - val_loss: 0.0709 - val_mse: 0.0709 - val_mae: 0.2030
# Epoch 54/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0728 - mse: 0.0728 - mae: 0.2063 - val_loss: 0.0709 - val_mse: 0.0709 - val_mae: 0.2040
# Epoch 55/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0727 - mse: 0.0727 - mae: 0.2060 - val_loss: 0.0740 - val_mse: 0.0740 - val_mae: 0.2051
# Epoch 56/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0727 - mse: 0.0727 - mae: 0.2062 - val_loss: 0.0720 - val_mse: 0.0720 - val_mae: 0.2070
# Epoch 57/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0724 - mse: 0.0724 - mae: 0.2054 - val_loss: 0.0699 - val_mse: 0.0699 - val_mae: 0.2021
# Epoch 58/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0721 - mse: 0.0721 - mae: 0.2053 - val_loss: 0.0738 - val_mse: 0.0738 - val_mae: 0.2060
# Epoch 59/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0722 - mse: 0.0722 - mae: 0.2051 - val_loss: 0.0705 - val_mse: 0.0705 - val_mae: 0.2027
# Epoch 60/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0719 - mse: 0.0719 - mae: 0.2047 - val_loss: 0.0712 - val_mse: 0.0712 - val_mae: 0.2043
# Epoch 61/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0716 - mse: 0.0716 - mae: 0.2040 - val_loss: 0.0707 - val_mse: 0.0707 - val_mae: 0.2030
# Epoch 62/120
# 85946/85946 [==============================] - 9s 110us/sample - loss: 0.0716 - mse: 0.0716 - mae: 0.2040 - val_loss: 0.0713 - val_mse: 0.0713 - val_mae: 0.2031
# Epoch 63/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0713 - mse: 0.0713 - mae: 0.2036 - val_loss: 0.0694 - val_mse: 0.0694 - val_mae: 0.2016
# Epoch 64/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0711 - mse: 0.0711 - mae: 0.2032 - val_loss: 0.0688 - val_mse: 0.0688 - val_mae: 0.2011
# Epoch 65/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0710 - mse: 0.0710 - mae: 0.2030 - val_loss: 0.0695 - val_mse: 0.0695 - val_mae: 0.2011
# Epoch 66/120
# 85946/85946 [==============================] - 9s 110us/sample - loss: 0.0708 - mse: 0.0708 - mae: 0.2027 - val_loss: 0.0687 - val_mse: 0.0687 - val_mae: 0.1997
# Epoch 67/120
# 85946/85946 [==============================] - 9s 110us/sample - loss: 0.0706 - mse: 0.0706 - mae: 0.2023 - val_loss: 0.0730 - val_mse: 0.0730 - val_mae: 0.2051
# Epoch 68/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0704 - mse: 0.0704 - mae: 0.2018 - val_loss: 0.0724 - val_mse: 0.0724 - val_mae: 0.2046
# Epoch 69/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0706 - mse: 0.0706 - mae: 0.2021 - val_loss: 0.0682 - val_mse: 0.0682 - val_mae: 0.1990
# Epoch 70/120
# 85946/85946 [==============================] - 9s 110us/sample - loss: 0.0704 - mse: 0.0704 - mae: 0.2020 - val_loss: 0.0679 - val_mse: 0.0679 - val_mae: 0.1975
# Epoch 71/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0702 - mse: 0.0702 - mae: 0.2018 - val_loss: 0.0708 - val_mse: 0.0708 - val_mae: 0.2028
# Epoch 72/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0700 - mse: 0.0700 - mae: 0.2014 - val_loss: 0.0720 - val_mse: 0.0720 - val_mae: 0.2042
# Epoch 73/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0700 - mse: 0.0700 - mae: 0.2012 - val_loss: 0.0712 - val_mse: 0.0712 - val_mae: 0.2028
# Epoch 74/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0699 - mse: 0.0699 - mae: 0.2010 - val_loss: 0.0698 - val_mse: 0.0698 - val_mae: 0.2026
# Epoch 75/120
# 85946/85946 [==============================] - 9s 110us/sample - loss: 0.0698 - mse: 0.0698 - mae: 0.2012 - val_loss: 0.0709 - val_mse: 0.0709 - val_mae: 0.2015
# Epoch 76/120
# 85946/85946 [==============================] - 9s 110us/sample - loss: 0.0697 - mse: 0.0697 - mae: 0.2008 - val_loss: 0.0704 - val_mse: 0.0704 - val_mae: 0.2028
# Epoch 77/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0698 - mse: 0.0698 - mae: 0.2012 - val_loss: 0.0685 - val_mse: 0.0685 - val_mae: 0.1993
# Epoch 78/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0694 - mse: 0.0694 - mae: 0.2005 - val_loss: 0.0741 - val_mse: 0.0741 - val_mae: 0.2070
# Epoch 79/120
# 85946/85946 [==============================] - 10s 112us/sample - loss: 0.0694 - mse: 0.0694 - mae: 0.2002 - val_loss: 0.0688 - val_mse: 0.0688 - val_mae: 0.2014
# Epoch 80/120
# 85946/85946 [==============================] - 9s 110us/sample - loss: 0.0695 - mse: 0.0695 - mae: 0.2007 - val_loss: 0.0720 - val_mse: 0.0720 - val_mae: 0.2045
# Epoch 81/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0693 - mse: 0.0693 - mae: 0.1999 - val_loss: 0.0680 - val_mse: 0.0680 - val_mae: 0.1987
# Epoch 82/120
# 85946/85946 [==============================] - 10s 111us/sample - loss: 0.0693 - mse: 0.0693 - mae: 0.2002 - val_loss: 0.0683 - val_mse: 0.0683 - val_mae: 0.1991
# Epoch 83/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0691 - mse: 0.0691 - mae: 0.2002 - val_loss: 0.0709 - val_mse: 0.0709 - val_mae: 0.2024
# Epoch 84/120
# 85946/85946 [==============================] - 9s 110us/sample - loss: 0.0693 - mse: 0.0693 - mae: 0.2004 - val_loss: 0.0677 - val_mse: 0.0677 - val_mae: 0.1972
# Epoch 85/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0690 - mse: 0.0690 - mae: 0.2001 - val_loss: 0.0691 - val_mse: 0.0691 - val_mae: 0.1986
# Epoch 86/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0689 - mse: 0.0689 - mae: 0.1998 - val_loss: 0.0678 - val_mse: 0.0678 - val_mae: 0.1988
# Epoch 87/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0691 - mse: 0.0691 - mae: 0.2000 - val_loss: 0.0678 - val_mse: 0.0678 - val_mae: 0.1978
# Epoch 88/120
# 85946/85946 [==============================] - 9s 110us/sample - loss: 0.0689 - mse: 0.0689 - mae: 0.1996 - val_loss: 0.0694 - val_mse: 0.0694 - val_mae: 0.2009
# Epoch 89/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0689 - mse: 0.0689 - mae: 0.1997 - val_loss: 0.0696 - val_mse: 0.0696 - val_mae: 0.2049
# Epoch 90/120
# 85946/85946 [==============================] - 9s 110us/sample - loss: 0.0687 - mse: 0.0687 - mae: 0.1994 - val_loss: 0.0717 - val_mse: 0.0717 - val_mae: 0.2049
# Epoch 91/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0688 - mse: 0.0688 - mae: 0.1997 - val_loss: 0.0662 - val_mse: 0.0662 - val_mae: 0.1969
# Epoch 92/120
# 85946/85946 [==============================] - 9s 110us/sample - loss: 0.0688 - mse: 0.0688 - mae: 0.1995 - val_loss: 0.0676 - val_mse: 0.0676 - val_mae: 0.2000
# Epoch 93/120
# 85946/85946 [==============================] - 9s 110us/sample - loss: 0.0687 - mse: 0.0687 - mae: 0.1996 - val_loss: 0.0691 - val_mse: 0.0691 - val_mae: 0.1986
# Epoch 94/120
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0686 - mse: 0.0686 - mae: 0.1994 - val_loss: 0.0678 - val_mse: 0.0678 - val_mae: 0.1987
# Epoch 95/120
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0685 - mse: 0.0685 - mae: 0.1992 - val_loss: 0.0718 - val_mse: 0.0718 - val_mae: 0.2042
# Epoch 96/120
# 85946/85946 [==============================] - 11s 130us/sample - loss: 0.0686 - mse: 0.0686 - mae: 0.1993 - val_loss: 0.0663 - val_mse: 0.0663 - val_mae: 0.1955
# Epoch 97/120
# 85946/85946 [==============================] - 11s 129us/sample - loss: 0.0684 - mse: 0.0684 - mae: 0.1991 - val_loss: 0.0698 - val_mse: 0.0698 - val_mae: 0.2002
# Epoch 98/120
# 85946/85946 [==============================] - 11s 125us/sample - loss: 0.0684 - mse: 0.0684 - mae: 0.1989 - val_loss: 0.0688 - val_mse: 0.0688 - val_mae: 0.1999
# Epoch 99/120
# 85946/85946 [==============================] - 11s 131us/sample - loss: 0.0683 - mse: 0.0683 - mae: 0.1992 - val_loss: 0.0705 - val_mse: 0.0705 - val_mae: 0.2026
# Epoch 100/120
# 85946/85946 [==============================] - 11s 131us/sample - loss: 0.0684 - mse: 0.0684 - mae: 0.1989 - val_loss: 0.0671 - val_mse: 0.0671 - val_mae: 0.1983
# Epoch 101/120
# 85946/85946 [==============================] - 11s 129us/sample - loss: 0.0684 - mse: 0.0684 - mae: 0.1991 - val_loss: 0.0677 - val_mse: 0.0677 - val_mae: 0.1973
# Epoch 102/120
# 85946/85946 [==============================] - 11s 129us/sample - loss: 0.0681 - mse: 0.0681 - mae: 0.1986 - val_loss: 0.0669 - val_mse: 0.0669 - val_mae: 0.1961
# Epoch 103/120
# 85946/85946 [==============================] - 11s 132us/sample - loss: 0.0680 - mse: 0.0680 - mae: 0.1984 - val_loss: 0.0666 - val_mse: 0.0666 - val_mae: 0.1955
# Epoch 104/120
# 85946/85946 [==============================] - 11s 131us/sample - loss: 0.0681 - mse: 0.0681 - mae: 0.1986 - val_loss: 0.0656 - val_mse: 0.0656 - val_mae: 0.1961
# Epoch 105/120
# 85946/85946 [==============================] - 11s 132us/sample - loss: 0.0681 - mse: 0.0681 - mae: 0.1987 - val_loss: 0.0688 - val_mse: 0.0688 - val_mae: 0.2018
# Epoch 106/120
# 85946/85946 [==============================] - 11s 133us/sample - loss: 0.0680 - mse: 0.0680 - mae: 0.1985 - val_loss: 0.0671 - val_mse: 0.0671 - val_mae: 0.1963
# Epoch 107/120
# 85946/85946 [==============================] - 12s 135us/sample - loss: 0.0680 - mse: 0.0680 - mae: 0.1984 - val_loss: 0.0687 - val_mse: 0.0687 - val_mae: 0.1985
# Epoch 108/120
# 85946/85946 [==============================] - 12s 134us/sample - loss: 0.0678 - mse: 0.0678 - mae: 0.1981 - val_loss: 0.0702 - val_mse: 0.0702 - val_mae: 0.2003
# Epoch 109/120
# 85946/85946 [==============================] - 11s 133us/sample - loss: 0.0679 - mse: 0.0679 - mae: 0.1981 - val_loss: 0.0663 - val_mse: 0.0663 - val_mae: 0.1962
# Epoch 110/120
# 85946/85946 [==============================] - 12s 138us/sample - loss: 0.0678 - mse: 0.0678 - mae: 0.1982 - val_loss: 0.0664 - val_mse: 0.0664 - val_mae: 0.1955
# Epoch 111/120
# 85946/85946 [==============================] - 12s 137us/sample - loss: 0.0677 - mse: 0.0677 - mae: 0.1982 - val_loss: 0.0688 - val_mse: 0.0688 - val_mae: 0.1986
# Epoch 112/120
# 85946/85946 [==============================] - 12s 138us/sample - loss: 0.0676 - mse: 0.0676 - mae: 0.1981 - val_loss: 0.0665 - val_mse: 0.0665 - val_mae: 0.1964
# Epoch 113/120
# 85946/85946 [==============================] - 12s 137us/sample - loss: 0.0675 - mse: 0.0675 - mae: 0.1978 - val_loss: 0.0661 - val_mse: 0.0661 - val_mae: 0.1956
# Epoch 114/120
# 85946/85946 [==============================] - 12s 135us/sample - loss: 0.0675 - mse: 0.0675 - mae: 0.1978 - val_loss: 0.0664 - val_mse: 0.0664 - val_mae: 0.1973
# Epoch 115/120
# 85946/85946 [==============================] - 12s 138us/sample - loss: 0.0675 - mse: 0.0675 - mae: 0.1979 - val_loss: 0.0668 - val_mse: 0.0668 - val_mae: 0.1972
# Epoch 116/120
# 85946/85946 [==============================] - 12s 137us/sample - loss: 0.0674 - mse: 0.0674 - mae: 0.1978 - val_loss: 0.0723 - val_mse: 0.0723 - val_mae: 0.2055
# Epoch 117/120
# 85946/85946 [==============================] - 12s 135us/sample - loss: 0.0675 - mse: 0.0675 - mae: 0.1978 - val_loss: 0.0648 - val_mse: 0.0648 - val_mae: 0.1953
# Epoch 118/120
# 85946/85946 [==============================] - 14s 162us/sample - loss: 0.0672 - mse: 0.0672 - mae: 0.1974 - val_loss: 0.0666 - val_mse: 0.0666 - val_mae: 0.1982
# Epoch 119/120
# 85946/85946 [==============================] - 12s 144us/sample - loss: 0.0675 - mse: 0.0675 - mae: 0.1981 - val_loss: 0.0668 - val_mse: 0.0668 - val_mae: 0.1975
# Epoch 120/120
# 85946/85946 [==============================] - 12s 139us/sample - loss: 0.0673 - mse: 0.0673 - mae: 0.1976 - val_loss: 0.0711 - val_mse: 0.0711 - val_mae: 0.2011

# %%
# Runs NN Model for FAPAR

FAPAR_history_no_weights = FAPAR_model_no_weights.fit(x = numpy.array(training_data), y = numpy.array(FAPAR_training),
                                epochs = 20, 
                                validation_data = (numpy.array(valid_data), numpy.array(FAPAR_valid))
                               )
# Out:
# Train on 85946 samples, validate on 36834 samples
# Epoch 1/20
# 85946/85946 [==============================] - 12s 145us/sample - loss: 0.0961 - mse: 0.0961 - mae: 0.2007 - val_loss: 0.0370 - val_mse: 0.0370 - val_mae: 0.1414
# Epoch 2/20
# 85946/85946 [==============================] - 10s 122us/sample - loss: 0.0300 - mse: 0.0300 - mae: 0.1272 - val_loss: 0.0264 - val_mse: 0.0264 - val_mae: 0.1184
# Epoch 3/20
# 85946/85946 [==============================] - 10s 121us/sample - loss: 0.0234 - mse: 0.0234 - mae: 0.1113 - val_loss: 0.0212 - val_mse: 0.0212 - val_mae: 0.1060
# Epoch 4/20
# 85946/85946 [==============================] - 10s 122us/sample - loss: 0.0206 - mse: 0.0206 - mae: 0.1039 - val_loss: 0.0210 - val_mse: 0.0210 - val_mae: 0.1037
# Epoch 5/20
# 85946/85946 [==============================] - 11s 123us/sample - loss: 0.0189 - mse: 0.0189 - mae: 0.0992 - val_loss: 0.0178 - val_mse: 0.0178 - val_mae: 0.097489 - mae: 0.0
# Epoch 6/20
# 85946/85946 [==============================] - 11s 123us/sample - loss: 0.0178 - mse: 0.0178 - mae: 0.0958 - val_loss: 0.0169 - val_mse: 0.0169 - val_mae: 0.0928
# Epoch 7/20
# 85946/85946 [==============================] - 11s 125us/sample - loss: 0.0170 - mse: 0.0170 - mae: 0.0932 - val_loss: 0.0163 - val_mse: 0.0163 - val_mae: 0.0914
# Epoch 8/20
# 85946/85946 [==============================] - 10s 121us/sample - loss: 0.0166 - mse: 0.0166 - mae: 0.0919 - val_loss: 0.0164 - val_mse: 0.0164 - val_mae: 0.0908
# Epoch 9/20
# 85946/85946 [==============================] - 10s 121us/sample - loss: 0.0163 - mse: 0.0163 - mae: 0.0908 - val_loss: 0.0164 - val_mse: 0.0164 - val_mae: 0.0896
# Epoch 10/20
# 85946/85946 [==============================] - 11s 125us/sample - loss: 0.0160 - mse: 0.0160 - mae: 0.0899 - val_loss: 0.0156 - val_mse: 0.0156 - val_mae: 0.0881
# Epoch 11/20
# 85946/85946 [==============================] - 11s 123us/sample - loss: 0.0158 - mse: 0.0158 - mae: 0.0892 - val_loss: 0.0152 - val_mse: 0.0152 - val_mae: 0.0877
# Epoch 12/20
# 85946/85946 [==============================] - 11s 132us/sample - loss: 0.0156 - mse: 0.0156 - mae: 0.0887 - val_loss: 0.0159 - val_mse: 0.0159 - val_mae: 0.0900
# Epoch 13/20
# 85946/85946 [==============================] - 11s 123us/sample - loss: 0.0155 - mse: 0.0155 - mae: 0.0882 - val_loss: 0.0149 - val_mse: 0.0149 - val_mae: 0.0861
# Epoch 14/20
# 85946/85946 [==============================] - 11s 125us/sample - loss: 0.0153 - mse: 0.0153 - mae: 0.0880 - val_loss: 0.0149 - val_mse: 0.0149 - val_mae: 0.0881
# Epoch 15/20
# 85946/85946 [==============================] - 11s 124us/sample - loss: 0.0152 - mse: 0.0152 - mae: 0.0874 - val_loss: 0.0146 - val_mse: 0.0146 - val_mae: 0.0850
# Epoch 16/20
# 85946/85946 [==============================] - 11s 123us/sample - loss: 0.0151 - mse: 0.0151 - mae: 0.0875 - val_loss: 0.0144 - val_mse: 0.0144 - val_mae: 0.0846
# Epoch 17/20
# 85946/85946 [==============================] - 11s 126us/sample - loss: 0.0150 - mse: 0.0150 - mae: 0.0869 - val_loss: 0.0151 - val_mse: 0.0151 - val_mae: 0.0861
# Epoch 18/20
# 85946/85946 [==============================] - 11s 127us/sample - loss: 0.0149 - mse: 0.0149 - mae: 0.0866 - val_loss: 0.0149 - val_mse: 0.0149 - val_mae: 0.0854
# Epoch 19/20
# 85946/85946 [==============================] - 11s 126us/sample - loss: 0.0148 - mse: 0.0148 - mae: 0.0863 - val_loss: 0.0152 - val_mse: 0.0152 - val_mae: 0.0861
# Epoch 20/20
# 85946/85946 [==============================] - 11s 125us/sample - loss: 0.0147 - mse: 0.0147 - mae: 0.0859 - val_loss: 0.0143 - val_mse: 0.0143 - val_mae: 0.0847

# %%
# Runs NN Model for FCOVER

FCOVER_history_no_weights = FCOVER_model_no_weights.fit(x = numpy.array(training_data), y = numpy.array(FCOVER_training),
                                  epochs = 20, 
                                  validation_data = (numpy.array(valid_data), numpy.array(FCOVER_valid))
                                 )
# Out:
# Train on 85946 samples, validate on 36834 samples
# Epoch 1/20
# 85946/85946 [==============================] - 12s 144us/sample - loss: 0.0933 - mse: 0.0933 - mae: 0.1852 - val_loss: 0.0270 - val_mse: 0.0270 - val_mae: 0.1214
# Epoch 2/20
# 85946/85946 [==============================] - 10s 121us/sample - loss: 0.0224 - mse: 0.0224 - mae: 0.1104 - val_loss: 0.0197 - val_mse: 0.0197 - val_mae: 0.1025
# Epoch 3/20
# 85946/85946 [==============================] - 11s 123us/sample - loss: 0.0176 - mse: 0.0176 - mae: 0.0972 - val_loss: 0.0157 - val_mse: 0.0157 - val_mae: 0.0896
# Epoch 4/20
# 85946/85946 [==============================] - 10s 121us/sample - loss: 0.0152 - mse: 0.0152 - mae: 0.0878 - val_loss: 0.0142 - val_mse: 0.0142 - val_mae: 0.0841
# Epoch 5/20
# 85946/85946 [==============================] - 10s 122us/sample - loss: 0.0143 - mse: 0.0143 - mae: 0.0844 - val_loss: 0.0138 - val_mse: 0.0138 - val_mae: 0.0832
# Epoch 6/20
# 85946/85946 [==============================] - 11s 122us/sample - loss: 0.0137 - mse: 0.0137 - mae: 0.0823 - val_loss: 0.0129 - val_mse: 0.0129 - val_mae: 0.0797
# Epoch 7/20
# 85946/85946 [==============================] - 10s 122us/sample - loss: 0.0132 - mse: 0.0132 - mae: 0.0810 - val_loss: 0.0128 - val_mse: 0.0128 - val_mae: 0.0786
# Epoch 8/20
# 85946/85946 [==============================] - 11s 124us/sample - loss: 0.0130 - mse: 0.0130 - mae: 0.0802 - val_loss: 0.0132 - val_mse: 0.0132 - val_mae: 0.0806
# Epoch 9/20
# 85946/85946 [==============================] - 11s 129us/sample - loss: 0.0128 - mse: 0.0128 - mae: 0.0795 - val_loss: 0.0122 - val_mse: 0.0122 - val_mae: 0.0771
# Epoch 10/20
# 85946/85946 [==============================] - 11s 128us/sample - loss: 0.0126 - mse: 0.0126 - mae: 0.0789 - val_loss: 0.0120 - val_mse: 0.0120 - val_mae: 0.0766
# Epoch 11/20
# 85946/85946 [==============================] - 12s 135us/sample - loss: 0.0124 - mse: 0.0124 - mae: 0.0782 - val_loss: 0.0122 - val_mse: 0.0122 - val_mae: 0.0778
# Epoch 12/20
# 85946/85946 [==============================] - 11s 124us/sample - loss: 0.0123 - mse: 0.0123 - mae: 0.0779 - val_loss: 0.0120 - val_mse: 0.0120 - val_mae: 0.0772
# Epoch 13/20
# 85946/85946 [==============================] - 11s 126us/sample - loss: 0.0122 - mse: 0.0122 - mae: 0.0774 - val_loss: 0.0119 - val_mse: 0.0119 - val_mae: 0.0764
# Epoch 14/20
# 85946/85946 [==============================] - 12s 139us/sample - loss: 0.0120 - mse: 0.0120 - mae: 0.0772 - val_loss: 0.0120 - val_mse: 0.0120 - val_mae: 0.0767
# Epoch 15/20
# 85946/85946 [==============================] - 10s 115us/sample - loss: 0.0119 - mse: 0.0119 - mae: 0.0768 - val_loss: 0.0115 - val_mse: 0.0115 - val_mae: 0.0759
# Epoch 16/20
# 85946/85946 [==============================] - 10s 121us/sample - loss: 0.0118 - mse: 0.0118 - mae: 0.0764 - val_loss: 0.0115 - val_mse: 0.0115 - val_mae: 0.0776
# Epoch 17/20
# 85946/85946 [==============================] - 11s 133us/sample - loss: 0.0117 - mse: 0.0117 - mae: 0.0761 - val_loss: 0.0111 - val_mse: 0.0111 - val_mae: 0.0741
# Epoch 18/20
# 85946/85946 [==============================] - 11s 126us/sample - loss: 0.0116 - mse: 0.0116 - mae: 0.0757 - val_loss: 0.0110 - val_mse: 0.0110 - val_mae: 0.0742
# Epoch 19/20
# 85946/85946 [==============================] - 11s 125us/sample - loss: 0.0114 - mse: 0.0114 - mae: 0.0753 - val_loss: 0.0110 - val_mse: 0.0110 - val_mae: 0.0743
# Epoch 20/20
# 85946/85946 [==============================] - 11s 125us/sample - loss: 0.0114 - mse: 0.0114 - mae: 0.0751 - val_loss: 0.0109 - val_mse: 0.0109 - val_mae: 0.0738

# %%
# Makes predictions on the validation data

LAI_predictions_no_weights = pandas.Series(LAI_model_no_weights.predict(numpy.array(valid_data)).flatten())
FAPAR_predictions_no_weights = pandas.Series(FAPAR_model_no_weights.predict(numpy.array(valid_data)).flatten())
FCOVER_predictions_no_weights = pandas.Series(FCOVER_model_no_weights.predict(numpy.array(valid_data)).flatten())

# %%
fig, (ax9, ax10, ax11) = plt.subplots(1,3,figsize=(25,15))

plotting_function('LAI', LAI_valid, LAI_predictions_no_weights, 'LAI','Input LAI','Predicted LAI','NNet',ax9)
plotting_function('FAPAR', FAPAR_valid, FAPAR_predictions_no_weights, 'FAPAR','Input FAPAR','Predicted FAPAR','NNet',ax10)
plotting_function('FCOVER', FCOVER_valid, FCOVER_predictions_no_weights, 'FCOVER','Input FCOVER','Predicted FCOVER','NNet',ax11)

fig.suptitle('Reference LAI Greater than Four - Neural Network - without weights', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Reference LAI Greater than Four - Neural Network - without weights')

# %%
fig, (ax12) = plt.subplots(1,1,figsize=(25,15))

lai_greater_four('LAI',LAI_valid, LAI_predictions_no_weights, 'LAI','Input LAI','Predicted LAI','NNet', ax12)

fig.suptitle('Reference LAI Greater than Four - Only LAI Values Greater than Four - NNet - without weights', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Reference LAI Greater than Four - Only LAI Values Greater than Four - NNet - without weights')

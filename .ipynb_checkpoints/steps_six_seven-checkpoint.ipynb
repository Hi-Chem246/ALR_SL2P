# %%
# Import the necessary packages and libraries #
import scipy
import scipy.io as sio
import matplotlib.pyplot as plt
import numpy
import numpy.matlib
import pandas 
import sklearn
from sklearn import preprocessing
from sklearn import linear_model
import tensorflow
from tensorflow import keras 
import os
from sklearn.neighbors import DistanceMetric

# %%
# Sets the precision of the data in the Pandas Dataframes 

pandas.set_option("precision", 10)

# %%
# Removes any Tensorflow warnings 

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
# Import the MatLab data #

matlabData = sio.loadmat(file_name='./data/s2_sl2p_uniform_10_replicates_sobol_prosail_inout.mat', variable_names=['Input', 'Output'])

# %%
# Extract the input and output data #

bands = pandas.DataFrame(data=matlabData['Input']['Rho_Toc'][0][0])
angles = pandas.DataFrame(data=matlabData['Input']['Angles'][0][0])
LAI = pandas.Series(data=matlabData['Output']['LAI'][0][0].flatten())
FAPAR = pandas.Series(data=matlabData['Output']['FAPAR'][0][0].flatten())
FCOVER = pandas.Series(data=matlabData['Output']['FCOVER'][0][0].flatten())

# %%
# Standardize the calibration data #

cal_data = pandas.concat([bands, angles, LAI, FAPAR, FCOVER], axis=1, join='outer')

cal_data.columns = ['B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'A1', 'A2', 'A3', 'LAI', 'FAPAR', 'FCOVER']

cal_data
# Out:
#                   B0            B1            B2            B3            B4  \
# 0       0.1312746755  0.0743505601  0.1729546392  0.2952160738  0.3209243927
# 1       0.1019407701  0.0868185076  0.1599851769  0.3680334831  0.4389734403
# 2       0.0577228876  0.0543735427  0.0726863963  0.1146353863  0.1262129829
# 3       0.0608335819  0.0423475494  0.0917885392  0.1738484853  0.1980468499
# 4       0.0789422177  0.1359804109  0.1677317262  0.2554469658  0.2962514793
# ...              ...           ...           ...           ...           ...
# 122875  0.0642385315  0.0276301255  0.0866383370  0.3106952678  0.4255780128
# 122876  0.0913131658  0.0504649365  0.1222839075  0.3081750760  0.4047671458
# 122877  0.0621419307  0.0380236717  0.0921177459  0.2614424931  0.3577263614
# 122878  0.0514800307  0.0288523379  0.0690024543  0.4158467721  0.6343113015
# 122879  0.0668233773  0.0250243879  0.0907567987  0.4369922465  0.6772450624
#
#                   B5            B6            B7            A1            A2  \
# 0       0.3303722287  0.1873586099  0.1113007554  0.9638065534  0.5275411500
# 1       0.4759755142  0.3043390179  0.1996883219  0.9995852344  0.5284670738
# 2       0.1300015294  0.1048168652  0.0853760008  0.9807097061  0.6843199822
# 3       0.2153382831  0.1396374825  0.0906137034  0.9865515976  0.7869673865
# 4       0.3108466204  0.3167107908  0.2088934617  0.9999190888  0.8237423248
# ...              ...           ...           ...           ...           ...
# 122875  0.4466691326  0.1173674161  0.0414608341  0.9641458993  0.8501574022
# 122876  0.4293059492  0.1725548796  0.1005631041  0.9616583754  0.8710934328
# 122877  0.3626203975  0.1294881968  0.0624406803  0.9757927762  0.8637999983
# 122878  0.6354447032  0.1810943898  0.0474550174  0.9606931097  0.8268533675
# 122879  0.6972009957  0.2347272437  0.0863371443  0.9591264867  0.8382274319
#
#                   A3  LAI         FAPAR        FCOVER
# 0      -0.5752876765    1  0.4391203617  0.4803244610
# 1      -0.4777431279    1  0.5296906764  0.5338211214
# 2       0.6909005295    1  0.2406051357  0.2324486617
# 3       0.8590635747    1  0.3515168619  0.3732491055
# 4      -0.9085753290    1  0.2890892994  0.2565897729
# ...              ...  ...           ...           ...
# 122875 -0.9266152189   10  0.9454688738  0.9530549586
# 122876  0.9265827175   10  0.8085248415  0.8034524935
# 122877 -0.9813994186   10  0.8185069725  0.8122050332
# 122878 -0.8694016324   10  0.9810850825  0.9992241257
# 122879  0.9967558231   10  0.9762029807  0.9928982883
#
# [122880 rows x 14 columns]

# %%
# Standardize the calibration data #

cal_data_scaled = pandas.DataFrame(sklearn.preprocessing.StandardScaler().fit_transform(cal_data))

cal_data_scaled.columns = ['B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'A1', 'A2', 'A3', 'LAI', 'FAPAR', 'FCOVER']

cal_data_scaled
# Out:
#                   B0            B1            B2            B3            B4  \
# 0       1.1600887942  1.1894959571  1.1005309674 -0.7574953553 -1.2136760897
# 1       0.3768666595  1.6844505369  0.8279254564 -0.1275628723 -0.4502226101
# 2      -0.8037611472  0.3964451147 -1.0070101806 -2.3196717910 -2.4729247349
# 3      -0.7207048794 -0.0809646948 -0.6055016769 -1.8074281556 -2.0083566857
# 4      -0.2372000684  3.6360876602  0.9907504054 -1.1015319421 -1.3732421509
# ...              ...           ...           ...           ...           ...
# 122875 -0.6297919312 -0.6652193518 -0.7137539294 -0.6235871705 -0.5368542767
# 122876  0.0931071377  0.2412806393  0.0354813671 -0.6453889716 -0.6714434932
# 122877 -0.6857716627 -0.2526146846 -0.5985820716 -1.0496655348 -0.9756683152
# 122878 -0.9704468859 -0.6166997679 -1.0844430668  0.2860627172  0.8130774569
# 122879 -0.5607759421 -0.7686623410 -0.6271878617  0.4689890443  1.0907411044
#
#                   B5            B6            B7            A1            A2  \
# 0      -1.2551477212 -0.5123998591  0.0482701907 -1.5351947333 -1.2590753240
# 1      -0.3312429285  0.9573384489  1.5671047307  1.3154921199 -1.2529678973
# 2      -2.5265712936 -1.5494518415 -0.3972156885 -0.1884263875 -0.2249564670
# 3      -1.9850791466 -1.1119666599 -0.3072120391  0.2770296632  0.4521095310
# 4      -1.3790446724  1.1127770292  1.7252840412  1.3420921626  0.6946783564
# ...              ...           ...           ...           ...           ...
# 122875 -0.5172023756 -1.3917671005 -1.1518452670 -1.5081571622  0.8689131637
# 122876 -0.6273779690 -0.6983934776 -0.1362434958 -1.7063520463  1.0070079804
# 122877 -1.0505215854 -1.2394819780 -0.7913317214 -0.5801855863  0.9589002217
# 122878  0.6806459689 -0.5911033299 -1.0488424022 -1.7832601421  0.7151989067
# 122879  1.0725116772  0.0827382237 -0.3806995885 -1.9080817293  0.7902226473
#
#                   A3           LAI         FAPAR        FCOVER
# 0      -0.7795178075 -1.5666989036 -1.8949148320 -1.6291084301
# 1      -0.6517039023 -1.5666989036 -1.4265332698 -1.3709908078
# 2       0.8795852552 -1.5666989036 -2.9215301414 -2.8250917213
# 3       1.0999315055 -1.5666989036 -2.3479536034 -2.1457394865
# 4      -1.2162290029 -1.5666989036 -2.6707957989 -2.7086125584
# ...              ...           ...           ...           ...
# 122875 -1.2398669079  1.5666989036  0.7236507314  0.6517829598
# 122876  1.1884027264  1.5666989036  0.0154489326 -0.0700384081
# 122877 -1.3116513655  1.5666989036  0.0670712121 -0.0278080201
# 122878 -1.1648991929  1.5666989036  0.9078388454  0.8745459430
# 122879  1.2803514698  1.5666989036  0.8825912079  0.8440242224
#
# [122880 rows x 14 columns]

# %%
# Create subset id's #

rep = 10

subsets = numpy.arange(0, int(cal_data_scaled.shape[0]/10))

subset_ids = numpy.matlib.repmat(subsets, 1, rep)

cal_data_scaled['subset_id'] = subset_ids[0]

cal_data_scaled.columns = ['B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'A1', 'A2', 'A3', 'LAI', 'FAPAR', 'FCOVER', 'subset_id']

cal_data_scaled
# Out:
#                   B0            B1            B2            B3            B4  \
# 0       1.1600887942  1.1894959571  1.1005309674 -0.7574953553 -1.2136760897
# 1       0.3768666595  1.6844505369  0.8279254564 -0.1275628723 -0.4502226101
# 2      -0.8037611472  0.3964451147 -1.0070101806 -2.3196717910 -2.4729247349
# 3      -0.7207048794 -0.0809646948 -0.6055016769 -1.8074281556 -2.0083566857
# 4      -0.2372000684  3.6360876602  0.9907504054 -1.1015319421 -1.3732421509
# ...              ...           ...           ...           ...           ...
# 122875 -0.6297919312 -0.6652193518 -0.7137539294 -0.6235871705 -0.5368542767
# 122876  0.0931071377  0.2412806393  0.0354813671 -0.6453889716 -0.6714434932
# 122877 -0.6857716627 -0.2526146846 -0.5985820716 -1.0496655348 -0.9756683152
# 122878 -0.9704468859 -0.6166997679 -1.0844430668  0.2860627172  0.8130774569
# 122879 -0.5607759421 -0.7686623410 -0.6271878617  0.4689890443  1.0907411044
#
#                   B5            B6            B7            A1            A2  \
# 0      -1.2551477212 -0.5123998591  0.0482701907 -1.5351947333 -1.2590753240
# 1      -0.3312429285  0.9573384489  1.5671047307  1.3154921199 -1.2529678973
# 2      -2.5265712936 -1.5494518415 -0.3972156885 -0.1884263875 -0.2249564670
# 3      -1.9850791466 -1.1119666599 -0.3072120391  0.2770296632  0.4521095310
# 4      -1.3790446724  1.1127770292  1.7252840412  1.3420921626  0.6946783564
# ...              ...           ...           ...           ...           ...
# 122875 -0.5172023756 -1.3917671005 -1.1518452670 -1.5081571622  0.8689131637
# 122876 -0.6273779690 -0.6983934776 -0.1362434958 -1.7063520463  1.0070079804
# 122877 -1.0505215854 -1.2394819780 -0.7913317214 -0.5801855863  0.9589002217
# 122878  0.6806459689 -0.5911033299 -1.0488424022 -1.7832601421  0.7151989067
# 122879  1.0725116772  0.0827382237 -0.3806995885 -1.9080817293  0.7902226473
#
#                   A3           LAI         FAPAR        FCOVER  subset_id
# 0      -0.7795178075 -1.5666989036 -1.8949148320 -1.6291084301          0
# 1      -0.6517039023 -1.5666989036 -1.4265332698 -1.3709908078          1
# 2       0.8795852552 -1.5666989036 -2.9215301414 -2.8250917213          2
# 3       1.0999315055 -1.5666989036 -2.3479536034 -2.1457394865          3
# 4      -1.2162290029 -1.5666989036 -2.6707957989 -2.7086125584          4
# ...              ...           ...           ...           ...        ...
# 122875 -1.2398669079  1.5666989036  0.7236507314  0.6517829598      12283
# 122876  1.1884027264  1.5666989036  0.0154489326 -0.0700384081      12284
# 122877 -1.3116513655  1.5666989036  0.0670712121 -0.0278080201      12285
# 122878 -1.1648991929  1.5666989036  0.9078388454  0.8745459430      12286
# 122879  1.2803514698  1.5666989036  0.8825912079  0.8440242224      12287
#
# [122880 rows x 15 columns]

# %%
# Sample data to create reference database # 

ref_data = cal_data_scaled.sample(n=100, ignore_index=False)

ref_data
# Out:
#                   B0            B1            B2            B3            B4  \
# 8126   -1.5493352875 -0.5157831907 -1.5669321728 -2.5512465236 -2.6300888292
# 96007  -0.8362572957 -0.6311319354 -0.9106515980  0.5360519084  1.2349135498
# 110747 -0.8994707681 -0.8951517057 -0.9340294981 -0.4845907350 -0.1771940557
# 78057   0.3730927249 -0.4318424229  0.3652361401  1.1383311584  1.1233465229
# 1352    0.0148455856  2.1182264842  0.8616509804 -0.6497992090 -1.0303042331
# ...              ...           ...           ...           ...           ...
# 2680    1.0909455813  3.6407642229  0.8999063197 -0.5222916001 -0.7170755211
# 24795  -0.7228265857 -0.6039509057 -0.6938511809 -0.4757874229 -0.5698767671
# 92309  -0.5555447967 -0.6985512489 -0.5932738987  0.5565909014  1.0193198870
# 29013   0.7326341245 -0.0287592085  0.8090844582  0.1685825826 -0.2013694298
# 68505  -0.1996006069 -0.5175537508 -0.1915346390  0.7381173677  0.8076443940
#
#                   B5            B6            B7            A1            A2  \
# 8126   -2.6862423523 -1.6109186800 -0.4910382759 -0.7447657013 -0.3965958638
# 96007   1.1819644358  0.6280923231 -0.0808625471  0.3454540233 -1.1041440438
# 110747 -0.0603323786 -0.6486309506 -0.8071232372  0.5183858322 -1.7450981533
# 78057   1.1080588880  0.2554484826 -0.4251715946  0.7776170613  0.4370320976
# 1352   -1.0708078759  0.3488269743  0.6455036789 -1.7282831413  0.0184781114
# ...              ...           ...           ...           ...           ...
# 2680   -0.6996505281  1.3598789271  2.4624756640  1.3193522070  1.2723174547
# 24795  -0.5429912992 -0.6165967790 -0.7399113207 -2.0423027569  1.1299382129
# 92309   1.0523067311  0.3500767633 -0.2444354146 -0.8961255658  0.9990591766
# 29013  -0.2015153302  0.5526338228  0.3937251297  0.1318112315 -0.5065299368
# 68505   0.8632107631 -0.1553035131 -0.7555336332  0.5945456531  0.8612055316
#
#                   A3           LAI         FAPAR        FCOVER  subset_id
# 8126    0.8008938897 -1.5666989036 -3.0442004694 -2.9051379656       8126
# 96007   0.7876484735  0.8703882798  0.8571721929  0.8278409048       9991
# 110747 -0.6393869079  1.5666989036  0.8043571407  0.7497533189        155
# 78057  -1.0947445407  0.5222329679  0.8056929406  0.8152299134       4329
# 1352    0.9945452695 -1.5666989036 -1.9479495120 -1.8432687330       1352
# ...              ...           ...           ...           ...        ...
# 2680   -1.2926144959 -1.5666989036 -1.6477780535 -1.7971837002       2680
# 24795  -1.2205507753 -0.8703882798 -0.0717961499 -0.0195428785        219
# 92309  -1.3329239976  0.8703882798  0.8317618169  0.8060425132       6293
# 29013  -0.7910099560 -0.8703882798 -0.3756111839 -0.2422375179       4437
# 68505   1.2807914273  0.1740776560  0.8380451312  0.8323908867       7065
#
# [100 rows x 15 columns]

# %%
# List of indices to remove from the calibration database #

index_list = ref_data.index.values

# %%
# Resets the indices in the reference data so that they start from zero

ref_data = ref_data.reset_index(drop=True)

# %%
# Removes the indices from calibration database that are in the reference database #

cal_data_scaled = cal_data_scaled.drop(index_list)

# %%
# Resets the indices in the calibration data so that they start from zero

cal_data_scaled = cal_data_scaled.reset_index(drop=True)

# %%
# Creates the training and validation sets from the calibration data

features_training, features_valid = sklearn.model_selection.train_test_split(cal_data_scaled, test_size=0.3, train_size=0.7, random_state=None, shuffle=True, stratify=None)

# %%
# Resets the indices in the training data so that they start from zero

features_training = features_training.reset_index(drop=True)

# %%
# Resets the indices in the validation data so that they start from zero

features_valid = features_valid.reset_index(drop=True)

# %%
# Extracts the LAI, FAPAR, and FCOVER data to be used for training

LAI_feature_training = features_training['LAI']
FAPAR_feature_training = features_training['FAPAR']
FCOVER_feature_training = features_training['FCOVER']

# %%
# Extracts the LAI, FAPAR, and FCOVER data to be used for validation

LAI_feature_valid = features_valid['LAI']
FAPAR_feature_valid = features_valid['FAPAR']
FCOVER_feature_valid = features_valid['FCOVER']

# %%
# Removes that isn't needed for training and validation 
# call them features training and features validation
features_training.drop(['LAI', 'FAPAR', 'FCOVER','subset_id'], axis=1)
features_valid.drop(['LAI', 'FAPAR', 'FCOVER','subset_id'], axis=1)
# Out:
#                  B0            B1            B2            B3            B4  \
# 0      0.7372758459 -0.3696455985  0.7911589763  1.5086365604  1.4635775114
# 1      0.1065702486  1.3091990078 -0.0254286012 -0.6442771921 -0.6787085445
# 2     -0.8682048016 -0.3012604786 -0.8997336051  0.0624510723  0.3141825506
# 3     -0.8001993852 -0.7115991042 -0.8236378548  0.3643352469  1.0981995742
# 4     -0.1057482588 -0.4611967832 -0.0650456432  0.1195493623 -0.2014446603
# ...             ...           ...           ...           ...           ...
# 36829 -0.5869656377 -0.6343561965 -0.6434429312  0.8249700583  1.3673238028
# 36830  0.5265362983 -0.1405472405  0.4538068608  1.0544901049  0.9425112897
# 36831 -1.0023023582 -0.2391899795 -0.9251483646 -1.2677250372 -1.3831927602
# 36832 -0.6182544905  0.0725751421 -0.5034303553 -1.2052925964 -1.2193130078
# 36833  0.9661359858  3.5145828422  2.2498556519  0.1057817255 -0.4145774680
#
#                  B5            B6            B7            A1            A2  \
# 0      1.5952639413  2.8810251171  2.1688041291 -1.0717750229  1.1069007808
# 1     -0.6562595642  0.4242269144  0.9449858491  1.1642048609 -0.0769671474
# 2      0.2340387249  0.1948784877 -0.1803850576  0.0129942203 -1.3511114683
# 3      1.3207901566  1.5500254661  0.9192847680  0.8855518526  0.0053685919
# 4     -0.2790322256  0.4438029725  0.0815338162  0.5715716520 -0.0892174743
# ...             ...           ...           ...           ...           ...
# 36829  1.2424084836 -0.0461717998 -0.6051150890 -0.4241043455  0.9963254062
# 36830  0.8552036144  0.1733250551 -0.1089868469 -0.9309758756  0.8108835041
# 36831 -1.3613568193 -0.3565919558 -0.0572957622  0.2764714920  0.9015626722
# 36832 -1.1546725368 -0.6142741584  0.1161332850 -0.9026924780  1.0114105110
# 36833 -0.4328139271  2.0709300159  2.0843317359  0.1129529673 -0.0028681810
#
#                  A3
# 0     -1.2336538653
# 1     -0.8523082182
# 2     -0.6502960516
# 3     -0.9813488118
# 4     -0.9563346412
# ...             ...
# 36829  1.1524259165
# 36830  1.2815699683
# 36831 -0.9845084492
# 36832 -1.3359726865
# 36833  0.7436419407
#
# [36834 rows x 11 columns]

# %%
# Creates a model for LAI, FAPAR, and FCOVER using LARs regression 

LAI_feature_model = sklearn.linear_model.Lars(n_nonzero_coefs=4)
LAI_feature_model = LAI_feature_model.fit(features_training, LAI_feature_training)

FAPAR_feature_model = sklearn.linear_model.Lars(n_nonzero_coefs=4)
FAPAR_feature_model = FAPAR_feature_model.fit(features_training, FAPAR_feature_training)

FCOVER_feature_model = sklearn.linear_model.Lars(n_nonzero_coefs=4)
FCOVER_feature_model = FCOVER_feature_model.fit(features_training, FCOVER_feature_training)

# %%
# Makes predictions on the validation data using the LARS models

LAI_feature_predicted = pandas.Series(LAI_feature_model.predict(features_valid))
FAPAR_feature_predicted = pandas.Series(FAPAR_feature_model.predict(features_valid))
FCOVER_feature_predicted = pandas.Series(FCOVER_feature_model.predict(features_valid))

# %%
# Extracts the features from the LARS Model

LAI_features = numpy.nonzero(LAI_feature_model.coef_)[0]
FAPAR_features = numpy.nonzero(FAPAR_feature_model.coef_)[0]
FCOVER_features = numpy.nonzero(FCOVER_feature_model.coef_)[0]

LAI_features = features_valid.columns[LAI_features]
FAPAR_features = features_valid.columns[FAPAR_features]
FCOVER_features = features_valid.columns[FCOVER_features]

# %%
# Creates arrays containing the calibration and reference data 

ref_array = numpy.array(ref_data[LAI_features])

cal_array = numpy.array(cal_data_scaled[LAI_features])

# %%
# Calls function from sci-kit learn for calculating the euclidean distance 

dist = DistanceMetric.get_metric('euclidean')

# %%
# Calculates the probability for each sample in the calibration data

probs = numpy.exp(-numpy.amin(dist.pairwise(cal_array,ref_array),1))

# %%
# Initialize the probability column in the calibration database #

cal_data_scaled['prob'] = probs 

cal_data_scaled.columns = ['B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'A1', 'A2', 'A3', 'LAI', 'FAPAR', 'FCOVER', 'subset_id', 'prob']

# %%
# Function to normalize the probabilities 

def normalize(data):
    norm_prob = numpy.array(data['prob'])/sum(data['prob'])
    data['prob'] = norm_prob 
    return data

# %%
normalize(cal_data_scaled)
# Out:
#                   B0            B1            B2            B3            B4  \
# 0       1.1600887942  1.1894959571  1.1005309674 -0.7574953553 -1.2136760897
# 1       0.3768666595  1.6844505369  0.8279254564 -0.1275628723 -0.4502226101
# 2      -0.8037611472  0.3964451147 -1.0070101806 -2.3196717910 -2.4729247349
# 3      -0.7207048794 -0.0809646948 -0.6055016769 -1.8074281556 -2.0083566857
# 4      -0.2372000684  3.6360876602  0.9907504054 -1.1015319421 -1.3732421509
# ...              ...           ...           ...           ...           ...
# 122775 -0.6297919312 -0.6652193518 -0.7137539294 -0.6235871705 -0.5368542767
# 122776  0.0931071377  0.2412806393  0.0354813671 -0.6453889716 -0.6714434932
# 122777 -0.6857716627 -0.2526146846 -0.5985820716 -1.0496655348 -0.9756683152
# 122778 -0.9704468859 -0.6166997679 -1.0844430668  0.2860627172  0.8130774569
# 122779 -0.5607759421 -0.7686623410 -0.6271878617  0.4689890443  1.0907411044
#
#                   B5            B6            B7            A1            A2  \
# 0      -1.2551477212 -0.5123998591  0.0482701907 -1.5351947333 -1.2590753240
# 1      -0.3312429285  0.9573384489  1.5671047307  1.3154921199 -1.2529678973
# 2      -2.5265712936 -1.5494518415 -0.3972156885 -0.1884263875 -0.2249564670
# 3      -1.9850791466 -1.1119666599 -0.3072120391  0.2770296632  0.4521095310
# 4      -1.3790446724  1.1127770292  1.7252840412  1.3420921626  0.6946783564
# ...              ...           ...           ...           ...           ...
# 122775 -0.5172023756 -1.3917671005 -1.1518452670 -1.5081571622  0.8689131637
# 122776 -0.6273779690 -0.6983934776 -0.1362434958 -1.7063520463  1.0070079804
# 122777 -1.0505215854 -1.2394819780 -0.7913317214 -0.5801855863  0.9589002217
# 122778  0.6806459689 -0.5911033299 -1.0488424022 -1.7832601421  0.7151989067
# 122779  1.0725116772  0.0827382237 -0.3806995885 -1.9080817293  0.7902226473
#
#                   A3           LAI         FAPAR        FCOVER  subset_id  \
# 0      -0.7795178075 -1.5666989036 -1.8949148320 -1.6291084301          0
# 1      -0.6517039023 -1.5666989036 -1.4265332698 -1.3709908078          1
# 2       0.8795852552 -1.5666989036 -2.9215301414 -2.8250917213          2
# 3       1.0999315055 -1.5666989036 -2.3479536034 -2.1457394865          3
# 4      -1.2162290029 -1.5666989036 -2.6707957989 -2.7086125584          4
# ...              ...           ...           ...           ...        ...
# 122775 -1.2398669079  1.5666989036  0.7236507314  0.6517829598      12283
# 122776  1.1884027264  1.5666989036  0.0154489326 -0.0700384081      12284
# 122777 -1.3116513655  1.5666989036  0.0670712121 -0.0278080201      12285
# 122778 -1.1648991929  1.5666989036  0.9078388454  0.8745459430      12286
# 122779  1.2803514698  1.5666989036  0.8825912079  0.8440242224      12287
#
#                 prob
# 0       0.0000081446
# 1       0.0000081446
# 2       0.0000081446
# 3       0.0000081446
# 4       0.0000081446
# ...              ...
# 122775  0.0000081446
# 122776  0.0000081446
# 122777  0.0000081446
# 122778  0.0000081446
# 122779  0.0000081446
#
# [122780 rows x 16 columns]

# %%
# Initialize the probability column in the calibration database #

cal_data_scaled.columns = ['B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'A1', 'A2', 'A3', 'LAI', 'FAPAR', 'FCOVER', 'subset_id', 'prob']

# %%
# Assign max probability in each subset to every member of that subset 

cal_data_scaled['prob'] = cal_data_scaled.groupby('subset_id')['prob'].transform('max')

# %%
normalize(cal_data_scaled)
# Out:
#                   B0            B1            B2            B3            B4  \
# 0       1.1600887942  1.1894959571  1.1005309674 -0.7574953553 -1.2136760897
# 1       0.3768666595  1.6844505369  0.8279254564 -0.1275628723 -0.4502226101
# 2      -0.8037611472  0.3964451147 -1.0070101806 -2.3196717910 -2.4729247349
# 3      -0.7207048794 -0.0809646948 -0.6055016769 -1.8074281556 -2.0083566857
# 4      -0.2372000684  3.6360876602  0.9907504054 -1.1015319421 -1.3732421509
# ...              ...           ...           ...           ...           ...
# 122775 -0.6297919312 -0.6652193518 -0.7137539294 -0.6235871705 -0.5368542767
# 122776  0.0931071377  0.2412806393  0.0354813671 -0.6453889716 -0.6714434932
# 122777 -0.6857716627 -0.2526146846 -0.5985820716 -1.0496655348 -0.9756683152
# 122778 -0.9704468859 -0.6166997679 -1.0844430668  0.2860627172  0.8130774569
# 122779 -0.5607759421 -0.7686623410 -0.6271878617  0.4689890443  1.0907411044
#
#                   B5            B6            B7            A1            A2  \
# 0      -1.2551477212 -0.5123998591  0.0482701907 -1.5351947333 -1.2590753240
# 1      -0.3312429285  0.9573384489  1.5671047307  1.3154921199 -1.2529678973
# 2      -2.5265712936 -1.5494518415 -0.3972156885 -0.1884263875 -0.2249564670
# 3      -1.9850791466 -1.1119666599 -0.3072120391  0.2770296632  0.4521095310
# 4      -1.3790446724  1.1127770292  1.7252840412  1.3420921626  0.6946783564
# ...              ...           ...           ...           ...           ...
# 122775 -0.5172023756 -1.3917671005 -1.1518452670 -1.5081571622  0.8689131637
# 122776 -0.6273779690 -0.6983934776 -0.1362434958 -1.7063520463  1.0070079804
# 122777 -1.0505215854 -1.2394819780 -0.7913317214 -0.5801855863  0.9589002217
# 122778  0.6806459689 -0.5911033299 -1.0488424022 -1.7832601421  0.7151989067
# 122779  1.0725116772  0.0827382237 -0.3806995885 -1.9080817293  0.7902226473
#
#                   A3           LAI         FAPAR        FCOVER  subset_id  \
# 0      -0.7795178075 -1.5666989036 -1.8949148320 -1.6291084301          0
# 1      -0.6517039023 -1.5666989036 -1.4265332698 -1.3709908078          1
# 2       0.8795852552 -1.5666989036 -2.9215301414 -2.8250917213          2
# 3       1.0999315055 -1.5666989036 -2.3479536034 -2.1457394865          3
# 4      -1.2162290029 -1.5666989036 -2.6707957989 -2.7086125584          4
# ...              ...           ...           ...           ...        ...
# 122775 -1.2398669079  1.5666989036  0.7236507314  0.6517829598      12283
# 122776  1.1884027264  1.5666989036  0.0154489326 -0.0700384081      12284
# 122777 -1.3116513655  1.5666989036  0.0670712121 -0.0278080201      12285
# 122778 -1.1648991929  1.5666989036  0.9078388454  0.8745459430      12286
# 122779  1.2803514698  1.5666989036  0.8825912079  0.8440242224      12287
#
#                 prob
# 0       0.0000081446
# 1       0.0000081446
# 2       0.0000081446
# 3       0.0000081446
# 4       0.0000081446
# ...              ...
# 122775  0.0000081446
# 122776  0.0000081446
# 122777  0.0000081446
# 122778  0.0000081446
# 122779  0.0000081446
#
# [122780 rows x 16 columns]

# %%
# Creates the training and validation sets from the calibration data

training_data, valid_data = sklearn.model_selection.train_test_split(cal_data_scaled, test_size=0.3, train_size=0.7, random_state=None, shuffle=True, stratify=None)

# %%
# Resets the indices in the training data so that they start from zero

training_data = training_data.reset_index(drop=True)

# %%
# Resets the indices in the validation data so that they start from zero

valid_data = valid_data.reset_index(drop=True)

# %%
# Extracts the LAI, FAPAR, and FCOVER data to be used for training

LAI_training = training_data['LAI']
FAPAR_training = training_data['FAPAR']
FCOVER_training = training_data['FCOVER']

# %%
# Extracts the LAI, FAPAR, and FCOVER data to be used for validation

LAI_valid = valid_data['LAI']
FAPAR_valid = valid_data['FAPAR']
FCOVER_valid = valid_data['FCOVER']

# %%
# Extracts the probabilites for training and validation 

training_weights = numpy.array(training_data['prob'])
valid_weights = numpy.array(valid_data['prob'])

# %%
# Removes that isn't needed for training and validation 
# Explicitly subset the inputs
training_data = training_data.drop(['LAI', 'FAPAR', 'FCOVER','subset_id','prob'], axis=1)
valid_data = valid_data.drop(['LAI', 'FAPAR', 'FCOVER','subset_id','prob'], axis=1)

# %%
LAI_callback = tensorflow.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
FAPAR_callback = tensorflow.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
FCOVER_callback = tensorflow.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

# %%
# Creation of the Neural Network models for LAI, FAPAR, and FCOVER 

LAI_model = tensorflow.keras.models.Sequential([
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu, 
                                  input_shape=[len(training_data.keys())]),
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu),
    tensorflow.keras.layers.Dense(1)
])

LAI_model.compile(
    optimizer=tensorflow.keras.optimizers.Nadam(),
    loss='mse',
    metrics=['mse', 'mae'])

FAPAR_model = tensorflow.keras.models.Sequential([
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu, 
                                  input_shape=[len(training_data.keys())]),
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu),
    tensorflow.keras.layers.Dense(1)
])

FAPAR_model.compile(
    optimizer=tensorflow.keras.optimizers.Nadam(),
    loss='mse',
    metrics=['mse', 'mae'])

FCOVER_model = tensorflow.keras.models.Sequential([
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu, 
                                  input_shape=[len(training_data.keys())]),
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu),
    tensorflow.keras.layers.Dense(1)
])

FCOVER_model.compile(
    optimizer=tensorflow.keras.optimizers.Nadam(),
    loss='mse',
    metrics=['mse', 'mae'])

# %%
# Runs NN Model for LAI

LAI_history = LAI_model.fit(x = numpy.array(training_data), y = numpy.array(LAI_training), 
                            sample_weight = training_weights,
                            epochs = 120,
                            validation_data = (numpy.array(valid_data), numpy.array(LAI_valid), valid_weights),
                            callbacks=[LAI_callback]
                           )
# Out:
# Train on 85946 samples, validate on 36834 samples
# Epoch 1/120
# 85946/85946 [==============================] - 15s 176us/sample - loss: 2.9179e-06 - mse: 0.3583 - mae: 0.4785 - val_loss: 1.8483e-06 - val_mse: 0.2269 - val_mae: 0.3732
# Epoch 2/120
# 85946/85946 [==============================] - 12s 138us/sample - loss: 1.5597e-06 - mse: 0.1915 - mae: 0.3442 - val_loss: 1.3577e-06 - val_mse: 0.1667 - val_mae: 0.3205
# Epoch 3/120
# 85946/85946 [==============================] - 11s 133us/sample - loss: 1.2513e-06 - mse: 0.1536 - mae: 0.3061 - val_loss: 1.2002e-06 - val_mse: 0.1474 - val_mae: 0.2978
# Epoch 4/120
# 85946/85946 [==============================] - 14s 158us/sample - loss: 1.1346e-06 - mse: 0.1393 - mae: 0.2905 - val_loss: 1.1332e-06 - val_mse: 0.1391 - val_mae: 0.2869
# Epoch 5/120
# 85946/85946 [==============================] - 14s 164us/sample - loss: 1.0660e-06 - mse: 0.1309 - mae: 0.2812 - val_loss: 1.0428e-06 - val_mse: 0.1280 - val_mae: 0.2782
# Epoch 6/120
# 85946/85946 [==============================] - 12s 134us/sample - loss: 1.0038e-06 - mse: 0.1233 - mae: 0.2725 - val_loss: 9.8248e-07 - val_mse: 0.1206 - val_mae: 0.2711
# Epoch 7/120
# 85946/85946 [==============================] - 12s 138us/sample - loss: 9.4405e-07 - mse: 0.1159 - mae: 0.2641 - val_loss: 9.3828e-07 - val_mse: 0.1152 - val_mae: 0.2617
# Epoch 8/120
# 85946/85946 [==============================] - 11s 132us/sample - loss: 8.9497e-07 - mse: 0.1099 - mae: 0.2566 - val_loss: 8.8054e-07 - val_mse: 0.1081 - val_mae: 0.2551
# Epoch 9/120
# 85946/85946 [==============================] - 13s 147us/sample - loss: 8.5296e-07 - mse: 0.1047 - mae: 0.2504 - val_loss: 8.4251e-07 - val_mse: 0.1034 - val_mae: 0.2484
# Epoch 10/120
# 85946/85946 [==============================] - 13s 147us/sample - loss: 8.1528e-07 - mse: 0.1001 - mae: 0.2445 - val_loss: 8.2381e-07 - val_mse: 0.1011 - val_mae: 0.2449
# Epoch 11/120
# 85946/85946 [==============================] - 16s 184us/sample - loss: 7.8715e-07 - mse: 0.0966 - mae: 0.2402 - val_loss: 8.3962e-07 - val_mse: 0.1031 - val_mae: 0.2435
# Epoch 12/120
# 85946/85946 [==============================] - 15s 169us/sample - loss: 7.6674e-07 - mse: 0.0941 - mae: 0.2369 - val_loss: 7.5775e-07 - val_mse: 0.0930 - val_mae: 0.2345
# Epoch 13/120
# 85946/85946 [==============================] - 12s 145us/sample - loss: 7.5159e-07 - mse: 0.0923 - mae: 0.2343 - val_loss: 7.4079e-07 - val_mse: 0.0910 - val_mae: 0.2315
# Epoch 14/120
# 85946/85946 [==============================] - 12s 136us/sample - loss: 7.3802e-07 - mse: 0.0906 - mae: 0.2318 - val_loss: 7.2460e-07 - val_mse: 0.0890 - val_mae: 0.2291
# Epoch 15/120
# 85946/85946 [==============================] - 13s 155us/sample - loss: 7.2693e-07 - mse: 0.0893 - mae: 0.2300 - val_loss: 7.2798e-07 - val_mse: 0.0894 - val_mae: 0.2306
# Epoch 16/120
# 85946/85946 [==============================] - 13s 147us/sample - loss: 7.1773e-07 - mse: 0.0881 - mae: 0.2285 - val_loss: 7.0490e-07 - val_mse: 0.0865 - val_mae: 0.2266
# Epoch 17/120
# 85946/85946 [==============================] - 14s 166us/sample - loss: 7.0856e-07 - mse: 0.0870 - mae: 0.2271 - val_loss: 7.3162e-07 - val_mse: 0.0898 - val_mae: 0.2306
# Epoch 18/120
# 85946/85946 [==============================] - 17s 199us/sample - loss: 7.0163e-07 - mse: 0.0861 - mae: 0.2258 - val_loss: 6.9919e-07 - val_mse: 0.0858 - val_mae: 0.2245
# Epoch 19/120
# 85946/85946 [==============================] - 16s 189us/sample - loss: 6.9587e-07 - mse: 0.0854 - mae: 0.2249 - val_loss: 7.0396e-07 - val_mse: 0.0864 - val_mae: 0.2261
# Epoch 20/120
# 85946/85946 [==============================] - 15s 169us/sample - loss: 6.8812e-07 - mse: 0.0845 - mae: 0.2238 - val_loss: 7.0839e-07 - val_mse: 0.0870 - val_mae: 0.2264
# Epoch 21/120
# 85946/85946 [==============================] - 14s 157us/sample - loss: 6.8461e-07 - mse: 0.0841 - mae: 0.2231 - val_loss: 6.9260e-07 - val_mse: 0.0850 - val_mae: 0.2242
# Epoch 22/120
# 85946/85946 [==============================] - 13s 157us/sample - loss: 6.7785e-07 - mse: 0.0832 - mae: 0.2218 - val_loss: 6.6320e-07 - val_mse: 0.0814 - val_mae: 0.2199
# Epoch 23/120
# 85946/85946 [==============================] - 14s 159us/sample - loss: 6.7171e-07 - mse: 0.0825 - mae: 0.2209 - val_loss: 6.7263e-07 - val_mse: 0.0826 - val_mae: 0.2200
# Epoch 24/120
# 85946/85946 [==============================] - 14s 159us/sample - loss: 6.6622e-07 - mse: 0.0818 - mae: 0.2200 - val_loss: 6.7085e-07 - val_mse: 0.0824 - val_mae: 0.2211
# Epoch 25/120
# 85946/85946 [==============================] - 14s 160us/sample - loss: 6.6352e-07 - mse: 0.0815 - mae: 0.2193 - val_loss: 6.6354e-07 - val_mse: 0.0815 - val_mae: 0.2185
# Epoch 26/120
# 85946/85946 [==============================] - 14s 167us/sample - loss: 6.5660e-07 - mse: 0.0806 - mae: 0.2182 - val_loss: 6.6405e-07 - val_mse: 0.0815 - val_mae: 0.2189
# Epoch 27/120
# 85946/85946 [==============================] - 14s 158us/sample - loss: 6.5366e-07 - mse: 0.0803 - mae: 0.2174 - val_loss: 6.9492e-07 - val_mse: 0.0853 - val_mae: 0.2232
# Epoch 28/120
# 85946/85946 [==============================] - 14s 161us/sample - loss: 6.5030e-07 - mse: 0.0798 - mae: 0.2169 - val_loss: 6.5890e-07 - val_mse: 0.0809 - val_mae: 0.2188
# Epoch 29/120
# 85946/85946 [==============================] - 14s 159us/sample - loss: 6.4628e-07 - mse: 0.0793 - mae: 0.2162 - val_loss: 6.2901e-07 - val_mse: 0.0772 - val_mae: 0.2136
# Epoch 30/120
# 85946/85946 [==============================] - 14s 161us/sample - loss: 6.4256e-07 - mse: 0.0789 - mae: 0.2155 - val_loss: 6.4274e-07 - val_mse: 0.0789 - val_mae: 0.2171
# Epoch 31/120
# 85946/85946 [==============================] - 14s 161us/sample - loss: 6.4039e-07 - mse: 0.0786 - mae: 0.2151 - val_loss: 6.4653e-07 - val_mse: 0.0794 - val_mae: 0.2163
# Epoch 32/120
# 85946/85946 [==============================] - 14s 159us/sample - loss: 6.3822e-07 - mse: 0.0784 - mae: 0.2146 - val_loss: 6.2316e-07 - val_mse: 0.0765 - val_mae: 0.2132
# Epoch 33/120
# 85946/85946 [==============================] - 14s 163us/sample - loss: 6.3654e-07 - mse: 0.0782 - mae: 0.2142 - val_loss: 6.2344e-07 - val_mse: 0.0765 - val_mae: 0.2114
# Epoch 34/120
# 85946/85946 [==============================] - 13s 154us/sample - loss: 6.3185e-07 - mse: 0.0776 - mae: 0.2134 - val_loss: 6.3338e-07 - val_mse: 0.0778 - val_mae: 0.2128
# Epoch 35/120
# 85946/85946 [==============================] - 10s 121us/sample - loss: 6.3136e-07 - mse: 0.0775 - mae: 0.2133 - val_loss: 6.3082e-07 - val_mse: 0.0775 - val_mae: 0.2138
# Epoch 36/120
# 85946/85946 [==============================] - 10s 120us/sample - loss: 6.2699e-07 - mse: 0.0770 - mae: 0.2125 - val_loss: 6.2098e-07 - val_mse: 0.0762 - val_mae: 0.2114
# Epoch 37/120
# 85946/85946 [==============================] - 10s 119us/sample - loss: 6.2559e-07 - mse: 0.0768 - mae: 0.2124 - val_loss: 6.2179e-07 - val_mse: 0.0763 - val_mae: 0.2120
# Epoch 38/120
# 85946/85946 [==============================] - 10s 120us/sample - loss: 6.2280e-07 - mse: 0.0765 - mae: 0.2115 - val_loss: 6.3122e-07 - val_mse: 0.0775 - val_mae: 0.2140
# Epoch 39/120
# 85946/85946 [==============================] - 10s 122us/sample - loss: 6.2011e-07 - mse: 0.0761 - mae: 0.2112 - val_loss: 6.3244e-07 - val_mse: 0.0777 - val_mae: 0.2129
# Epoch 40/120
# 85946/85946 [==============================] - 10s 119us/sample - loss: 6.1805e-07 - mse: 0.0759 - mae: 0.2109 - val_loss: 6.2300e-07 - val_mse: 0.0765 - val_mae: 0.2103
# Epoch 41/120
# 85946/85946 [==============================] - 10s 122us/sample - loss: 6.1694e-07 - mse: 0.0757 - mae: 0.2106 - val_loss: 6.1339e-07 - val_mse: 0.0753 - val_mae: 0.2112
# Epoch 42/120
# 85946/85946 [==============================] - 10s 120us/sample - loss: 6.1477e-07 - mse: 0.0755 - mae: 0.2104 - val_loss: 6.1911e-07 - val_mse: 0.0760 - val_mae: 0.2109
# Epoch 43/120
# 85946/85946 [==============================] - 10s 120us/sample - loss: 6.1154e-07 - mse: 0.0751 - mae: 0.2097 - val_loss: 6.1361e-07 - val_mse: 0.0753 - val_mae: 0.2104
# Epoch 44/120
# 85946/85946 [==============================] - 10s 119us/sample - loss: 6.1230e-07 - mse: 0.0752 - mae: 0.2098 - val_loss: 6.0977e-07 - val_mse: 0.0749 - val_mae: 0.2085
# Epoch 45/120
# 85946/85946 [==============================] - 10s 120us/sample - loss: 6.1039e-07 - mse: 0.0749 - mae: 0.2095 - val_loss: 6.3102e-07 - val_mse: 0.0775 - val_mae: 0.2126
# Epoch 46/120
# 85946/85946 [==============================] - 10s 119us/sample - loss: 6.0730e-07 - mse: 0.0746 - mae: 0.2091 - val_loss: 6.0296e-07 - val_mse: 0.0740 - val_mae: 0.2079
# Epoch 47/120
# 85946/85946 [==============================] - 11s 125us/sample - loss: 6.0554e-07 - mse: 0.0743 - mae: 0.2086 - val_loss: 6.0183e-07 - val_mse: 0.0739 - val_mae: 0.2078
# Epoch 48/120
# 85946/85946 [==============================] - 11s 124us/sample - loss: 6.0457e-07 - mse: 0.0742 - mae: 0.2085 - val_loss: 5.9971e-07 - val_mse: 0.0736 - val_mae: 0.2074
# Epoch 49/120
# 85946/85946 [==============================] - 10s 119us/sample - loss: 6.0300e-07 - mse: 0.0740 - mae: 0.2081 - val_loss: 6.0246e-07 - val_mse: 0.0740 - val_mae: 0.2067
# Epoch 50/120
# 85946/85946 [==============================] - 10s 121us/sample - loss: 6.0234e-07 - mse: 0.0740 - mae: 0.2080 - val_loss: 5.9570e-07 - val_mse: 0.0731 - val_mae: 0.2072
# Epoch 51/120
# 85946/85946 [==============================] - 11s 123us/sample - loss: 5.9983e-07 - mse: 0.0736 - mae: 0.2077 - val_loss: 6.0747e-07 - val_mse: 0.0746 - val_mae: 0.2065
# Epoch 52/120
# 85946/85946 [==============================] - 10s 121us/sample - loss: 5.9768e-07 - mse: 0.0734 - mae: 0.2072 - val_loss: 6.4692e-07 - val_mse: 0.0794 - val_mae: 0.2114
# Epoch 53/120
# 85946/85946 [==============================] - 10s 119us/sample - loss: 5.9617e-07 - mse: 0.0732 - mae: 0.2068 - val_loss: 5.8377e-07 - val_mse: 0.0717 - val_mae: 0.2037
# Epoch 54/120
# 85946/85946 [==============================] - 10s 119us/sample - loss: 5.9471e-07 - mse: 0.0730 - mae: 0.2066 - val_loss: 6.0738e-07 - val_mse: 0.0746 - val_mae: 0.2092
# Epoch 55/120
# 85946/85946 [==============================] - 10s 119us/sample - loss: 5.9522e-07 - mse: 0.0731 - mae: 0.2068 - val_loss: 5.9044e-07 - val_mse: 0.0725 - val_mae: 0.2065
# Epoch 56/120
# 85946/85946 [==============================] - 10s 119us/sample - loss: 5.9245e-07 - mse: 0.0727 - mae: 0.2063 - val_loss: 5.8834e-07 - val_mse: 0.0722 - val_mae: 0.2053
# Epoch 57/120
# 85946/85946 [==============================] - 10s 119us/sample - loss: 5.8979e-07 - mse: 0.0724 - mae: 0.2058 - val_loss: 5.9708e-07 - val_mse: 0.0733 - val_mae: 0.2077
# Epoch 58/120
# 85946/85946 [==============================] - 10s 119us/sample - loss: 5.8968e-07 - mse: 0.0724 - mae: 0.2056 - val_loss: 6.1187e-07 - val_mse: 0.0751 - val_mae: 0.2086
# Epoch 59/120
# 85946/85946 [==============================] - 11s 123us/sample - loss: 5.8820e-07 - mse: 0.0722 - mae: 0.2054 - val_loss: 5.8838e-07 - val_mse: 0.0722 - val_mae: 0.2039
# Epoch 60/120
# 85946/85946 [==============================] - 10s 119us/sample - loss: 5.8690e-07 - mse: 0.0721 - mae: 0.2053 - val_loss: 5.8251e-07 - val_mse: 0.0715 - val_mae: 0.2034
# Epoch 61/120
# 85946/85946 [==============================] - 10s 119us/sample - loss: 5.8487e-07 - mse: 0.0718 - mae: 0.2049 - val_loss: 5.8440e-07 - val_mse: 0.0718 - val_mae: 0.2037
# Epoch 62/120
# 85946/85946 [==============================] - 10s 120us/sample - loss: 5.8521e-07 - mse: 0.0719 - mae: 0.2049 - val_loss: 5.8464e-07 - val_mse: 0.0718 - val_mae: 0.2033
# Epoch 63/120
# 85946/85946 [==============================] - 10s 120us/sample - loss: 5.8404e-07 - mse: 0.0717 - mae: 0.2045 - val_loss: 5.7593e-07 - val_mse: 0.0707 - val_mae: 0.2022
# Epoch 64/120
# 85946/85946 [==============================] - 10s 120us/sample - loss: 5.8474e-07 - mse: 0.0718 - mae: 0.2047 - val_loss: 5.9120e-07 - val_mse: 0.0726 - val_mae: 0.2051
# Epoch 65/120
# 85946/85946 [==============================] - 10s 120us/sample - loss: 5.8134e-07 - mse: 0.0714 - mae: 0.2042 - val_loss: 5.7663e-07 - val_mse: 0.0708 - val_mae: 0.2031
# Epoch 66/120
# 85946/85946 [==============================] - 10s 120us/sample - loss: 5.8060e-07 - mse: 0.0713 - mae: 0.2040 - val_loss: 5.9460e-07 - val_mse: 0.0730 - val_mae: 0.2058
# Epoch 67/120
# 85946/85946 [==============================] - 10s 120us/sample - loss: 5.8063e-07 - mse: 0.0713 - mae: 0.2039 - val_loss: 5.7169e-07 - val_mse: 0.0702 - val_mae: 0.2021
# Epoch 68/120
# 85946/85946 [==============================] - 13s 147us/sample - loss: 5.8085e-07 - mse: 0.0713 - mae: 0.2040 - val_loss: 5.9350e-07 - val_mse: 0.0729 - val_mae: 0.2050
# Epoch 69/120
# 85946/85946 [==============================] - 14s 157us/sample - loss: 5.7854e-07 - mse: 0.0710 - mae: 0.2035 - val_loss: 5.8288e-07 - val_mse: 0.0716 - val_mae: 0.2029
# Epoch 70/120
# 85946/85946 [==============================] - 13s 155us/sample - loss: 5.7640e-07 - mse: 0.0708 - mae: 0.2033 - val_loss: 5.6589e-07 - val_mse: 0.0695 - val_mae: 0.2027
# Epoch 71/120
# 85946/85946 [==============================] - 13s 154us/sample - loss: 5.7615e-07 - mse: 0.0707 - mae: 0.2029 - val_loss: 5.8898e-07 - val_mse: 0.0723 - val_mae: 0.2053
# Epoch 72/120
# 85946/85946 [==============================] - 14s 161us/sample - loss: 5.7610e-07 - mse: 0.0707 - mae: 0.2031 - val_loss: 5.8617e-07 - val_mse: 0.0720 - val_mae: 0.2031
# Epoch 73/120
# 85946/85946 [==============================] - 14s 158us/sample - loss: 5.7673e-07 - mse: 0.0708 - mae: 0.2031 - val_loss: 5.7273e-07 - val_mse: 0.0703 - val_mae: 0.2018
# Epoch 74/120
# 85946/85946 [==============================] - 14s 161us/sample - loss: 5.7645e-07 - mse: 0.0708 - mae: 0.2031 - val_loss: 5.9907e-07 - val_mse: 0.0736 - val_mae: 0.2052
# Epoch 75/120
# 85946/85946 [==============================] - 13s 156us/sample - loss: 5.7432e-07 - mse: 0.0705 - mae: 0.2029 - val_loss: 5.9127e-07 - val_mse: 0.0726 - val_mae: 0.2050
# Epoch 76/120
# 85946/85946 [==============================] - 14s 158us/sample - loss: 5.7418e-07 - mse: 0.0705 - mae: 0.2027 - val_loss: 6.0078e-07 - val_mse: 0.0738 - val_mae: 0.2041
# Epoch 77/120
# 85946/85946 [==============================] - 14s 160us/sample - loss: 5.7154e-07 - mse: 0.0702 - mae: 0.2024 - val_loss: 5.6235e-07 - val_mse: 0.0690 - val_mae: 0.2017
# Epoch 78/120
# 85946/85946 [==============================] - 14s 164us/sample - loss: 5.7317e-07 - mse: 0.0704 - mae: 0.2026 - val_loss: 5.7557e-07 - val_mse: 0.0707 - val_mae: 0.2038
# Epoch 79/120
# 85946/85946 [==============================] - 14s 165us/sample - loss: 5.7060e-07 - mse: 0.0701 - mae: 0.2022 - val_loss: 5.8128e-07 - val_mse: 0.0714 - val_mae: 0.2041
# Epoch 80/120
# 85946/85946 [==============================] - 14s 161us/sample - loss: 5.7237e-07 - mse: 0.0703 - mae: 0.2023 - val_loss: 5.7439e-07 - val_mse: 0.0705 - val_mae: 0.2028
# Epoch 81/120
# 85946/85946 [==============================] - 14s 165us/sample - loss: 5.6987e-07 - mse: 0.0700 - mae: 0.2017 - val_loss: 5.6278e-07 - val_mse: 0.0691 - val_mae: 0.2015
# Epoch 82/120
# 85946/85946 [==============================] - 14s 160us/sample - loss: 5.7127e-07 - mse: 0.0701 - mae: 0.2023 - val_loss: 5.5755e-07 - val_mse: 0.0685 - val_mae: 0.2005
# Epoch 83/120
# 85946/85946 [==============================] - 14s 163us/sample - loss: 5.6950e-07 - mse: 0.0699 - mae: 0.2017 - val_loss: 5.5434e-07 - val_mse: 0.0681 - val_mae: 0.1988
# Epoch 84/120
# 85946/85946 [==============================] - 14s 164us/sample - loss: 5.6833e-07 - mse: 0.0698 - mae: 0.2015 - val_loss: 5.5652e-07 - val_mse: 0.0683 - val_mae: 0.2005
# Epoch 85/120
# 85946/85946 [==============================] - 14s 168us/sample - loss: 5.6803e-07 - mse: 0.0697 - mae: 0.2016 - val_loss: 5.6197e-07 - val_mse: 0.0690 - val_mae: 0.1995
# Epoch 86/120
# 85946/85946 [==============================] - 14s 160us/sample - loss: 5.6787e-07 - mse: 0.0697 - mae: 0.2015 - val_loss: 5.5629e-07 - val_mse: 0.0683 - val_mae: 0.1998
# Epoch 87/120
# 85946/85946 [==============================] - 13s 157us/sample - loss: 5.6841e-07 - mse: 0.0698 - mae: 0.2017 - val_loss: 5.8650e-07 - val_mse: 0.0720 - val_mae: 0.2030
# Epoch 88/120
# 85946/85946 [==============================] - 13s 155us/sample - loss: 5.6667e-07 - mse: 0.0696 - mae: 0.2015 - val_loss: 5.8386e-07 - val_mse: 0.0717 - val_mae: 0.2034
# Epoch 89/120
# 85946/85946 [==============================] - 13s 156us/sample - loss: 5.6529e-07 - mse: 0.0694 - mae: 0.2011 - val_loss: 5.6849e-07 - val_mse: 0.0698 - val_mae: 0.2020
# Epoch 90/120
# 85946/85946 [==============================] - 18s 209us/sample - loss: 5.6627e-07 - mse: 0.0695 - mae: 0.2011 - val_loss: 5.4592e-07 - val_mse: 0.0670 - val_mae: 0.1974
# Epoch 91/120
# 85946/85946 [==============================] - 13s 148us/sample - loss: 5.6522e-07 - mse: 0.0694 - mae: 0.2009 - val_loss: 5.5199e-07 - val_mse: 0.0678 - val_mae: 0.1994
# Epoch 92/120
# 85946/85946 [==============================] - 12s 134us/sample - loss: 5.6492e-07 - mse: 0.0694 - mae: 0.2008 - val_loss: 5.5266e-07 - val_mse: 0.0679 - val_mae: 0.1972
# Epoch 93/120
# 85946/85946 [==============================] - 14s 167us/sample - loss: 5.6412e-07 - mse: 0.0693 - mae: 0.2006 - val_loss: 5.6280e-07 - val_mse: 0.0691 - val_mae: 0.2048
# Epoch 94/120
# 85946/85946 [==============================] - 14s 162us/sample - loss: 5.6360e-07 - mse: 0.0692 - mae: 0.2007 - val_loss: 5.6392e-07 - val_mse: 0.0692 - val_mae: 0.2006
# Epoch 95/120
# 85946/85946 [==============================] - 12s 138us/sample - loss: 5.6287e-07 - mse: 0.0691 - mae: 0.2003 - val_loss: 5.5968e-07 - val_mse: 0.0687 - val_mae: 0.2012
# Epoch 96/120
# 85946/85946 [==============================] - 11s 133us/sample - loss: 5.6136e-07 - mse: 0.0689 - mae: 0.2003 - val_loss: 5.4647e-07 - val_mse: 0.0671 - val_mae: 0.1986
# Epoch 97/120
# 85946/85946 [==============================] - 11s 123us/sample - loss: 5.5998e-07 - mse: 0.0688 - mae: 0.1997 - val_loss: 5.6293e-07 - val_mse: 0.0691 - val_mae: 0.2002
# Epoch 98/120
# 85946/85946 [==============================] - 10s 122us/sample - loss: 5.5866e-07 - mse: 0.0686 - mae: 0.1996 - val_loss: 5.5836e-07 - val_mse: 0.0686 - val_mae: 0.2005
# Epoch 99/120
# 85946/85946 [==============================] - 10s 121us/sample - loss: 5.5889e-07 - mse: 0.0686 - mae: 0.1996 - val_loss: 5.6566e-07 - val_mse: 0.0695 - val_mae: 0.2002
# Epoch 100/120
# 85946/85946 [==============================] - 10s 121us/sample - loss: 5.5815e-07 - mse: 0.0685 - mae: 0.1996 - val_loss: 5.8755e-07 - val_mse: 0.0721 - val_mae: 0.2062
# Epoch 101/120
# 85946/85946 [==============================] - 11s 125us/sample - loss: 5.5746e-07 - mse: 0.0684 - mae: 0.1992 - val_loss: 5.4002e-07 - val_mse: 0.0663 - val_mae: 0.1955
# Epoch 102/120
# 85946/85946 [==============================] - 10s 120us/sample - loss: 5.5585e-07 - mse: 0.0682 - mae: 0.1987 - val_loss: 5.6333e-07 - val_mse: 0.0692 - val_mae: 0.1993
# Epoch 103/120
# 85946/85946 [==============================] - 10s 120us/sample - loss: 5.5719e-07 - mse: 0.0684 - mae: 0.1989 - val_loss: 5.4482e-07 - val_mse: 0.0669 - val_mae: 0.1967
# Epoch 104/120
# 85946/85946 [==============================] - 10s 120us/sample - loss: 5.5549e-07 - mse: 0.0682 - mae: 0.1987 - val_loss: 5.4195e-07 - val_mse: 0.0665 - val_mae: 0.1955
# Epoch 105/120
# 85946/85946 [==============================] - 10s 121us/sample - loss: 5.5466e-07 - mse: 0.0681 - mae: 0.1987 - val_loss: 5.5388e-07 - val_mse: 0.0680 - val_mae: 0.1962
# Epoch 106/120
# 85946/85946 [==============================] - 10s 121us/sample - loss: 5.5473e-07 - mse: 0.0681 - mae: 0.1987 - val_loss: 5.6014e-07 - val_mse: 0.0688 - val_mae: 0.2002
# Epoch 107/120
# 85946/85946 [==============================] - 10s 121us/sample - loss: 5.5286e-07 - mse: 0.0679 - mae: 0.1984 - val_loss: 5.3282e-07 - val_mse: 0.0654 - val_mae: 0.1950
# Epoch 108/120
# 85946/85946 [==============================] - 12s 136us/sample - loss: 5.5231e-07 - mse: 0.0678 - mae: 0.1980 - val_loss: 5.5185e-07 - val_mse: 0.0678 - val_mae: 0.1979
# Epoch 109/120
# 85946/85946 [==============================] - 16s 186us/sample - loss: 5.5343e-07 - mse: 0.0679 - mae: 0.1984 - val_loss: 5.5046e-07 - val_mse: 0.0676 - val_mae: 0.1976
# Epoch 110/120
# 85946/85946 [==============================] - 15s 171us/sample - loss: 5.5216e-07 - mse: 0.0678 - mae: 0.1982 - val_loss: 5.4894e-07 - val_mse: 0.0674 - val_mae: 0.1978
# Epoch 111/120
# 85946/85946 [==============================] - 12s 142us/sample - loss: 5.5160e-07 - mse: 0.0677 - mae: 0.1979 - val_loss: 5.3324e-07 - val_mse: 0.0655 - val_mae: 0.1943
# Epoch 112/120
# 85946/85946 [==============================] - 12s 140us/sample - loss: 5.5215e-07 - mse: 0.0678 - mae: 0.1981 - val_loss: 5.4751e-07 - val_mse: 0.0672 - val_mae: 0.1970
# Epoch 113/120
# 85946/85946 [==============================] - 12s 134us/sample - loss: 5.5101e-07 - mse: 0.0677 - mae: 0.1978 - val_loss: 5.8695e-07 - val_mse: 0.0721 - val_mae: 0.2042
# Epoch 114/120
# 85946/85946 [==============================] - 11s 131us/sample - loss: 5.4894e-07 - mse: 0.0674 - mae: 0.1977 - val_loss: 5.4740e-07 - val_mse: 0.0672 - val_mae: 0.1969
# Epoch 115/120
# 85946/85946 [==============================] - 11s 134us/sample - loss: 5.4969e-07 - mse: 0.0675 - mae: 0.1977 - val_loss: 5.5477e-07 - val_mse: 0.0681 - val_mae: 0.1968
# Epoch 116/120
# 85946/85946 [==============================] - 12s 145us/sample - loss: 5.4863e-07 - mse: 0.0674 - mae: 0.1974 - val_loss: 5.6397e-07 - val_mse: 0.0692 - val_mae: 0.1973
# Epoch 117/120
# 85946/85946 [==============================] - 13s 146us/sample - loss: 5.4926e-07 - mse: 0.0674 - mae: 0.1976 - val_loss: 5.5213e-07 - val_mse: 0.0678 - val_mae: 0.1972
# Epoch 118/120
# 85946/85946 [==============================] - 14s 161us/sample - loss: 5.4987e-07 - mse: 0.0675 - mae: 0.1976 - val_loss: 5.3900e-07 - val_mse: 0.0662 - val_mae: 0.1953
# Epoch 119/120
# 85946/85946 [==============================] - 13s 154us/sample - loss: 5.4872e-07 - mse: 0.0674 - mae: 0.1975 - val_loss: 5.3424e-07 - val_mse: 0.0656 - val_mae: 0.1953

# %%
# Runs NN Model for FAPAR

FAPAR_history = FAPAR_model.fit(x = numpy.array(training_data), y = numpy.array(FAPAR_training),
                                sample_weight = training_weights,
                                epochs = 20, 
                                validation_data = (numpy.array(valid_data), numpy.array(FAPAR_valid), valid_weights),
                                callbacks=[FAPAR_callback]
                               )
# Out:
# Train on 85946 samples, validate on 36834 samples
# Epoch 1/20
# 85946/85946 [==============================] - 16s 189us/sample - loss: 8.3464e-07 - mse: 0.1025 - mae: 0.2173 - val_loss: 2.6955e-07 - val_mse: 0.0331 - val_mae: 0.1356
# Epoch 2/20
# 85946/85946 [==============================] - 12s 137us/sample - loss: 2.1809e-07 - mse: 0.0268 - mae: 0.1199 - val_loss: 1.9392e-07 - val_mse: 0.0238 - val_mae: 0.1107- loss:
# Epoch 3/20
# 85946/85946 [==============================] - 12s 136us/sample - loss: 1.7580e-07 - mse: 0.0216 - mae: 0.1059 - val_loss: 1.7519e-07 - val_mse: 0.0215 - val_mae: 0.1060
# Epoch 4/20
# 85946/85946 [==============================] - 12s 144us/sample - loss: 1.6323e-07 - mse: 0.0200 - mae: 0.1020 - val_loss: 1.6498e-07 - val_mse: 0.0203 - val_mae: 0.1023
# Epoch 5/20
# 85946/85946 [==============================] - 14s 157us/sample - loss: 1.5577e-07 - mse: 0.0191 - mae: 0.0995 - val_loss: 1.5850e-07 - val_mse: 0.0195 - val_mae: 0.0993
# Epoch 6/20
# 85946/85946 [==============================] - 11s 127us/sample - loss: 1.4973e-07 - mse: 0.0184 - mae: 0.0973 - val_loss: 1.4954e-07 - val_mse: 0.0184 - val_mae: 0.0969
# Epoch 7/20
# 85946/85946 [==============================] - 12s 135us/sample - loss: 1.4513e-07 - mse: 0.0178 - mae: 0.0956 - val_loss: 1.4684e-07 - val_mse: 0.0180 - val_mae: 0.0957
# Epoch 8/20
# 85946/85946 [==============================] - 13s 151us/sample - loss: 1.4184e-07 - mse: 0.0174 - mae: 0.0941 - val_loss: 1.4416e-07 - val_mse: 0.0177 - val_mae: 0.0951
# Epoch 9/20
# 85946/85946 [==============================] - 17s 195us/sample - loss: 1.3851e-07 - mse: 0.0170 - mae: 0.0928 - val_loss: 1.4101e-07 - val_mse: 0.0173 - val_mae: 0.0935
# Epoch 10/20
# 85946/85946 [==============================] - 12s 137us/sample - loss: 1.3656e-07 - mse: 0.0168 - mae: 0.0919 - val_loss: 1.4236e-07 - val_mse: 0.0175 - val_mae: 0.0934
# Epoch 11/20
# 85946/85946 [==============================] - 12s 137us/sample - loss: 1.3450e-07 - mse: 0.0165 - mae: 0.0911 - val_loss: 1.3659e-07 - val_mse: 0.0168 - val_mae: 0.0917
# Epoch 12/20
# 85946/85946 [==============================] - 13s 157us/sample - loss: 1.3302e-07 - mse: 0.0163 - mae: 0.0906 - val_loss: 1.3996e-07 - val_mse: 0.0172 - val_mae: 0.0926
# Epoch 13/20
# 85946/85946 [==============================] - 11s 131us/sample - loss: 1.3172e-07 - mse: 0.0162 - mae: 0.0901 - val_loss: 1.3524e-07 - val_mse: 0.0166 - val_mae: 0.0911
# Epoch 14/20
# 85946/85946 [==============================] - 12s 144us/sample - loss: 1.3021e-07 - mse: 0.0160 - mae: 0.0896 - val_loss: 1.3311e-07 - val_mse: 0.0163 - val_mae: 0.0909
# Epoch 15/20
# 85946/85946 [==============================] - 13s 150us/sample - loss: 1.2936e-07 - mse: 0.0159 - mae: 0.0894 - val_loss: 1.3259e-07 - val_mse: 0.0163 - val_mae: 0.0905
# Epoch 16/20
# 85946/85946 [==============================] - 13s 151us/sample - loss: 1.2787e-07 - mse: 0.0157 - mae: 0.0889 - val_loss: 1.3011e-07 - val_mse: 0.0160 - val_mae: 0.0895
# Epoch 17/20
# 85946/85946 [==============================] - 12s 141us/sample - loss: 1.2703e-07 - mse: 0.0156 - mae: 0.0886 - val_loss: 1.3083e-07 - val_mse: 0.0161 - val_mae: 0.0898
# Epoch 18/20
# 85946/85946 [==============================] - 12s 141us/sample - loss: 1.2629e-07 - mse: 0.0155 - mae: 0.0883 - val_loss: 1.3655e-07 - val_mse: 0.0168 - val_mae: 0.0914
# Epoch 19/20
# 85946/85946 [==============================] - 13s 148us/sample - loss: 1.2530e-07 - mse: 0.0154 - mae: 0.0880 - val_loss: 1.2683e-07 - val_mse: 0.0156 - val_mae: 0.0890
# Epoch 20/20
# 85946/85946 [==============================] - 13s 147us/sample - loss: 1.2428e-07 - mse: 0.0153 - mae: 0.0877 - val_loss: 1.2888e-07 - val_mse: 0.0158 - val_mae: 0.0895

# %%
# Runs NN Model for FCOVER

FCOVER_history = FCOVER_model.fit(x = numpy.array(training_data), y = numpy.array(FCOVER_training),
                                  sample_weight = training_weights,
                                  epochs = 20, 
                                  validation_data = (numpy.array(valid_data), numpy.array(FCOVER_valid), valid_weights),
                                  callbacks=[FCOVER_callback]
                                 )
# Out:
# Train on 85946 samples, validate on 36834 samples
# Epoch 1/20
# 85946/85946 [==============================] - 17s 193us/sample - loss: 8.3294e-07 - mse: 0.1023 - mae: 0.2001 - val_loss: 2.6533e-07 - val_mse: 0.0326 - val_mae: 0.1346
# Epoch 2/20
# 85946/85946 [==============================] - 12s 134us/sample - loss: 2.2086e-07 - mse: 0.0271 - mae: 0.1229 - val_loss: 1.9379e-07 - val_mse: 0.0238 - val_mae: 0.1147
# Epoch 3/20
# 85946/85946 [==============================] - 15s 170us/sample - loss: 1.7302e-07 - mse: 0.0212 - mae: 0.1087 - val_loss: 1.6322e-07 - val_mse: 0.0200 - val_mae: 0.1052
# Epoch 4/20
# 85946/85946 [==============================] - 13s 149us/sample - loss: 1.5170e-07 - mse: 0.0186 - mae: 0.1012 - val_loss: 1.4784e-07 - val_mse: 0.0182 - val_mae: 0.0995
# Epoch 5/20
# 85946/85946 [==============================] - 12s 141us/sample - loss: 1.3933e-07 - mse: 0.0171 - mae: 0.0964 - val_loss: 1.4137e-07 - val_mse: 0.0174 - val_mae: 0.0974
# Epoch 6/20
# 85946/85946 [==============================] - 12s 137us/sample - loss: 1.3258e-07 - mse: 0.0163 - mae: 0.0934 - val_loss: 1.3745e-07 - val_mse: 0.0169 - val_mae: 0.0955
# Epoch 7/20
# 85946/85946 [==============================] - 12s 144us/sample - loss: 1.2807e-07 - mse: 0.0157 - mae: 0.0913 - val_loss: 1.2988e-07 - val_mse: 0.0159 - val_mae: 0.0913
# Epoch 8/20
# 85946/85946 [==============================] - 15s 176us/sample - loss: 1.2497e-07 - mse: 0.0153 - mae: 0.0897 - val_loss: 1.2785e-07 - val_mse: 0.0157 - val_mae: 0.0908
# Epoch 9/20
# 85946/85946 [==============================] - 11s 123us/sample - loss: 1.2197e-07 - mse: 0.0150 - mae: 0.0883 - val_loss: 1.2345e-07 - val_mse: 0.0152 - val_mae: 0.0886
# Epoch 10/20
# 85946/85946 [==============================] - 10s 121us/sample - loss: 1.1934e-07 - mse: 0.0147 - mae: 0.0872 - val_loss: 1.2206e-07 - val_mse: 0.0150 - val_mae: 0.0875
# Epoch 11/20
# 85946/85946 [==============================] - 10s 119us/sample - loss: 1.1723e-07 - mse: 0.0144 - mae: 0.0863 - val_loss: 1.1819e-07 - val_mse: 0.0145 - val_mae: 0.0863
# Epoch 12/20
# 85946/85946 [==============================] - 10s 119us/sample - loss: 1.1504e-07 - mse: 0.0141 - mae: 0.0855 - val_loss: 1.1674e-07 - val_mse: 0.0143 - val_mae: 0.0862
# Epoch 13/20
# 85946/85946 [==============================] - 10s 119us/sample - loss: 1.1358e-07 - mse: 0.0139 - mae: 0.0849 - val_loss: 1.1676e-07 - val_mse: 0.0143 - val_mae: 0.0863
# Epoch 14/20
# 85946/85946 [==============================] - 10s 119us/sample - loss: 1.1248e-07 - mse: 0.0138 - mae: 0.0844 - val_loss: 1.1558e-07 - val_mse: 0.0142 - val_mae: 0.0854
# Epoch 15/20
# 85946/85946 [==============================] - 10s 120us/sample - loss: 1.1135e-07 - mse: 0.0137 - mae: 0.0840 - val_loss: 1.1371e-07 - val_mse: 0.0140 - val_mae: 0.0847
# Epoch 16/20
# 85946/85946 [==============================] - 10s 119us/sample - loss: 1.1040e-07 - mse: 0.0136 - mae: 0.0837 - val_loss: 1.1974e-07 - val_mse: 0.0147 - val_mae: 0.0864
# Epoch 17/20
# 85946/85946 [==============================] - 11s 123us/sample - loss: 1.0930e-07 - mse: 0.0134 - mae: 0.0832 - val_loss: 1.1294e-07 - val_mse: 0.0139 - val_mae: 0.0851
# Epoch 18/20
# 85946/85946 [==============================] - 10s 120us/sample - loss: 1.0830e-07 - mse: 0.0133 - mae: 0.0829 - val_loss: 1.1500e-07 - val_mse: 0.0141 - val_mae: 0.0848
# Epoch 19/20
# 85946/85946 [==============================] - 10s 119us/sample - loss: 1.0733e-07 - mse: 0.0132 - mae: 0.0824 - val_loss: 1.0966e-07 - val_mse: 0.0135 - val_mae: 0.0827
# Epoch 20/20
# 85946/85946 [==============================] - 10s 119us/sample - loss: 1.0597e-07 - mse: 0.0130 - mae: 0.0820 - val_loss: 1.0704e-07 - val_mse: 0.0131 - val_mae: 0.0826

# %%
# These are all plots for the RMSE of the NN as training was run

# %%
LAI_rmse = plt.plot(numpy.sqrt(LAI_history.history['mse']))
plt.xlabel("Epoch Number")
plt.ylabel("RMSE")
plt.title("LAI RMSE")
plt.show()

# %%
FAPAR_rmse = plt.plot(numpy.sqrt(FAPAR_history.history['mse']))
plt.xlabel("Epoch Number")
plt.ylabel("RMSE")
plt.title("FAPAR RMSE")
plt.show()

# %%
FCOVER_rmse = plt.plot(numpy.sqrt(FCOVER_history.history['mse']))
plt.xlabel("Epoch Number")
plt.ylabel("RMSE")
plt.title("FCOVER RMSE")
plt.show()

# %%
# Makes predictions on the validation data using the 

LAI_predictions = pandas.Series(LAI_model.predict(numpy.array(valid_data)).flatten())
FAPAR_predictions = pandas.Series(FAPAR_model.predict(numpy.array(valid_data)).flatten())
FCOVER_predictions = pandas.Series(FCOVER_model.predict(numpy.array(valid_data)).flatten())

# %%
# Creates a model for LAI, FAPAR, and FCOVER using LARs regression 

LAImodel = sklearn.linear_model.Lars(n_nonzero_coefs=4)
LAImodel = LAImodel.fit(training_data, LAI_training)

FAPARmodel = sklearn.linear_model.Lars(n_nonzero_coefs=4)
FAPARmodel = FAPARmodel.fit(training_data, FAPAR_training)

FCOVERmodel = sklearn.linear_model.Lars(n_nonzero_coefs=4)
FCOVERmodel = FCOVERmodel.fit(training_data, FCOVER_training)

# %%
# Makes predictions on the validation data using the LARS models

LAI_predicted = pandas.Series(LAImodel.predict(valid_data))
FAPAR_predicted = pandas.Series(FAPARmodel.predict(valid_data))
FCOVER_predicted = pandas.Series(FCOVERmodel.predict(valid_data))

# %%
# Function that creates the density plots 

def plotting_function(var, input_var, resp_var, title, xlabel, ylabel, alg, ax=None):
    ax = ax
    input_var = input_var*cal_data[var].std() + cal_data[var].mean()
    resp_var = resp_var*cal_data[var].std() + cal_data[var].mean()
    xy = numpy.vstack([input_var, resp_var])
    z = scipy.stats.gaussian_kde(xy)(xy)
    idx = z.argsort()
    x = input_var[idx]
    y = resp_var[idx]
    z = z[idx]
    rmse = sklearn.metrics.mean_squared_error(x, y, squared=False)
    r_sqr = sklearn.metrics.r2_score(x, y)
    ax.scatter(x, y, c = z)
    plt.colorbar(mappable=ax.scatter(x, y, c = z), ax=ax)
    ax.set_title(title + '-' + alg + ' - RMSE: {}'.format(rmse) + ' - $R^2$: {}'.format(r_sqr))
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3,figsize=(25,15))

plotting_function('LAI',LAI_valid, LAI_predicted, 'LAI','Input LAI','Predicted LAI','LARS', ax1)
  
plotting_function('FAPAR',FAPAR_valid, FAPAR_predicted, 'FAPAR','Input FAPAR','Predicted FAPAR','LARS', ax2)

plotting_function('FCOVER',FCOVER_valid, FCOVER_predicted, 'FCOVER','Input FCOVER','Predicted FCOVER','LARS', ax3)

fig.suptitle('LARS Regression', fontsize=16)
# Out:
# Text(0.5, 0.98, 'LARS Regression')

# %%
fig, (ax4, ax5, ax6) = plt.subplots(1,3,figsize=(25,15))

plotting_function('LAI', LAI_valid, LAI_predictions, 'LAI','Input LAI','Predicted LAI','NNet',ax4)
plotting_function('FAPAR', FAPAR_valid, FAPAR_predictions, 'FAPAR','Input FAPAR','Predicted FAPAR','NNet',ax5)
plotting_function('FCOVER', FCOVER_valid, FCOVER_predictions, 'FCOVER','Input FCOVER','Predicted FCOVER','NNet',ax6)

fig.suptitle('Neural Network - with weights', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Neural Network - with weights')

# %%
# Creation of the Neural Network models for LAI, FAPAR, and FCOVER 

LAI_model_no_weights = tensorflow.keras.models.Sequential([
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu, 
                                  input_shape=[len(training_data.keys())]),
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu),
    tensorflow.keras.layers.Dense(1)
])

LAI_model_no_weights.compile(
    optimizer=tensorflow.keras.optimizers.Nadam(),
    loss='mse',
    metrics=['mse', 'mae'])

FAPAR_model_no_weights = tensorflow.keras.models.Sequential([
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu, 
                                  input_shape=[len(training_data.keys())]),
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu),
    tensorflow.keras.layers.Dense(1)
])

FAPAR_model_no_weights.compile(
    optimizer=tensorflow.keras.optimizers.Nadam(),
    loss='mse',
    metrics=['mse', 'mae'])

FCOVER_model_no_weights = tensorflow.keras.models.Sequential([
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu, 
                                  input_shape=[len(training_data.keys())]),
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu),
    tensorflow.keras.layers.Dense(1)
])

FCOVER_model_no_weights.compile(
    optimizer=tensorflow.keras.optimizers.Nadam(),
    loss='mse',
    metrics=['mse', 'mae'])

# %%
# Runs NN Model for LAI

LAI_history_no_weights = LAI_model_no_weights.fit(x = numpy.array(training_data), y = numpy.array(LAI_training), 
                            epochs = 120,
                            validation_data = (numpy.array(valid_data), numpy.array(LAI_valid)) 
                           )
# Out:
# Train on 85946 samples, validate on 36834 samples
# Epoch 1/120
# 85946/85946 [==============================] - 15s 173us/sample - loss: 0.3532 - mse: 0.3532 - mae: 0.4751 - val_loss: 0.2121 - val_mse: 0.2121 - val_mae: 0.3649
# Epoch 2/120
# 85946/85946 [==============================] - 12s 137us/sample - loss: 0.1778 - mse: 0.1778 - mae: 0.3300 - val_loss: 0.1621 - val_mse: 0.1621 - val_mae: 0.3185
# Epoch 3/120
# 85946/85946 [==============================] - 11s 133us/sample - loss: 0.1502 - mse: 0.1502 - mae: 0.3017 - val_loss: 0.1460 - val_mse: 0.1460 - val_mae: 0.2965
# Epoch 4/120
# 85946/85946 [==============================] - 11s 126us/sample - loss: 0.1401 - mse: 0.1401 - mae: 0.2908 - val_loss: 0.1389 - val_mse: 0.1389 - val_mae: 0.2888
# Epoch 5/120
# 85946/85946 [==============================] - 13s 148us/sample - loss: 0.1316 - mse: 0.1316 - mae: 0.2811 - val_loss: 0.1308 - val_mse: 0.1308 - val_mae: 0.2774
# Epoch 6/120
# 85946/85946 [==============================] - 11s 133us/sample - loss: 0.1241 - mse: 0.1241 - mae: 0.2724 - val_loss: 0.1236 - val_mse: 0.1236 - val_mae: 0.2722
# Epoch 7/120
# 85946/85946 [==============================] - 10s 118us/sample - loss: 0.1187 - mse: 0.1187 - mae: 0.2662 - val_loss: 0.1199 - val_mse: 0.1199 - val_mae: 0.2672
# Epoch 8/120
# 85946/85946 [==============================] - 10s 112us/sample - loss: 0.1135 - mse: 0.1135 - mae: 0.2602 - val_loss: 0.1125 - val_mse: 0.1125 - val_mae: 0.2573
# Epoch 9/120
# 85946/85946 [==============================] - 10s 112us/sample - loss: 0.1082 - mse: 0.1082 - mae: 0.2542 - val_loss: 0.1086 - val_mse: 0.1086 - val_mae: 0.2550
# Epoch 10/120
# 85946/85946 [==============================] - 10s 114us/sample - loss: 0.1034 - mse: 0.1034 - mae: 0.2482 - val_loss: 0.1022 - val_mse: 0.1022 - val_mae: 0.2463
# Epoch 11/120
# 85946/85946 [==============================] - 10s 111us/sample - loss: 0.0994 - mse: 0.0994 - mae: 0.2430 - val_loss: 0.0983 - val_mse: 0.0983 - val_mae: 0.2401
# Epoch 12/120
# 85946/85946 [==============================] - 10s 111us/sample - loss: 0.0958 - mse: 0.0958 - mae: 0.2386 - val_loss: 0.0961 - val_mse: 0.0961 - val_mae: 0.2401
# Epoch 13/120
# 85946/85946 [==============================] - 10s 112us/sample - loss: 0.0931 - mse: 0.0931 - mae: 0.2348 - val_loss: 0.0974 - val_mse: 0.0974 - val_mae: 0.2358
# Epoch 14/120
# 85946/85946 [==============================] - 10s 111us/sample - loss: 0.0908 - mse: 0.0908 - mae: 0.2316 - val_loss: 0.0908 - val_mse: 0.0908 - val_mae: 0.2319
# Epoch 15/120
# 85946/85946 [==============================] - 10s 111us/sample - loss: 0.0884 - mse: 0.0884 - mae: 0.2285 - val_loss: 0.0896 - val_mse: 0.0896 - val_mae: 0.2292
# Epoch 16/120
# 85946/85946 [==============================] - 10s 111us/sample - loss: 0.0869 - mse: 0.0869 - mae: 0.2264 - val_loss: 0.0844 - val_mse: 0.0844 - val_mae: 0.2225
# Epoch 17/120
# 85946/85946 [==============================] - 10s 112us/sample - loss: 0.0854 - mse: 0.0854 - mae: 0.2243 - val_loss: 0.0853 - val_mse: 0.0853 - val_mae: 0.2236
# Epoch 18/120
# 85946/85946 [==============================] - 10s 113us/sample - loss: 0.0841 - mse: 0.0841 - mae: 0.2224 - val_loss: 0.0905 - val_mse: 0.0905 - val_mae: 0.2280
# Epoch 19/120
# 85946/85946 [==============================] - 10s 112us/sample - loss: 0.0829 - mse: 0.0829 - mae: 0.2206 - val_loss: 0.0849 - val_mse: 0.0849 - val_mae: 0.2219
# Epoch 20/120
# 85946/85946 [==============================] - 10s 111us/sample - loss: 0.0816 - mse: 0.0816 - mae: 0.2188 - val_loss: 0.0787 - val_mse: 0.0787 - val_mae: 0.2155
# Epoch 21/120
# 85946/85946 [==============================] - 10s 114us/sample - loss: 0.0807 - mse: 0.0807 - mae: 0.2174 - val_loss: 0.0812 - val_mse: 0.0812 - val_mae: 0.2184
# Epoch 22/120
# 85946/85946 [==============================] - 10s 112us/sample - loss: 0.0799 - mse: 0.0799 - mae: 0.2165 - val_loss: 0.0786 - val_mse: 0.0786 - val_mae: 0.2141
# Epoch 23/120
# 85946/85946 [==============================] - 10s 112us/sample - loss: 0.0793 - mse: 0.0793 - mae: 0.2152 - val_loss: 0.0774 - val_mse: 0.0774 - val_mae: 0.2125
# Epoch 24/120
# 85946/85946 [==============================] - 10s 111us/sample - loss: 0.0787 - mse: 0.0787 - mae: 0.2142 - val_loss: 0.0838 - val_mse: 0.0838 - val_mae: 0.2200
# Epoch 25/120
# 85946/85946 [==============================] - 12s 134us/sample - loss: 0.0780 - mse: 0.0780 - mae: 0.2133 - val_loss: 0.0789 - val_mse: 0.0789 - val_mae: 0.2132
# Epoch 26/120
# 85946/85946 [==============================] - 11s 133us/sample - loss: 0.0776 - mse: 0.0776 - mae: 0.2128 - val_loss: 0.0780 - val_mse: 0.0780 - val_mae: 0.2122
# Epoch 27/120
# 85946/85946 [==============================] - 11s 126us/sample - loss: 0.0771 - mse: 0.0771 - mae: 0.2119 - val_loss: 0.0774 - val_mse: 0.0774 - val_mae: 0.2121
# Epoch 28/120
# 85946/85946 [==============================] - 11s 127us/sample - loss: 0.0765 - mse: 0.0765 - mae: 0.2112 - val_loss: 0.0817 - val_mse: 0.0817 - val_mae: 0.2165
# Epoch 29/120
# 85946/85946 [==============================] - 11s 127us/sample - loss: 0.0761 - mse: 0.0761 - mae: 0.2104 - val_loss: 0.0746 - val_mse: 0.0746 - val_mae: 0.2085
# Epoch 30/120
# 85946/85946 [==============================] - 11s 126us/sample - loss: 0.0755 - mse: 0.0755 - mae: 0.2094 - val_loss: 0.0752 - val_mse: 0.0752 - val_mae: 0.2092
# Epoch 31/120
# 85946/85946 [==============================] - 11s 130us/sample - loss: 0.0754 - mse: 0.0754 - mae: 0.2093 - val_loss: 0.0802 - val_mse: 0.0802 - val_mae: 0.2144
# Epoch 32/120
# 85946/85946 [==============================] - 11s 127us/sample - loss: 0.0748 - mse: 0.0748 - mae: 0.2086 - val_loss: 0.0760 - val_mse: 0.0760 - val_mae: 0.2087
# Epoch 33/120
# 85946/85946 [==============================] - 11s 127us/sample - loss: 0.0748 - mse: 0.0748 - mae: 0.2084 - val_loss: 0.0731 - val_mse: 0.0731 - val_mae: 0.2060
# Epoch 34/120
# 85946/85946 [==============================] - 11s 133us/sample - loss: 0.0743 - mse: 0.0743 - mae: 0.2077 - val_loss: 0.0738 - val_mse: 0.0738 - val_mae: 0.2058
# Epoch 35/120
# 85946/85946 [==============================] - 11s 132us/sample - loss: 0.0741 - mse: 0.0741 - mae: 0.2074 - val_loss: 0.0829 - val_mse: 0.0829 - val_mae: 0.2173
# Epoch 36/120
# 85946/85946 [==============================] - 11s 126us/sample - loss: 0.0740 - mse: 0.0740 - mae: 0.2072 - val_loss: 0.0742 - val_mse: 0.0742 - val_mae: 0.2065los
# Epoch 37/120
# 85946/85946 [==============================] - 11s 126us/sample - loss: 0.0735 - mse: 0.0735 - mae: 0.2067 - val_loss: 0.0748 - val_mse: 0.0748 - val_mae: 0.2065
# Epoch 38/120
# 85946/85946 [==============================] - 11s 125us/sample - loss: 0.0735 - mse: 0.0735 - mae: 0.2064 - val_loss: 0.0770 - val_mse: 0.0770 - val_mae: 0.21090734 - mse: 0.0734 - mae: 0
# Epoch 39/120
# 85946/85946 [==============================] - 11s 131us/sample - loss: 0.0731 - mse: 0.0731 - mae: 0.2059 - val_loss: 0.0722 - val_mse: 0.0722 - val_mae: 0.2038
# Epoch 40/120
# 85946/85946 [==============================] - 11s 127us/sample - loss: 0.0732 - mse: 0.0732 - mae: 0.2061 - val_loss: 0.0731 - val_mse: 0.0731 - val_mae: 0.2051
# Epoch 41/120
# 85946/85946 [==============================] - 11s 128us/sample - loss: 0.0730 - mse: 0.0730 - mae: 0.2054 - val_loss: 0.0738 - val_mse: 0.0738 - val_mae: 0.2052
# Epoch 42/120
# 85946/85946 [==============================] - 11s 128us/sample - loss: 0.0728 - mse: 0.0728 - mae: 0.2051 - val_loss: 0.0722 - val_mse: 0.0722 - val_mae: 0.2030
# Epoch 43/120
# 85946/85946 [==============================] - 11s 132us/sample - loss: 0.0724 - mse: 0.0724 - mae: 0.2047 - val_loss: 0.0748 - val_mse: 0.0748 - val_mae: 0.2082
# Epoch 44/120
# 85946/85946 [==============================] - 11s 127us/sample - loss: 0.0722 - mse: 0.0722 - mae: 0.2044 - val_loss: 0.0790 - val_mse: 0.0790 - val_mae: 0.2134
# Epoch 45/120
# 85946/85946 [==============================] - 11s 128us/sample - loss: 0.0720 - mse: 0.0720 - mae: 0.2041 - val_loss: 0.0711 - val_mse: 0.0711 - val_mae: 0.2026
# Epoch 46/120
# 85946/85946 [==============================] - 11s 130us/sample - loss: 0.0718 - mse: 0.0718 - mae: 0.2038 - val_loss: 0.0707 - val_mse: 0.0707 - val_mae: 0.2021
# Epoch 47/120
# 85946/85946 [==============================] - 11s 134us/sample - loss: 0.0718 - mse: 0.0718 - mae: 0.2039 - val_loss: 0.0735 - val_mse: 0.0735 - val_mae: 0.2059
# Epoch 48/120
# 85946/85946 [==============================] - 11s 130us/sample - loss: 0.0716 - mse: 0.0716 - mae: 0.2035 - val_loss: 0.0698 - val_mse: 0.0698 - val_mae: 0.2010
# Epoch 49/120
# 85946/85946 [==============================] - 11s 130us/sample - loss: 0.0716 - mse: 0.0716 - mae: 0.2036 - val_loss: 0.0710 - val_mse: 0.0710 - val_mae: 0.2016
# Epoch 50/120
# 85946/85946 [==============================] - 11s 132us/sample - loss: 0.0712 - mse: 0.0712 - mae: 0.2030 - val_loss: 0.0720 - val_mse: 0.0720 - val_mae: 0.2029
# Epoch 51/120
# 85946/85946 [==============================] - 12s 136us/sample - loss: 0.0711 - mse: 0.0711 - mae: 0.2027 - val_loss: 0.0711 - val_mse: 0.0711 - val_mae: 0.2025
# Epoch 52/120
# 85946/85946 [==============================] - 11s 133us/sample - loss: 0.0712 - mse: 0.0712 - mae: 0.2029 - val_loss: 0.0690 - val_mse: 0.0690 - val_mae: 0.1991
# Epoch 53/120
# 85946/85946 [==============================] - 12s 137us/sample - loss: 0.0710 - mse: 0.0710 - mae: 0.2027 - val_loss: 0.0734 - val_mse: 0.0734 - val_mae: 0.2049
# Epoch 54/120
# 85946/85946 [==============================] - 11s 132us/sample - loss: 0.0710 - mse: 0.0710 - mae: 0.2026 - val_loss: 0.0696 - val_mse: 0.0696 - val_mae: 0.19982 - mse: 0.0712 - mae: 0.202 - ETA: 4s - loss: 0.0712 - mse: 0.071 - ETA: 3s - - ETA: 1s - loss: 0
# Epoch 55/120
# 85946/85946 [==============================] - 11s 133us/sample - loss: 0.0706 - mse: 0.0706 - mae: 0.2019 - val_loss: 0.0701 - val_mse: 0.0701 - val_mae: 0.2002
# Epoch 56/120
# 85946/85946 [==============================] - 12s 136us/sample - loss: 0.0706 - mse: 0.0706 - mae: 0.2018 - val_loss: 0.0694 - val_mse: 0.0694 - val_mae: 0.1995
# Epoch 57/120
# 85946/85946 [==============================] - 11s 132us/sample - loss: 0.0704 - mse: 0.0704 - mae: 0.2019 - val_loss: 0.0731 - val_mse: 0.0731 - val_mae: 0.2027
# Epoch 58/120
# 85946/85946 [==============================] - 11s 133us/sample - loss: 0.0703 - mse: 0.0703 - mae: 0.2017 - val_loss: 0.0736 - val_mse: 0.0736 - val_mae: 0.2037705  - ETA: 1s - lo
# Epoch 59/120
# 85946/85946 [==============================] - 11s 129us/sample - loss: 0.0706 - mse: 0.0706 - mae: 0.2023 - val_loss: 0.0681 - val_mse: 0.0681 - val_mae: 0.1971
# Epoch 60/120
# 85946/85946 [==============================] - 11s 130us/sample - loss: 0.0702 - mse: 0.0702 - mae: 0.2015 - val_loss: 0.0696 - val_mse: 0.0696 - val_mae: 0.2006
# Epoch 61/120
# 85946/85946 [==============================] - 12s 134us/sample - loss: 0.0700 - mse: 0.0700 - mae: 0.2011 - val_loss: 0.0674 - val_mse: 0.0674 - val_mae: 0.1984
# Epoch 62/120
# 85946/85946 [==============================] - 12s 135us/sample - loss: 0.0701 - mse: 0.0701 - mae: 0.2017 - val_loss: 0.0699 - val_mse: 0.0699 - val_mae: 0.2013
# Epoch 63/120
# 85946/85946 [==============================] - 11s 132us/sample - loss: 0.0699 - mse: 0.0699 - mae: 0.2011 - val_loss: 0.0724 - val_mse: 0.0724 - val_mae: 0.2040
# Epoch 64/120
# 85946/85946 [==============================] - 12s 135us/sample - loss: 0.0700 - mse: 0.0700 - mae: 0.2011 - val_loss: 0.0708 - val_mse: 0.0708 - val_mae: 0.2023
# Epoch 65/120
# 85946/85946 [==============================] - 12s 135us/sample - loss: 0.0697 - mse: 0.0697 - mae: 0.2007 - val_loss: 0.0681 - val_mse: 0.0681 - val_mae: 0.1981
# Epoch 66/120
# 85946/85946 [==============================] - 12s 137us/sample - loss: 0.0697 - mse: 0.0697 - mae: 0.2007 - val_loss: 0.0698 - val_mse: 0.0698 - val_mae: 0.1987
# Epoch 67/120
# 85946/85946 [==============================] - 11s 132us/sample - loss: 0.0695 - mse: 0.0695 - mae: 0.2004 - val_loss: 0.0676 - val_mse: 0.0676 - val_mae: 0.1971
# Epoch 68/120
# 85946/85946 [==============================] - 11s 132us/sample - loss: 0.0694 - mse: 0.0694 - mae: 0.2004 - val_loss: 0.0691 - val_mse: 0.0691 - val_mae: 0.1988 ETA: 0s - loss: 0.0694 - mse: 0.0694 - mae: 0
# Epoch 69/120
# 85946/85946 [==============================] - 11s 130us/sample - loss: 0.0695 - mse: 0.0695 - mae: 0.2003 - val_loss: 0.0689 - val_mse: 0.0689 - val_mae: 0.19995 - mse: 0.0695 -
# Epoch 70/120
# 85946/85946 [==============================] - 11s 130us/sample - loss: 0.0693 - mse: 0.0693 - mae: 0.2004 - val_loss: 0.0674 - val_mse: 0.0674 - val_mae: 0.1970
# Epoch 71/120
# 85946/85946 [==============================] - 12s 135us/sample - loss: 0.0692 - mse: 0.0692 - mae: 0.2000 - val_loss: 0.0682 - val_mse: 0.0682 - val_mae: 0.1988oss: 0.0693 - mse
# Epoch 72/120
# 85946/85946 [==============================] - 11s 132us/sample - loss: 0.0691 - mse: 0.0691 - mae: 0.2000 - val_loss: 0.0727 - val_mse: 0.0727 - val_mae: 0.2029
# Epoch 73/120
# 85946/85946 [==============================] - 12s 136us/sample - loss: 0.0691 - mse: 0.0691 - mae: 0.1998 - val_loss: 0.0672 - val_mse: 0.0672 - val_mae: 0.1958 loss: 0.0690 - mse: 0.0690 - mae: 0.19 - ETA: 0s - loss: 0.0691 - mse: 0.06
# Epoch 74/120
# 85946/85946 [==============================] - 12s 136us/sample - loss: 0.0692 - mse: 0.0692 - mae: 0.1999 - val_loss: 0.0671 - val_mse: 0.0671 - val_mae: 0.1966
# Epoch 75/120
# 85946/85946 [==============================] - 11s 132us/sample - loss: 0.0690 - mse: 0.0690 - mae: 0.1996 - val_loss: 0.0683 - val_mse: 0.0683 - val_mae: 0.19910 - mae: 0.19
# Epoch 76/120
# 85946/85946 [==============================] - 11s 133us/sample - loss: 0.0690 - mse: 0.0690 - mae: 0.1997 - val_loss: 0.0683 - val_mse: 0.0683 - val_mae: 0.1983s - loss: 0.0684  - ETA: 1s - loss: 0.0691 - mse - ETA: 0s - loss: 0.0690 - mse: 0.0690 - mae: 0.1
# Epoch 77/120
# 85946/85946 [==============================] - 12s 140us/sample - loss: 0.0689 - mse: 0.0689 - mae: 0.1994 - val_loss: 0.0688 - val_mse: 0.0688 - val_mae: 0.1986
# Epoch 78/120
# 85946/85946 [==============================] - 11s 133us/sample - loss: 0.0689 - mse: 0.0689 - mae: 0.1996 - val_loss: 0.0738 - val_mse: 0.0738 - val_mae: 0.2061
# Epoch 79/120
# 85946/85946 [==============================] - 11s 130us/sample - loss: 0.0685 - mse: 0.0685 - mae: 0.1988 - val_loss: 0.0697 - val_mse: 0.0697 - val_mae: 0.1990
# Epoch 80/120
# 85946/85946 [==============================] - 11s 130us/sample - loss: 0.0688 - mse: 0.0688 - mae: 0.1993 - val_loss: 0.0703 - val_mse: 0.0703 - val_mae: 0.2006
# Epoch 81/120
# 85946/85946 [==============================] - 12s 135us/sample - loss: 0.0686 - mse: 0.0686 - mae: 0.1993 - val_loss: 0.0672 - val_mse: 0.0672 - val_mae: 0.1967ss:
# Epoch 82/120
# 85946/85946 [==============================] - 11s 131us/sample - loss: 0.0686 - mse: 0.0686 - mae: 0.1993 - val_loss: 0.0672 - val_mse: 0.0672 - val_mae: 0.1979
# Epoch 83/120
# 85946/85946 [==============================] - 11s 132us/sample - loss: 0.0684 - mse: 0.0684 - mae: 0.1988 - val_loss: 0.0688 - val_mse: 0.0688 - val_mae: 0.1983- mse: 0.068
# Epoch 84/120
# 85946/85946 [==============================] - 12s 135us/sample - loss: 0.0686 - mse: 0.0686 - mae: 0.1990 - val_loss: 0.0664 - val_mse: 0.0664 - val_mae: 0.1952
# Epoch 85/120
# 85946/85946 [==============================] - 11s 133us/sample - loss: 0.0685 - mse: 0.0685 - mae: 0.1987 - val_loss: 0.0674 - val_mse: 0.0674 - val_mae: 0.1971
# Epoch 86/120
# 85946/85946 [==============================] - 11s 132us/sample - loss: 0.0681 - mse: 0.0681 - mae: 0.1984 - val_loss: 0.0674 - val_mse: 0.0674 - val_mae: 0.1971
# Epoch 87/120
# 85946/85946 [==============================] - 11s 133us/sample - loss: 0.0684 - mse: 0.0684 - mae: 0.1985 - val_loss: 0.0664 - val_mse: 0.0664 - val_mae: 0.1951
# Epoch 88/120
# 85946/85946 [==============================] - 12s 139us/sample - loss: 0.0682 - mse: 0.0682 - mae: 0.1985 - val_loss: 0.0713 - val_mse: 0.0713 - val_mae: 0.2025
# Epoch 89/120
# 85946/85946 [==============================] - 12s 134us/sample - loss: 0.0680 - mse: 0.0680 - mae: 0.1982 - val_loss: 0.0672 - val_mse: 0.0672 - val_mae: 0.1970
# Epoch 90/120
# 85946/85946 [==============================] - 12s 136us/sample - loss: 0.0684 - mse: 0.0684 - mae: 0.1986 - val_loss: 0.0706 - val_mse: 0.0706 - val_mae: 0.2002
# Epoch 91/120
# 85946/85946 [==============================] - 11s 133us/sample - loss: 0.0682 - mse: 0.0682 - mae: 0.1984 - val_loss: 0.0670 - val_mse: 0.0670 - val_mae: 0.1975
# Epoch 92/120
# 85946/85946 [==============================] - 12s 135us/sample - loss: 0.0681 - mse: 0.0681 - mae: 0.1983 - val_loss: 0.0682 - val_mse: 0.0682 - val_mae: 0.1980
# Epoch 93/120
# 85946/85946 [==============================] - 12s 142us/sample - loss: 0.0681 - mse: 0.0681 - mae: 0.1979 - val_loss: 0.0678 - val_mse: 0.0678 - val_mae: 0.2002
# Epoch 94/120
# 85946/85946 [==============================] - 11s 129us/sample - loss: 0.0680 - mse: 0.0680 - mae: 0.1983 - val_loss: 0.0659 - val_mse: 0.0659 - val_mae: 0.1951
# Epoch 95/120
# 85946/85946 [==============================] - 11s 132us/sample - loss: 0.0679 - mse: 0.0679 - mae: 0.1980 - val_loss: 0.0667 - val_mse: 0.0667 - val_mae: 0.1962
# Epoch 96/120
# 85946/85946 [==============================] - 11s 130us/sample - loss: 0.0678 - mse: 0.0678 - mae: 0.1979 - val_loss: 0.0691 - val_mse: 0.0691 - val_mae: 0.1995
# Epoch 97/120
# 85946/85946 [==============================] - 11s 131us/sample - loss: 0.0676 - mse: 0.0676 - mae: 0.1977 - val_loss: 0.0657 - val_mse: 0.0657 - val_mae: 0.1939
# Epoch 98/120
# 85946/85946 [==============================] - 12s 139us/sample - loss: 0.0678 - mse: 0.0678 - mae: 0.1977 - val_loss: 0.0670 - val_mse: 0.0670 - val_mae: 0.1965
# Epoch 99/120
# 85946/85946 [==============================] - 11s 134us/sample - loss: 0.0676 - mse: 0.0676 - mae: 0.1977 - val_loss: 0.0689 - val_mse: 0.0689 - val_mae: 0.1982
# Epoch 100/120
# 85946/85946 [==============================] - 11s 131us/sample - loss: 0.0675 - mse: 0.0675 - mae: 0.1976 - val_loss: 0.0668 - val_mse: 0.0668 - val_mae: 0.1961
# Epoch 101/120
# 85946/85946 [==============================] - 13s 151us/sample - loss: 0.0675 - mse: 0.0675 - mae: 0.1975 - val_loss: 0.0685 - val_mse: 0.0685 - val_mae: 0.1982- mse: 0.0675 - mae:
# Epoch 102/120
# 85946/85946 [==============================] - 13s 148us/sample - loss: 0.0674 - mse: 0.0674 - mae: 0.1974 - val_loss: 0.0656 - val_mse: 0.0656 - val_mae: 0.1944
# Epoch 103/120
# 85946/85946 [==============================] - 15s 178us/sample - loss: 0.0675 - mse: 0.0675 - mae: 0.1973 - val_loss: 0.0660 - val_mse: 0.0660 - val_mae: 0.1941
# Epoch 104/120
# 85946/85946 [==============================] - 13s 153us/sample - loss: 0.0673 - mse: 0.0673 - mae: 0.1970 - val_loss: 0.0724 - val_mse: 0.0724 - val_mae: 0.2029.0671 - mae: 0.19 - ETA: 2s - loss: 0.0671 - ms - ETA: 0s - loss: 0.0674 - mse: 0.0674 -
# Epoch 105/120
# 85946/85946 [==============================] - 11s 124us/sample - loss: 0.0674 - mse: 0.0674 - mae: 0.1972 - val_loss: 0.0666 - val_mse: 0.0666 - val_mae: 0.1954
# Epoch 106/120
# 85946/85946 [==============================] - 11s 125us/sample - loss: 0.0674 - mse: 0.0674 - mae: 0.1973 - val_loss: 0.0662 - val_mse: 0.0662 - val_mae: 0.1953
# Epoch 107/120
# 85946/85946 [==============================] - 11s 132us/sample - loss: 0.0673 - mse: 0.0673 - mae: 0.1971 - val_loss: 0.0671 - val_mse: 0.0671 - val_mae: 0.1964
# Epoch 108/120
# 85946/85946 [==============================] - 12s 135us/sample - loss: 0.0673 - mse: 0.0673 - mae: 0.1971 - val_loss: 0.0653 - val_mse: 0.0653 - val_mae: 0.1935
# Epoch 109/120
# 85946/85946 [==============================] - 11s 123us/sample - loss: 0.0670 - mse: 0.0670 - mae: 0.1969 - val_loss: 0.0656 - val_mse: 0.0656 - val_mae: 0.1948
# Epoch 110/120
# 85946/85946 [==============================] - 12s 138us/sample - loss: 0.0672 - mse: 0.0672 - mae: 0.1970 - val_loss: 0.0671 - val_mse: 0.0671 - val_mae: 0.1956
# Epoch 111/120
# 85946/85946 [==============================] - 15s 178us/sample - loss: 0.0670 - mse: 0.0670 - mae: 0.1967 - val_loss: 0.0679 - val_mse: 0.0679 - val_mae: 0.1969
# Epoch 112/120
# 85946/85946 [==============================] - 12s 143us/sample - loss: 0.0672 - mse: 0.0672 - mae: 0.1967 - val_loss: 0.0704 - val_mse: 0.0704 - val_mae: 0.1999
# Epoch 113/120
# 85946/85946 [==============================] - 11s 128us/sample - loss: 0.0670 - mse: 0.0670 - mae: 0.1969 - val_loss: 0.0700 - val_mse: 0.0700 - val_mae: 0.2009
# Epoch 114/120
# 85946/85946 [==============================] - 10s 111us/sample - loss: 0.0670 - mse: 0.0670 - mae: 0.1968 - val_loss: 0.0697 - val_mse: 0.0697 - val_mae: 0.1995
# Epoch 115/120
# 85946/85946 [==============================] - 9s 110us/sample - loss: 0.0670 - mse: 0.0670 - mae: 0.1970 - val_loss: 0.0693 - val_mse: 0.0693 - val_mae: 0.1988
# Epoch 116/120
# 85946/85946 [==============================] - 10s 111us/sample - loss: 0.0669 - mse: 0.0669 - mae: 0.1966 - val_loss: 0.0671 - val_mse: 0.0671 - val_mae: 0.1963
# Epoch 117/120
# 85946/85946 [==============================] - 11s 127us/sample - loss: 0.0670 - mse: 0.0670 - mae: 0.1968 - val_loss: 0.0675 - val_mse: 0.0675 - val_mae: 0.1974
# Epoch 118/120
# 85946/85946 [==============================] - 10s 121us/sample - loss: 0.0668 - mse: 0.0668 - mae: 0.1964 - val_loss: 0.0676 - val_mse: 0.0676 - val_mae: 0.1973
# Epoch 119/120
# 85946/85946 [==============================] - 13s 155us/sample - loss: 0.0669 - mse: 0.0669 - mae: 0.1966 - val_loss: 0.0697 - val_mse: 0.0697 - val_mae: 0.1997
# Epoch 120/120
# 85946/85946 [==============================] - 10s 112us/sample - loss: 0.0669 - mse: 0.0669 - mae: 0.1967 - val_loss: 0.0672 - val_mse: 0.0672 - val_mae: 0.1958ss:

# %%
# Runs NN Model for FAPAR

FAPAR_history_no_weights = FAPAR_model_no_weights.fit(x = numpy.array(training_data), y = numpy.array(FAPAR_training),
                                epochs = 20, 
                                validation_data = (numpy.array(valid_data), numpy.array(FAPAR_valid))
                               )
# Out:
# Train on 85946 samples, validate on 36834 samples
# Epoch 1/20
# 85946/85946 [==============================] - 11s 133us/sample - loss: 0.0927 - mse: 0.0927 - mae: 0.2011 - val_loss: 0.0379 - val_mse: 0.0379 - val_mae: 0.1461
# Epoch 2/20
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0316 - mse: 0.0316 - mae: 0.1329 - val_loss: 0.0279 - val_mse: 0.0279 - val_mae: 0.1236
# Epoch 3/20
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0249 - mse: 0.0249 - mae: 0.1170 - val_loss: 0.0233 - val_mse: 0.0233 - val_mae: 0.1125
# Epoch 4/20
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0217 - mse: 0.0217 - mae: 0.1086 - val_loss: 0.0206 - val_mse: 0.0206 - val_mae: 0.1047
# Epoch 5/20
# 85946/85946 [==============================] - 9s 110us/sample - loss: 0.0194 - mse: 0.0194 - mae: 0.1019 - val_loss: 0.0190 - val_mse: 0.0190 - val_mae: 0.1001
# Epoch 6/20
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0181 - mse: 0.0181 - mae: 0.0975 - val_loss: 0.0180 - val_mse: 0.0180 - val_mae: 0.0963
# Epoch 7/20
# 85946/85946 [==============================] - 10s 111us/sample - loss: 0.0171 - mse: 0.0171 - mae: 0.0943 - val_loss: 0.0171 - val_mse: 0.0171 - val_mae: 0.0954
# Epoch 8/20
# 85946/85946 [==============================] - 10s 111us/sample - loss: 0.0162 - mse: 0.0162 - mae: 0.0915 - val_loss: 0.0163 - val_mse: 0.0163 - val_mae: 0.0906
# Epoch 9/20
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0157 - mse: 0.0157 - mae: 0.0896 - val_loss: 0.0156 - val_mse: 0.0156 - val_mae: 0.0889
# Epoch 10/20
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0154 - mse: 0.0154 - mae: 0.0885 - val_loss: 0.0155 - val_mse: 0.0155 - val_mae: 0.0901
# Epoch 11/20
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0151 - mse: 0.0151 - mae: 0.0878 - val_loss: 0.0151 - val_mse: 0.0151 - val_mae: 0.0870
# Epoch 12/20
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0149 - mse: 0.0149 - mae: 0.0871 - val_loss: 0.0156 - val_mse: 0.0156 - val_mae: 0.0889
# Epoch 13/20
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0147 - mse: 0.0147 - mae: 0.0865 - val_loss: 0.0153 - val_mse: 0.0153 - val_mae: 0.0872
# Epoch 14/20
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0146 - mse: 0.0146 - mae: 0.0862 - val_loss: 0.0147 - val_mse: 0.0147 - val_mae: 0.0867
# Epoch 15/20
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0145 - mse: 0.0145 - mae: 0.0859 - val_loss: 0.0147 - val_mse: 0.0147 - val_mae: 0.0858
# Epoch 16/20
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0143 - mse: 0.0143 - mae: 0.0854 - val_loss: 0.0151 - val_mse: 0.0151 - val_mae: 0.0875
# Epoch 17/20
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0143 - mse: 0.0143 - mae: 0.0852 - val_loss: 0.0152 - val_mse: 0.0152 - val_mae: 0.0890
# Epoch 18/20
# 85946/85946 [==============================] - 9s 109us/sample - loss: 0.0142 - mse: 0.0142 - mae: 0.0848 - val_loss: 0.0144 - val_mse: 0.0144 - val_mae: 0.0856
# Epoch 19/20
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0141 - mse: 0.0141 - mae: 0.0846 - val_loss: 0.0144 - val_mse: 0.0144 - val_mae: 0.0852
# Epoch 20/20
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0141 - mse: 0.0141 - mae: 0.0844 - val_loss: 0.0148 - val_mse: 0.0148 - val_mae: 0.0856

# %%
# Runs NN Model for FCOVER

FCOVER_history_no_weights = FCOVER_model_no_weights.fit(x = numpy.array(training_data), y = numpy.array(FCOVER_training),
                                  epochs = 20, 
                                  validation_data = (numpy.array(valid_data), numpy.array(FCOVER_valid))
                                 )
# Out:
# Train on 85946 samples, validate on 36834 samples
# Epoch 1/20
# 85946/85946 [==============================] - 12s 136us/sample - loss: 0.0768 - mse: 0.0768 - mae: 0.1752 - val_loss: 0.0234 - val_mse: 0.0234 - val_mae: 0.1128
# Epoch 2/20
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0194 - mse: 0.0194 - mae: 0.1018 - val_loss: 0.0176 - val_mse: 0.0176 - val_mae: 0.0961
# Epoch 3/20
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0163 - mse: 0.0163 - mae: 0.0925 - val_loss: 0.0158 - val_mse: 0.0158 - val_mae: 0.0898
# Epoch 4/20
# 85946/85946 [==============================] - 9s 110us/sample - loss: 0.0149 - mse: 0.0149 - mae: 0.0876 - val_loss: 0.0146 - val_mse: 0.0146 - val_mae: 0.0864
# Epoch 5/20
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0141 - mse: 0.0141 - mae: 0.0847 - val_loss: 0.0144 - val_mse: 0.0144 - val_mae: 0.0858
# Epoch 6/20
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0136 - mse: 0.0136 - mae: 0.0829 - val_loss: 0.0138 - val_mse: 0.0138 - val_mae: 0.0830
# Epoch 7/20
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0133 - mse: 0.0133 - mae: 0.0817 - val_loss: 0.0141 - val_mse: 0.0141 - val_mae: 0.0830
# Epoch 8/20
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0131 - mse: 0.0131 - mae: 0.0808 - val_loss: 0.0132 - val_mse: 0.0132 - val_mae: 0.0815
# Epoch 9/20
# 85946/85946 [==============================] - 10s 113us/sample - loss: 0.0129 - mse: 0.0129 - mae: 0.0802 - val_loss: 0.0132 - val_mse: 0.0132 - val_mae: 0.0819
# Epoch 10/20
# 85946/85946 [==============================] - 12s 137us/sample - loss: 0.0128 - mse: 0.0128 - mae: 0.0799 - val_loss: 0.0133 - val_mse: 0.0133 - val_mae: 0.0815
# Epoch 11/20
# 85946/85946 [==============================] - 12s 140us/sample - loss: 0.0126 - mse: 0.0126 - mae: 0.0792 - val_loss: 0.0127 - val_mse: 0.0127 - val_mae: 0.0801
# Epoch 12/20
# 85946/85946 [==============================] - 11s 124us/sample - loss: 0.0125 - mse: 0.0125 - mae: 0.0789 - val_loss: 0.0128 - val_mse: 0.0128 - val_mae: 0.0804
# Epoch 13/20
# 85946/85946 [==============================] - 11s 130us/sample - loss: 0.0124 - mse: 0.0124 - mae: 0.0786 - val_loss: 0.0128 - val_mse: 0.0128 - val_mae: 0.0810
# Epoch 14/20
# 85946/85946 [==============================] - 13s 151us/sample - loss: 0.0123 - mse: 0.0123 - mae: 0.0783 - val_loss: 0.0128 - val_mse: 0.0128 - val_mae: 0.0794
# Epoch 15/20
# 85946/85946 [==============================] - 11s 124us/sample - loss: 0.0122 - mse: 0.0122 - mae: 0.0777 - val_loss: 0.0124 - val_mse: 0.0124 - val_mae: 0.0784
# Epoch 16/20
# 85946/85946 [==============================] - 9s 108us/sample - loss: 0.0121 - mse: 0.0121 - mae: 0.0772 - val_loss: 0.0123 - val_mse: 0.0123 - val_mae: 0.0779
# Epoch 17/20
# 85946/85946 [==============================] - 10s 121us/sample - loss: 0.0120 - mse: 0.0120 - mae: 0.0772 - val_loss: 0.0122 - val_mse: 0.0122 - val_mae: 0.0786
# Epoch 18/20
# 85946/85946 [==============================] - 12s 141us/sample - loss: 0.0119 - mse: 0.0119 - mae: 0.0769 - val_loss: 0.0120 - val_mse: 0.0120 - val_mae: 0.0770
# Epoch 19/20
# 85946/85946 [==============================] - 10s 120us/sample - loss: 0.0118 - mse: 0.0118 - mae: 0.0768 - val_loss: 0.0119 - val_mse: 0.0119 - val_mae: 0.0765
# Epoch 20/20
# 85946/85946 [==============================] - 12s 135us/sample - loss: 0.0118 - mse: 0.0118 - mae: 0.0767 - val_loss: 0.0123 - val_mse: 0.0123 - val_mae: 0.0786

# %%
# Makes predictions on the validation data using the 

LAI_predictions_no_weights = pandas.Series(LAI_model_no_weights.predict(numpy.array(valid_data)).flatten())
FAPAR_predictions_no_weights = pandas.Series(FAPAR_model_no_weights.predict(numpy.array(valid_data)).flatten())
FCOVER_predictions_no_weights = pandas.Series(FCOVER_model_no_weights.predict(numpy.array(valid_data)).flatten())

# %%
fig, (ax7, ax8, ax9) = plt.subplots(1,3,figsize=(25,15))

plotting_function('LAI', LAI_valid, LAI_predictions_no_weights, 'LAI','Input LAI','Predicted LAI','NNet',ax7)
plotting_function('FAPAR', FAPAR_valid, FAPAR_predictions_no_weights, 'FAPAR','Input FAPAR','Predicted FAPAR','NNet',ax8)
plotting_function('FCOVER', FCOVER_valid, FCOVER_predictions_no_weights, 'FCOVER','Input FCOVER','Predicted FCOVER','NNet',ax9)

fig.suptitle('Neural Network - without weights', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Neural Network - without weights')

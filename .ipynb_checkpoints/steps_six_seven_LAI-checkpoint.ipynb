# %%
# Import the necessary packages and libraries #
import scipy
import scipy.io as sio
import matplotlib.pyplot as plt
import numpy
import numpy.matlib
import pandas 
import sklearn
from sklearn import preprocessing
from sklearn import linear_model
import tensorflow
from tensorflow import keras 
import os
from sklearn.neighbors import DistanceMetric

# %%
# Sets the precision of the data in the Pandas Dataframes 

pandas.set_option("precision", 10)

# %%
# Removes any Tensorflow warnings 

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
# Import the MatLab data #

matlabData = sio.loadmat(file_name='./data/s2_sl2p_uniform_10_replicates_sobol_prosail_inout.mat', variable_names=['Input', 'Output'])

# %%
# Extract the input and output data #

bands = pandas.DataFrame(data=matlabData['Input']['Rho_Toc'][0][0])
angles = pandas.DataFrame(data=matlabData['Input']['Angles'][0][0])
LAI = pandas.Series(data=matlabData['Output']['LAI'][0][0].flatten())
FAPAR = pandas.Series(data=matlabData['Output']['FAPAR'][0][0].flatten())
FCOVER = pandas.Series(data=matlabData['Output']['FCOVER'][0][0].flatten())

# %%
# Standardize the calibration data #

cal_data = pandas.concat([bands, angles, LAI, FAPAR, FCOVER], axis=1, join='outer')

cal_data.columns = ['B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'A1', 'A2', 'A3', 'LAI', 'FAPAR', 'FCOVER']

cal_data
# Out:
#                   B0            B1            B2            B3            B4  \
# 0       0.1312746755  0.0743505601  0.1729546392  0.2952160738  0.3209243927
# 1       0.1019407701  0.0868185076  0.1599851769  0.3680334831  0.4389734403
# 2       0.0577228876  0.0543735427  0.0726863963  0.1146353863  0.1262129829
# 3       0.0608335819  0.0423475494  0.0917885392  0.1738484853  0.1980468499
# 4       0.0789422177  0.1359804109  0.1677317262  0.2554469658  0.2962514793
# ...              ...           ...           ...           ...           ...
# 122875  0.0642385315  0.0276301255  0.0866383370  0.3106952678  0.4255780128
# 122876  0.0913131658  0.0504649365  0.1222839075  0.3081750760  0.4047671458
# 122877  0.0621419307  0.0380236717  0.0921177459  0.2614424931  0.3577263614
# 122878  0.0514800307  0.0288523379  0.0690024543  0.4158467721  0.6343113015
# 122879  0.0668233773  0.0250243879  0.0907567987  0.4369922465  0.6772450624
#
#                   B5            B6            B7            A1            A2  \
# 0       0.3303722287  0.1873586099  0.1113007554  0.9638065534  0.5275411500
# 1       0.4759755142  0.3043390179  0.1996883219  0.9995852344  0.5284670738
# 2       0.1300015294  0.1048168652  0.0853760008  0.9807097061  0.6843199822
# 3       0.2153382831  0.1396374825  0.0906137034  0.9865515976  0.7869673865
# 4       0.3108466204  0.3167107908  0.2088934617  0.9999190888  0.8237423248
# ...              ...           ...           ...           ...           ...
# 122875  0.4466691326  0.1173674161  0.0414608341  0.9641458993  0.8501574022
# 122876  0.4293059492  0.1725548796  0.1005631041  0.9616583754  0.8710934328
# 122877  0.3626203975  0.1294881968  0.0624406803  0.9757927762  0.8637999983
# 122878  0.6354447032  0.1810943898  0.0474550174  0.9606931097  0.8268533675
# 122879  0.6972009957  0.2347272437  0.0863371443  0.9591264867  0.8382274319
#
#                   A3  LAI         FAPAR        FCOVER
# 0      -0.5752876765    1  0.4391203617  0.4803244610
# 1      -0.4777431279    1  0.5296906764  0.5338211214
# 2       0.6909005295    1  0.2406051357  0.2324486617
# 3       0.8590635747    1  0.3515168619  0.3732491055
# 4      -0.9085753290    1  0.2890892994  0.2565897729
# ...              ...  ...           ...           ...
# 122875 -0.9266152189   10  0.9454688738  0.9530549586
# 122876  0.9265827175   10  0.8085248415  0.8034524935
# 122877 -0.9813994186   10  0.8185069725  0.8122050332
# 122878 -0.8694016324   10  0.9810850825  0.9992241257
# 122879  0.9967558231   10  0.9762029807  0.9928982883
#
# [122880 rows x 14 columns]

# %%
# Standardize the calibration data #

cal_data_scaled = pandas.DataFrame(sklearn.preprocessing.StandardScaler().fit_transform(cal_data))

cal_data_scaled.columns = ['B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'A1', 'A2', 'A3', 'LAI', 'FAPAR', 'FCOVER']

cal_data_scaled
# Out:
#                   B0            B1            B2            B3            B4  \
# 0       1.1600887942  1.1894959571  1.1005309674 -0.7574953553 -1.2136760897
# 1       0.3768666595  1.6844505369  0.8279254564 -0.1275628723 -0.4502226101
# 2      -0.8037611472  0.3964451147 -1.0070101806 -2.3196717910 -2.4729247349
# 3      -0.7207048794 -0.0809646948 -0.6055016769 -1.8074281556 -2.0083566857
# 4      -0.2372000684  3.6360876602  0.9907504054 -1.1015319421 -1.3732421509
# ...              ...           ...           ...           ...           ...
# 122875 -0.6297919312 -0.6652193518 -0.7137539294 -0.6235871705 -0.5368542767
# 122876  0.0931071377  0.2412806393  0.0354813671 -0.6453889716 -0.6714434932
# 122877 -0.6857716627 -0.2526146846 -0.5985820716 -1.0496655348 -0.9756683152
# 122878 -0.9704468859 -0.6166997679 -1.0844430668  0.2860627172  0.8130774569
# 122879 -0.5607759421 -0.7686623410 -0.6271878617  0.4689890443  1.0907411044
#
#                   B5            B6            B7            A1            A2  \
# 0      -1.2551477212 -0.5123998591  0.0482701907 -1.5351947333 -1.2590753240
# 1      -0.3312429285  0.9573384489  1.5671047307  1.3154921199 -1.2529678973
# 2      -2.5265712936 -1.5494518415 -0.3972156885 -0.1884263875 -0.2249564670
# 3      -1.9850791466 -1.1119666599 -0.3072120391  0.2770296632  0.4521095310
# 4      -1.3790446724  1.1127770292  1.7252840412  1.3420921626  0.6946783564
# ...              ...           ...           ...           ...           ...
# 122875 -0.5172023756 -1.3917671005 -1.1518452670 -1.5081571622  0.8689131637
# 122876 -0.6273779690 -0.6983934776 -0.1362434958 -1.7063520463  1.0070079804
# 122877 -1.0505215854 -1.2394819780 -0.7913317214 -0.5801855863  0.9589002217
# 122878  0.6806459689 -0.5911033299 -1.0488424022 -1.7832601421  0.7151989067
# 122879  1.0725116772  0.0827382237 -0.3806995885 -1.9080817293  0.7902226473
#
#                   A3           LAI         FAPAR        FCOVER
# 0      -0.7795178075 -1.5666989036 -1.8949148320 -1.6291084301
# 1      -0.6517039023 -1.5666989036 -1.4265332698 -1.3709908078
# 2       0.8795852552 -1.5666989036 -2.9215301414 -2.8250917213
# 3       1.0999315055 -1.5666989036 -2.3479536034 -2.1457394865
# 4      -1.2162290029 -1.5666989036 -2.6707957989 -2.7086125584
# ...              ...           ...           ...           ...
# 122875 -1.2398669079  1.5666989036  0.7236507314  0.6517829598
# 122876  1.1884027264  1.5666989036  0.0154489326 -0.0700384081
# 122877 -1.3116513655  1.5666989036  0.0670712121 -0.0278080201
# 122878 -1.1648991929  1.5666989036  0.9078388454  0.8745459430
# 122879  1.2803514698  1.5666989036  0.8825912079  0.8440242224
#
# [122880 rows x 14 columns]

# %%
# Create subset id's #

rep = 10

subsets = numpy.arange(0, int(cal_data_scaled.shape[0]/10))

subset_ids = numpy.matlib.repmat(subsets, 1, rep)

cal_data_scaled['subset_id'] = subset_ids[0]

cal_data_scaled.columns = ['B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'A1', 'A2', 'A3', 'LAI', 'FAPAR', 'FCOVER', 'subset_id']

cal_data_scaled
# Out:
#                   B0            B1            B2            B3            B4  \
# 0       1.1600887942  1.1894959571  1.1005309674 -0.7574953553 -1.2136760897
# 1       0.3768666595  1.6844505369  0.8279254564 -0.1275628723 -0.4502226101
# 2      -0.8037611472  0.3964451147 -1.0070101806 -2.3196717910 -2.4729247349
# 3      -0.7207048794 -0.0809646948 -0.6055016769 -1.8074281556 -2.0083566857
# 4      -0.2372000684  3.6360876602  0.9907504054 -1.1015319421 -1.3732421509
# ...              ...           ...           ...           ...           ...
# 122875 -0.6297919312 -0.6652193518 -0.7137539294 -0.6235871705 -0.5368542767
# 122876  0.0931071377  0.2412806393  0.0354813671 -0.6453889716 -0.6714434932
# 122877 -0.6857716627 -0.2526146846 -0.5985820716 -1.0496655348 -0.9756683152
# 122878 -0.9704468859 -0.6166997679 -1.0844430668  0.2860627172  0.8130774569
# 122879 -0.5607759421 -0.7686623410 -0.6271878617  0.4689890443  1.0907411044
#
#                   B5            B6            B7            A1            A2  \
# 0      -1.2551477212 -0.5123998591  0.0482701907 -1.5351947333 -1.2590753240
# 1      -0.3312429285  0.9573384489  1.5671047307  1.3154921199 -1.2529678973
# 2      -2.5265712936 -1.5494518415 -0.3972156885 -0.1884263875 -0.2249564670
# 3      -1.9850791466 -1.1119666599 -0.3072120391  0.2770296632  0.4521095310
# 4      -1.3790446724  1.1127770292  1.7252840412  1.3420921626  0.6946783564
# ...              ...           ...           ...           ...           ...
# 122875 -0.5172023756 -1.3917671005 -1.1518452670 -1.5081571622  0.8689131637
# 122876 -0.6273779690 -0.6983934776 -0.1362434958 -1.7063520463  1.0070079804
# 122877 -1.0505215854 -1.2394819780 -0.7913317214 -0.5801855863  0.9589002217
# 122878  0.6806459689 -0.5911033299 -1.0488424022 -1.7832601421  0.7151989067
# 122879  1.0725116772  0.0827382237 -0.3806995885 -1.9080817293  0.7902226473
#
#                   A3           LAI         FAPAR        FCOVER  subset_id
# 0      -0.7795178075 -1.5666989036 -1.8949148320 -1.6291084301          0
# 1      -0.6517039023 -1.5666989036 -1.4265332698 -1.3709908078          1
# 2       0.8795852552 -1.5666989036 -2.9215301414 -2.8250917213          2
# 3       1.0999315055 -1.5666989036 -2.3479536034 -2.1457394865          3
# 4      -1.2162290029 -1.5666989036 -2.6707957989 -2.7086125584          4
# ...              ...           ...           ...           ...        ...
# 122875 -1.2398669079  1.5666989036  0.7236507314  0.6517829598      12283
# 122876  1.1884027264  1.5666989036  0.0154489326 -0.0700384081      12284
# 122877 -1.3116513655  1.5666989036  0.0670712121 -0.0278080201      12285
# 122878 -1.1648991929  1.5666989036  0.9078388454  0.8745459430      12286
# 122879  1.2803514698  1.5666989036  0.8825912079  0.8440242224      12287
#
# [122880 rows x 15 columns]

# %%
# Sample data to create reference database # 

ref_data = cal_data_scaled.sample(n=100, ignore_index=False)

ref_data
# Out:
#                   B0            B1            B2            B3            B4  \
# 112983 -1.0420943196 -0.6566245159 -1.1479391478  0.4385836701  1.5234691310
# 96824  -0.1444510712 -0.5782822905 -0.1802178016  0.7379086709  0.9090563823
# 118148  3.7634435419  0.6572732322  3.2496225983  2.1400595105  1.3428262107
# 59601  -0.5598242361 -0.4865627104 -0.5943454457  0.6560606516  0.9966155582
# 9668   -0.7406598184  0.9775612822 -0.4165066976 -1.8844585264 -2.0398457824
# ...              ...           ...           ...           ...           ...
# 59227  -0.8618171128 -0.4295845248 -0.9431827152 -0.0989575987  0.1255599705
# 67722   0.3018304548 -0.5746716939  0.2420799820  0.7473956762  0.6665617725
# 120473 -1.0871116594 -1.0987700171 -1.1983450523 -1.2893887694 -1.2214232732
# 802    -0.1358742381  2.5849787571  0.4708412439 -1.2135489176 -1.3630052029
# 78776  -0.7208652672 -0.6928403622 -0.8056030514 -1.3154826590 -1.3633355776
#
#                   B5            B6            B7            A1            A2  \
# 112983  1.4552682714  1.3117998310  0.5236140764 -0.8689830008 -2.0292307708
# 96824   0.9112255655  0.4843781554 -0.2035250352 -0.4962723457  0.7481920525
# 118148  1.1835839772  0.6743381429 -0.1359887610 -0.2111091922  0.4042036889
# 59601   1.0436288212  0.8324158533  0.0238239523  1.1609691213 -1.4278536527
# 9668   -1.9483891541  0.2938034268  1.4468516543 -0.2071569863 -0.0979927106
# ...              ...           ...           ...           ...           ...
# 59227   0.1661802802 -0.8500871395 -1.0659110303  1.3428912226  0.1007352409
# 67722   0.6387575883 -0.0038610218 -0.4914563312 -0.5417642590  1.2311966502
# 120473 -1.2573446059 -1.6562441045 -1.2996605601  1.2865335777 -0.6920914114
# 802    -1.1540713931  1.8172456514  3.0200742401 -0.4590480869 -0.9235404507
# 78776  -1.3146407827 -1.5602127196 -0.8984915090 -1.4694265671 -1.0656652921
#
#                   A3           LAI         FAPAR        FCOVER  subset_id
# 112983  0.5673152747  1.5666989036  0.8823724770  0.8471145159       2391
# 96824  -0.9601482522  0.8703882798  0.8424275042  0.8274693088      10808
# 118148 -1.0275046889  1.5666989036  0.6752378427  0.8658582318       7556
# 59601   0.7597378904 -0.1740776560  0.8006631482  0.7790522062      10449
# 9668   -0.9276134534 -1.5666989036 -2.8229301795 -2.7353590443       9668
# ...              ...           ...           ...           ...        ...
# 59227  -0.8214547604 -0.1740776560  0.7254845076  0.6892208935      10075
# 67722  -1.2538814698  0.1740776560  0.7238101871  0.7321255028       6282
# 120473 -0.8574002610  1.5666989036  0.3210033854  0.2748211818       9881
# 802    -0.8130395752 -1.5666989036 -2.4613813645 -2.5016788645        802
# 78776   0.7584392027  0.5222329679 -0.1067479938 -0.1547845697       5048
#
# [100 rows x 15 columns]

# %%
# List of indices to remove from the calibration database #

index_list = ref_data.index.values

# %%
# Resets the indices in the reference data so that they start from zero

ref_data = ref_data.reset_index(drop=True)

# %%
# Removes the indices from calibration database that are in the reference database #

cal_data_scaled = cal_data_scaled.drop(index_list)

# %%
# Resets the indices in the calibration data so that they start from zero

cal_data_scaled = cal_data_scaled.reset_index(drop=True)

# %%
# Creates the training and validation sets from the calibration data

features_training, features_valid = sklearn.model_selection.train_test_split(cal_data_scaled, test_size=0.3, train_size=0.7, random_state=None, shuffle=True, stratify=None)

# %%
# Resets the indices in the training data so that they start from zero

features_training = features_training.reset_index(drop=True)

# %%
# Resets the indices in the validation data so that they start from zero

features_valid = features_valid.reset_index(drop=True)

# %%
# Extracts the LAI, FAPAR, and FCOVER data to be used for training

LAI_feature_training = features_training['LAI']
FAPAR_feature_training = features_training['FAPAR']
FCOVER_feature_training = features_training['FCOVER']

# %%
# Extracts the LAI, FAPAR, and FCOVER data to be used for validation

LAI_feature_valid = features_valid['LAI']
FAPAR_feature_valid = features_valid['FAPAR']
FCOVER_feature_valid = features_valid['FCOVER']

# %%
# Removes that isn't needed for training and validation 
features_training = features_training.drop(['LAI', 'FAPAR', 'FCOVER','subset_id'], axis=1)
features_valid = features_valid.drop(['LAI', 'FAPAR', 'FCOVER','subset_id'], axis=1)

# %%
# Creates a model for LAI, FAPAR, and FCOVER using LARs regression 

LAI_feature_model = sklearn.linear_model.Lars(n_nonzero_coefs=4)
LAI_feature_model = LAI_feature_model.fit(features_training, LAI_feature_training)

FAPAR_feature_model = sklearn.linear_model.Lars(n_nonzero_coefs=4)
FAPAR_feature_model = FAPAR_feature_model.fit(features_training, FAPAR_feature_training)

FCOVER_feature_model = sklearn.linear_model.Lars(n_nonzero_coefs=3)
FCOVER_feature_model = FCOVER_feature_model.fit(features_training, FCOVER_feature_training)

# %%
# Makes predictions on the validation data using the LARS models

LAI_feature_predicted = pandas.Series(LAI_feature_model.predict(features_valid))
FAPAR_feature_predicted = pandas.Series(FAPAR_feature_model.predict(features_valid))
FCOVER_feature_predicted = pandas.Series(FCOVER_feature_model.predict(features_valid))

# %%
# Extracts the features from the LARS Model

LAI_features = numpy.nonzero(LAI_feature_model.coef_)[0]
FAPAR_features = numpy.nonzero(FAPAR_feature_model.coef_)[0]
FCOVER_features = numpy.nonzero(FCOVER_feature_model.coef_)[0]

LAI_features = features_valid.columns[LAI_features]
print(LAI_features)
FAPAR_features = features_valid.columns[FAPAR_features]
print(FAPAR_features)
FCOVER_features = features_valid.columns[FCOVER_features]
print(FCOVER_features)
# Out:
# Index(['B1', 'B5', 'B6', 'B7'], dtype='object')
# Index(['B1', 'B2', 'B5', 'B7'], dtype='object')
# Index(['B1', 'B5', 'B7'], dtype='object')

# %%
# Creates arrays containing the calibration and reference data 

ref_array = numpy.array(ref_data[LAI_features])

cal_array = numpy.array(cal_data_scaled[LAI_features])

# %%
# Calls function from sci-kit learn for calculating the euclidean distance 

dist = DistanceMetric.get_metric('euclidean')

# %%
# Calculates the probability for each sample in the calibration data

probs = numpy.exp(-numpy.amin(dist.pairwise(cal_array,ref_array),1))

# %%
# Initialize the probability column in the calibration database #

cal_data_scaled['prob'] = probs 

cal_data_scaled.columns = ['B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'A1', 'A2', 'A3', 'LAI', 'FAPAR', 'FCOVER', 'subset_id', 'prob']

# %%
cal_data_scaled
# Out:
#                   B0            B1            B2            B3            B4  \
# 0       1.1600887942  1.1894959571  1.1005309674 -0.7574953553 -1.2136760897
# 1       0.3768666595  1.6844505369  0.8279254564 -0.1275628723 -0.4502226101
# 2      -0.8037611472  0.3964451147 -1.0070101806 -2.3196717910 -2.4729247349
# 3      -0.7207048794 -0.0809646948 -0.6055016769 -1.8074281556 -2.0083566857
# 4      -0.2372000684  3.6360876602  0.9907504054 -1.1015319421 -1.3732421509
# ...              ...           ...           ...           ...           ...
# 122775 -0.6297919312 -0.6652193518 -0.7137539294 -0.6235871705 -0.5368542767
# 122776  0.0931071377  0.2412806393  0.0354813671 -0.6453889716 -0.6714434932
# 122777 -0.6857716627 -0.2526146846 -0.5985820716 -1.0496655348 -0.9756683152
# 122778 -0.9704468859 -0.6166997679 -1.0844430668  0.2860627172  0.8130774569
# 122779 -0.5607759421 -0.7686623410 -0.6271878617  0.4689890443  1.0907411044
#
#                   B5            B6            B7            A1            A2  \
# 0      -1.2551477212 -0.5123998591  0.0482701907 -1.5351947333 -1.2590753240
# 1      -0.3312429285  0.9573384489  1.5671047307  1.3154921199 -1.2529678973
# 2      -2.5265712936 -1.5494518415 -0.3972156885 -0.1884263875 -0.2249564670
# 3      -1.9850791466 -1.1119666599 -0.3072120391  0.2770296632  0.4521095310
# 4      -1.3790446724  1.1127770292  1.7252840412  1.3420921626  0.6946783564
# ...              ...           ...           ...           ...           ...
# 122775 -0.5172023756 -1.3917671005 -1.1518452670 -1.5081571622  0.8689131637
# 122776 -0.6273779690 -0.6983934776 -0.1362434958 -1.7063520463  1.0070079804
# 122777 -1.0505215854 -1.2394819780 -0.7913317214 -0.5801855863  0.9589002217
# 122778  0.6806459689 -0.5911033299 -1.0488424022 -1.7832601421  0.7151989067
# 122779  1.0725116772  0.0827382237 -0.3806995885 -1.9080817293  0.7902226473
#
#                   A3           LAI         FAPAR        FCOVER  subset_id  \
# 0      -0.7795178075 -1.5666989036 -1.8949148320 -1.6291084301          0
# 1      -0.6517039023 -1.5666989036 -1.4265332698 -1.3709908078          1
# 2       0.8795852552 -1.5666989036 -2.9215301414 -2.8250917213          2
# 3       1.0999315055 -1.5666989036 -2.3479536034 -2.1457394865          3
# 4      -1.2162290029 -1.5666989036 -2.6707957989 -2.7086125584          4
# ...              ...           ...           ...           ...        ...
# 122775 -1.2398669079  1.5666989036  0.7236507314  0.6517829598      12283
# 122776  1.1884027264  1.5666989036  0.0154489326 -0.0700384081      12284
# 122777 -1.3116513655  1.5666989036  0.0670712121 -0.0278080201      12285
# 122778 -1.1648991929  1.5666989036  0.9078388454  0.8745459430      12286
# 122779  1.2803514698  1.5666989036  0.8825912079  0.8440242224      12287
#
#                 prob
# 0       0.3440952604
# 1       0.5670801405
# 2       0.3416669309
# 3       0.5669805227
# 4       0.3467449737
# ...              ...
# 122775  0.8329757678
# 122776  0.6623663053
# 122777  0.7086508689
# 122778  0.8009496466
# 122779  0.7892428614
#
# [122780 rows x 16 columns]

# %%
# Function to normalize the probabilities 

def normalize(data):
    sum_prob = sum(data['prob'])
    data['prob'] = data['prob']/sum_prob
    return data

# %%
normalize(cal_data_scaled)
# Out:
#                   B0            B1            B2            B3            B4  \
# 0       1.1600887942  1.1894959571  1.1005309674 -0.7574953553 -1.2136760897
# 1       0.3768666595  1.6844505369  0.8279254564 -0.1275628723 -0.4502226101
# 2      -0.8037611472  0.3964451147 -1.0070101806 -2.3196717910 -2.4729247349
# 3      -0.7207048794 -0.0809646948 -0.6055016769 -1.8074281556 -2.0083566857
# 4      -0.2372000684  3.6360876602  0.9907504054 -1.1015319421 -1.3732421509
# ...              ...           ...           ...           ...           ...
# 122775 -0.6297919312 -0.6652193518 -0.7137539294 -0.6235871705 -0.5368542767
# 122776  0.0931071377  0.2412806393  0.0354813671 -0.6453889716 -0.6714434932
# 122777 -0.6857716627 -0.2526146846 -0.5985820716 -1.0496655348 -0.9756683152
# 122778 -0.9704468859 -0.6166997679 -1.0844430668  0.2860627172  0.8130774569
# 122779 -0.5607759421 -0.7686623410 -0.6271878617  0.4689890443  1.0907411044
#
#                   B5            B6            B7            A1            A2  \
# 0      -1.2551477212 -0.5123998591  0.0482701907 -1.5351947333 -1.2590753240
# 1      -0.3312429285  0.9573384489  1.5671047307  1.3154921199 -1.2529678973
# 2      -2.5265712936 -1.5494518415 -0.3972156885 -0.1884263875 -0.2249564670
# 3      -1.9850791466 -1.1119666599 -0.3072120391  0.2770296632  0.4521095310
# 4      -1.3790446724  1.1127770292  1.7252840412  1.3420921626  0.6946783564
# ...              ...           ...           ...           ...           ...
# 122775 -0.5172023756 -1.3917671005 -1.1518452670 -1.5081571622  0.8689131637
# 122776 -0.6273779690 -0.6983934776 -0.1362434958 -1.7063520463  1.0070079804
# 122777 -1.0505215854 -1.2394819780 -0.7913317214 -0.5801855863  0.9589002217
# 122778  0.6806459689 -0.5911033299 -1.0488424022 -1.7832601421  0.7151989067
# 122779  1.0725116772  0.0827382237 -0.3806995885 -1.9080817293  0.7902226473
#
#                   A3           LAI         FAPAR        FCOVER  subset_id  \
# 0      -0.7795178075 -1.5666989036 -1.8949148320 -1.6291084301          0
# 1      -0.6517039023 -1.5666989036 -1.4265332698 -1.3709908078          1
# 2       0.8795852552 -1.5666989036 -2.9215301414 -2.8250917213          2
# 3       1.0999315055 -1.5666989036 -2.3479536034 -2.1457394865          3
# 4      -1.2162290029 -1.5666989036 -2.6707957989 -2.7086125584          4
# ...              ...           ...           ...           ...        ...
# 122775 -1.2398669079  1.5666989036  0.7236507314  0.6517829598      12283
# 122776  1.1884027264  1.5666989036  0.0154489326 -0.0700384081      12284
# 122777 -1.3116513655  1.5666989036  0.0670712121 -0.0278080201      12285
# 122778 -1.1648991929  1.5666989036  0.9078388454  0.8745459430      12286
# 122779  1.2803514698  1.5666989036  0.8825912079  0.8440242224      12287
#
#                 prob
# 0       0.0000041947
# 1       0.0000069130
# 2       0.0000041651
# 3       0.0000069118
# 4       0.0000042270
# ...              ...
# 122775  0.0000101544
# 122776  0.0000080746
# 122777  0.0000086388
# 122778  0.0000097640
# 122779  0.0000096213
#
# [122780 rows x 16 columns]

# %%
# Initialize the probability column in the calibration database #

cal_data_scaled.columns = ['B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'A1', 'A2', 'A3', 'LAI', 'FAPAR', 'FCOVER', 'subset_id', 'prob']

# %%
# Assign max probability in each subset to every member of that subset 

cal_data_scaled['prob'] = cal_data_scaled.groupby('subset_id')['prob'].transform('max')

# %%
normalize(cal_data_scaled)
# Out:
#                   B0            B1            B2            B3            B4  \
# 0       1.1600887942  1.1894959571  1.1005309674 -0.7574953553 -1.2136760897
# 1       0.3768666595  1.6844505369  0.8279254564 -0.1275628723 -0.4502226101
# 2      -0.8037611472  0.3964451147 -1.0070101806 -2.3196717910 -2.4729247349
# 3      -0.7207048794 -0.0809646948 -0.6055016769 -1.8074281556 -2.0083566857
# 4      -0.2372000684  3.6360876602  0.9907504054 -1.1015319421 -1.3732421509
# ...              ...           ...           ...           ...           ...
# 122775 -0.6297919312 -0.6652193518 -0.7137539294 -0.6235871705 -0.5368542767
# 122776  0.0931071377  0.2412806393  0.0354813671 -0.6453889716 -0.6714434932
# 122777 -0.6857716627 -0.2526146846 -0.5985820716 -1.0496655348 -0.9756683152
# 122778 -0.9704468859 -0.6166997679 -1.0844430668  0.2860627172  0.8130774569
# 122779 -0.5607759421 -0.7686623410 -0.6271878617  0.4689890443  1.0907411044
#
#                   B5            B6            B7            A1            A2  \
# 0      -1.2551477212 -0.5123998591  0.0482701907 -1.5351947333 -1.2590753240
# 1      -0.3312429285  0.9573384489  1.5671047307  1.3154921199 -1.2529678973
# 2      -2.5265712936 -1.5494518415 -0.3972156885 -0.1884263875 -0.2249564670
# 3      -1.9850791466 -1.1119666599 -0.3072120391  0.2770296632  0.4521095310
# 4      -1.3790446724  1.1127770292  1.7252840412  1.3420921626  0.6946783564
# ...              ...           ...           ...           ...           ...
# 122775 -0.5172023756 -1.3917671005 -1.1518452670 -1.5081571622  0.8689131637
# 122776 -0.6273779690 -0.6983934776 -0.1362434958 -1.7063520463  1.0070079804
# 122777 -1.0505215854 -1.2394819780 -0.7913317214 -0.5801855863  0.9589002217
# 122778  0.6806459689 -0.5911033299 -1.0488424022 -1.7832601421  0.7151989067
# 122779  1.0725116772  0.0827382237 -0.3806995885 -1.9080817293  0.7902226473
#
#                   A3           LAI         FAPAR        FCOVER  subset_id  \
# 0      -0.7795178075 -1.5666989036 -1.8949148320 -1.6291084301          0
# 1      -0.6517039023 -1.5666989036 -1.4265332698 -1.3709908078          1
# 2       0.8795852552 -1.5666989036 -2.9215301414 -2.8250917213          2
# 3       1.0999315055 -1.5666989036 -2.3479536034 -2.1457394865          3
# 4      -1.2162290029 -1.5666989036 -2.6707957989 -2.7086125584          4
# ...              ...           ...           ...           ...        ...
# 122775 -1.2398669079  1.5666989036  0.7236507314  0.6517829598      12283
# 122776  1.1884027264  1.5666989036  0.0154489326 -0.0700384081      12284
# 122777 -1.3116513655  1.5666989036  0.0670712121 -0.0278080201      12285
# 122778 -1.1648991929  1.5666989036  0.9078388454  0.8745459430      12286
# 122779  1.2803514698  1.5666989036  0.8825912079  0.8440242224      12287
#
#                 prob
# 0       0.0000062979
# 1       0.0000071174
# 2       0.0000083948
# 3       0.0000081368
# 4       0.0000086952
# ...              ...
# 122775  0.0000083647
# 122776  0.0000067427
# 122777  0.0000071163
# 122778  0.0000083566
# 122779  0.0000087712
#
# [122780 rows x 16 columns]

# %%
# Find median probability 

median_prob = numpy.median(cal_data_scaled['prob'])

print(median_prob)
# Out:
# 8.30418674662193e-06

# %%
# Set weight that are below the median to zero 

cal_data_scaled['prob'] = cal_data_scaled['prob'].where(cal_data_scaled['prob'] > median_prob, 0.0)

# %%
cal_data_scaled
# Out:
#                   B0            B1            B2            B3            B4  \
# 0       1.1600887942  1.1894959571  1.1005309674 -0.7574953553 -1.2136760897
# 1       0.3768666595  1.6844505369  0.8279254564 -0.1275628723 -0.4502226101
# 2      -0.8037611472  0.3964451147 -1.0070101806 -2.3196717910 -2.4729247349
# 3      -0.7207048794 -0.0809646948 -0.6055016769 -1.8074281556 -2.0083566857
# 4      -0.2372000684  3.6360876602  0.9907504054 -1.1015319421 -1.3732421509
# ...              ...           ...           ...           ...           ...
# 122775 -0.6297919312 -0.6652193518 -0.7137539294 -0.6235871705 -0.5368542767
# 122776  0.0931071377  0.2412806393  0.0354813671 -0.6453889716 -0.6714434932
# 122777 -0.6857716627 -0.2526146846 -0.5985820716 -1.0496655348 -0.9756683152
# 122778 -0.9704468859 -0.6166997679 -1.0844430668  0.2860627172  0.8130774569
# 122779 -0.5607759421 -0.7686623410 -0.6271878617  0.4689890443  1.0907411044
#
#                   B5            B6            B7            A1            A2  \
# 0      -1.2551477212 -0.5123998591  0.0482701907 -1.5351947333 -1.2590753240
# 1      -0.3312429285  0.9573384489  1.5671047307  1.3154921199 -1.2529678973
# 2      -2.5265712936 -1.5494518415 -0.3972156885 -0.1884263875 -0.2249564670
# 3      -1.9850791466 -1.1119666599 -0.3072120391  0.2770296632  0.4521095310
# 4      -1.3790446724  1.1127770292  1.7252840412  1.3420921626  0.6946783564
# ...              ...           ...           ...           ...           ...
# 122775 -0.5172023756 -1.3917671005 -1.1518452670 -1.5081571622  0.8689131637
# 122776 -0.6273779690 -0.6983934776 -0.1362434958 -1.7063520463  1.0070079804
# 122777 -1.0505215854 -1.2394819780 -0.7913317214 -0.5801855863  0.9589002217
# 122778  0.6806459689 -0.5911033299 -1.0488424022 -1.7832601421  0.7151989067
# 122779  1.0725116772  0.0827382237 -0.3806995885 -1.9080817293  0.7902226473
#
#                   A3           LAI         FAPAR        FCOVER  subset_id  \
# 0      -0.7795178075 -1.5666989036 -1.8949148320 -1.6291084301          0
# 1      -0.6517039023 -1.5666989036 -1.4265332698 -1.3709908078          1
# 2       0.8795852552 -1.5666989036 -2.9215301414 -2.8250917213          2
# 3       1.0999315055 -1.5666989036 -2.3479536034 -2.1457394865          3
# 4      -1.2162290029 -1.5666989036 -2.6707957989 -2.7086125584          4
# ...              ...           ...           ...           ...        ...
# 122775 -1.2398669079  1.5666989036  0.7236507314  0.6517829598      12283
# 122776  1.1884027264  1.5666989036  0.0154489326 -0.0700384081      12284
# 122777 -1.3116513655  1.5666989036  0.0670712121 -0.0278080201      12285
# 122778 -1.1648991929  1.5666989036  0.9078388454  0.8745459430      12286
# 122779  1.2803514698  1.5666989036  0.8825912079  0.8440242224      12287
#
#                 prob
# 0       0.0000000000
# 1       0.0000000000
# 2       0.0000083948
# 3       0.0000000000
# 4       0.0000086952
# ...              ...
# 122775  0.0000083647
# 122776  0.0000000000
# 122777  0.0000000000
# 122778  0.0000083566
# 122779  0.0000087712
#
# [122780 rows x 16 columns]

# %%
# Creates the training and validation sets from the calibration data

training_data, valid_data = sklearn.model_selection.train_test_split(cal_data_scaled, test_size=0.3, train_size=0.7, random_state=None, shuffle=True, stratify=None)

# %%
# Resets the indices in the training data so that they start from zero

training_data = training_data.reset_index(drop=True)

# %%
# Resets the indices in the validation data so that they start from zero

valid_data = valid_data.reset_index(drop=True)

# %%
# Extracts the LAI, FAPAR, and FCOVER data to be used for training

LAI_training = training_data['LAI']
FAPAR_training = training_data['FAPAR']
FCOVER_training = training_data['FCOVER']

# %%
# Extracts the LAI, FAPAR, and FCOVER data to be used for validation

LAI_valid = valid_data['LAI']
FAPAR_valid = valid_data['FAPAR']
FCOVER_valid = valid_data['FCOVER']

# %%
# Extracts the probabilites for training and validation 

training_weights = numpy.array(training_data['prob'])
valid_weights = numpy.array(valid_data['prob'])

# %%
gee = ['cosVZA', 'cosSZA', 'cosRAA', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8A', 'B11', 'B12']
MatLab = ['B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'A1', 'A2', 'A3']
LAI_inputs = ['B3','B4', 'B5', 'B6', 'B7', 'B8A', 'B11', 'B12','cosVZA', 'cosSZA', 'cosRAA']

# %%
# Removes that isn't needed for training and validation 
# Explicitly subset the inputs
training_data = training_data[MatLab]
valid_data = valid_data[MatLab]

# %%
training_data
# Out:
#                  B0            B1            B2            B3            B4  \
# 0     -1.0336656120 -0.3320508467 -0.9886414838 -0.8308952797 -0.5635383767
# 1     -1.2740381893 -0.6569165708 -1.3272224500 -0.2468169187  0.8474992866
# 2      0.5526389235  3.3928791762  1.8292030814 -0.0091189625 -0.4602182073
# 3      1.4158335237 -0.1402139760  1.3770456859  2.0652239336  1.9711612071
# 4     -0.9235193819 -0.6245148364 -0.9601495635  0.0066906849  0.6020529843
# ...             ...           ...           ...           ...           ...
# 85941  2.8059026669  0.1860761773  2.4875955490  2.0309155022  1.3607673744
# 85942 -1.2614042101 -0.9749319763 -1.3318126771 -0.8553783525 -0.3306100948
# 85943 -0.7980849967 -0.1044070128 -0.8994322168 -1.0121350884 -0.8192786927
# 85944 -0.4046208268 -0.7177151875 -0.4987746924 -0.2827542811  0.0355592742
# 85945  1.8962331404 -0.0396727254  1.8203810427  1.4865037921  0.9772285012
#
#                  B5            B6            B7            A1            A2  \
# 0     -0.4566833863 -0.7858734776 -0.5011937321 -0.6730220729  0.8354437788
# 1      0.7976595503 -0.0341502333 -0.3813409783 -1.6289165260 -0.3343228889
# 2     -0.4501528486  1.4726577821  1.5324648185  0.5827287360 -1.5322623088
# 3      1.9818719205  1.8994612165  1.1145318464  1.3234296033  0.7501375369
# 4      0.6741568568  0.7840157402  0.3363533880 -0.5659136803 -0.1557393514
# ...             ...           ...           ...           ...           ...
# 85941  1.2206281199  0.8752428438  0.0905430827  0.0360571818  0.9867320133
# 85942 -0.2338813146 -1.1241990067 -0.9978954163  1.2605153587 -0.0866822184
# 85943 -0.8374780937  0.1594319236  0.8094000601  1.1319581466  0.2638617598
# 85944  0.1582676150  0.1008772447  0.0226150003 -0.9107443273 -0.4023955700
# 85945  0.9703406783  0.7606762159 -0.0007859687 -2.0914417102 -0.0890142034
#
#                  A3
# 0      1.1490170371
# 1      0.7731597694
# 2     -0.6783842409
# 3      1.1077310409
# 4     -0.9314656981
# ...             ...
# 85941 -1.3342971980
# 85942 -0.8400561236
# 85943 -0.8100969169
# 85944 -0.7245701549
# 85945  0.7476557781
#
# [85946 rows x 11 columns]

# %%
LAI_callback = tensorflow.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

# %%
# Creation of the Neural Network models for LAI, FAPAR, and FCOVER 

LAI_model = tensorflow.keras.models.Sequential([
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu, 
                                  input_shape=[len(training_data.keys())]),
    tensorflow.keras.layers.Dense(10, activation=tensorflow.nn.relu),
    tensorflow.keras.layers.Dense(1)
])

LAI_model.compile(
    optimizer=tensorflow.keras.optimizers.Nadam(),
    loss='mse',
    metrics=['mse', 'mae'])

# %%
# Runs NN Model for LAI

LAI_history = LAI_model.fit(x = numpy.array(training_data), y = numpy.array(LAI_training), 
                            sample_weight = training_weights,
                            epochs = 120,
                            validation_data = (numpy.array(valid_data), numpy.array(LAI_valid), valid_weights),
                            callbacks=[LAI_callback]
                           )
# Out:
# Train on 85946 samples, validate on 36834 samples
# Epoch 1/120
# 85946/85946 [==============================] - 13s 152us/sample - loss: 1.5596e-06 - mse: 0.4136 - mae: 0.5103 - val_loss: 9.8168e-07 - val_mse: 0.2853 - val_mae: 0.4077
# Epoch 2/120
# 85946/85946 [==============================] - 10s 114us/sample - loss: 8.6287e-07 - mse: 0.2442 - mae: 0.3785 - val_loss: 7.6679e-07 - val_mse: 0.2128 - val_mae: 0.3540
# Epoch 3/120
# 85946/85946 [==============================] - 10s 115us/sample - loss: 7.3346e-07 - mse: 0.1942 - mae: 0.3405 - val_loss: 6.8869e-07 - val_mse: 0.1759 - val_mae: 0.3259
# Epoch 4/120
# 85946/85946 [==============================] - 10s 114us/sample - loss: 6.6954e-07 - mse: 0.1702 - mae: 0.3198 - val_loss: 6.3198e-07 - val_mse: 0.1569 - val_mae: 0.3091
# Epoch 5/120
# 85946/85946 [==============================] - 10s 115us/sample - loss: 6.2278e-07 - mse: 0.1561 - mae: 0.3058 - val_loss: 5.8946e-07 - val_mse: 0.1510 - val_mae: 0.2993
# Epoch 6/120
# 85946/85946 [==============================] - 10s 115us/sample - loss: 5.8269e-07 - mse: 0.1455 - mae: 0.2939 - val_loss: 5.5899e-07 - val_mse: 0.1425 - val_mae: 0.2887
# Epoch 7/120
# 85946/85946 [==============================] - 10s 115us/sample - loss: 5.4599e-07 - mse: 0.1380 - mae: 0.2853 - val_loss: 5.1927e-07 - val_mse: 0.1353 - val_mae: 0.2818
# Epoch 8/120
# 85946/85946 [==============================] - 10s 115us/sample - loss: 5.1633e-07 - mse: 0.1322 - mae: 0.2786 - val_loss: 4.9956e-07 - val_mse: 0.1318 - val_mae: 0.2764
# Epoch 9/120
# 85946/85946 [==============================] - 10s 122us/sample - loss: 4.9076e-07 - mse: 0.1270 - mae: 0.2720 - val_loss: 5.0499e-07 - val_mse: 0.1286 - val_mae: 0.2738
# Epoch 10/120
# 85946/85946 [==============================] - 13s 148us/sample - loss: 4.7436e-07 - mse: 0.1227 - mae: 0.2670 - val_loss: 4.6004e-07 - val_mse: 0.1185 - val_mae: 0.2625
# Epoch 11/120
# 85946/85946 [==============================] - 11s 134us/sample - loss: 4.5943e-07 - mse: 0.1198 - mae: 0.2628 - val_loss: 4.3512e-07 - val_mse: 0.1116 - val_mae: 0.2565
# Epoch 12/120
# 85946/85946 [==============================] - 12s 134us/sample - loss: 4.4485e-07 - mse: 0.1166 - mae: 0.2592 - val_loss: 4.4179e-07 - val_mse: 0.1187 - val_mae: 0.2585
# Epoch 13/120
# 85946/85946 [==============================] - 12s 136us/sample - loss: 4.3313e-07 - mse: 0.1144 - mae: 0.2562 - val_loss: 4.1497e-07 - val_mse: 0.1101 - val_mae: 0.2514
# Epoch 14/120
# 85946/85946 [==============================] - 12s 138us/sample - loss: 4.2112e-07 - mse: 0.1115 - mae: 0.2526 - val_loss: 4.0741e-07 - val_mse: 0.1118 - val_mae: 0.2519
# Epoch 15/120
# 85946/85946 [==============================] - 12s 134us/sample - loss: 4.1292e-07 - mse: 0.1089 - mae: 0.2499 - val_loss: 3.8508e-07 - val_mse: 0.1011 - val_mae: 0.2412
# Epoch 16/120
# 85946/85946 [==============================] - 12s 136us/sample - loss: 4.0401e-07 - mse: 0.1066 - mae: 0.2469 - val_loss: 3.7922e-07 - val_mse: 0.1024 - val_mae: 0.2433
# Epoch 17/120
# 85946/85946 [==============================] - 12s 138us/sample - loss: 3.9716e-07 - mse: 0.1039 - mae: 0.2442 - val_loss: 3.7109e-07 - val_mse: 0.0962 - val_mae: 0.2364
# Epoch 18/120
# 85946/85946 [==============================] - 12s 136us/sample - loss: 3.8809e-07 - mse: 0.1015 - mae: 0.2413 - val_loss: 3.7844e-07 - val_mse: 0.0975 - val_mae: 0.2373
# Epoch 19/120
# 85946/85946 [==============================] - 12s 136us/sample - loss: 3.8410e-07 - mse: 0.1003 - mae: 0.2398 - val_loss: 3.7995e-07 - val_mse: 0.0997 - val_mae: 0.2394
# Epoch 20/120
# 85946/85946 [==============================] - 12s 139us/sample - loss: 3.7957e-07 - mse: 0.0991 - mae: 0.2385 - val_loss: 3.7002e-07 - val_mse: 0.0973 - val_mae: 0.2356
# Epoch 21/120
# 85946/85946 [==============================] - 12s 135us/sample - loss: 3.7519e-07 - mse: 0.0976 - mae: 0.2363 - val_loss: 3.6592e-07 - val_mse: 0.0935 - val_mae: 0.2321
# Epoch 22/120
# 85946/85946 [==============================] - 12s 138us/sample - loss: 3.7333e-07 - mse: 0.0974 - mae: 0.2356 - val_loss: 3.7242e-07 - val_mse: 0.0958 - val_mae: 0.2349
# Epoch 23/120
# 85946/85946 [==============================] - 12s 143us/sample - loss: 3.7002e-07 - mse: 0.0961 - mae: 0.2341 - val_loss: 3.6738e-07 - val_mse: 0.0962 - val_mae: 0.2348
# Epoch 24/120
# 85946/85946 [==============================] - 13s 149us/sample - loss: 3.6633e-07 - mse: 0.0951 - mae: 0.2333 - val_loss: 3.5278e-07 - val_mse: 0.0904 - val_mae: 0.2274
# Epoch 25/120
# 85946/85946 [==============================] - 12s 137us/sample - loss: 3.6468e-07 - mse: 0.0944 - mae: 0.2323 - val_loss: 3.6109e-07 - val_mse: 0.0916 - val_mae: 0.2297
# Epoch 26/120
# 85946/85946 [==============================] - 12s 138us/sample - loss: 3.6077e-07 - mse: 0.0942 - mae: 0.2315 - val_loss: 3.4997e-07 - val_mse: 0.0892 - val_mae: 0.2273
# Epoch 27/120
# 85946/85946 [==============================] - 12s 140us/sample - loss: 3.6042e-07 - mse: 0.0935 - mae: 0.2308 - val_loss: 3.6871e-07 - val_mse: 0.0967 - val_mae: 0.2355
# Epoch 28/120
# 85946/85946 [==============================] - 12s 137us/sample - loss: 3.5870e-07 - mse: 0.0932 - mae: 0.2308 - val_loss: 3.3710e-07 - val_mse: 0.0885 - val_mae: 0.2260
# Epoch 29/120
# 85946/85946 [==============================] - 12s 140us/sample - loss: 3.5498e-07 - mse: 0.0921 - mae: 0.2295 - val_loss: 3.4631e-07 - val_mse: 0.0908 - val_mae: 0.2275
# Epoch 30/120
# 85946/85946 [==============================] - 12s 143us/sample - loss: 3.5496e-07 - mse: 0.0923 - mae: 0.2295 - val_loss: 3.3727e-07 - val_mse: 0.0885 - val_mae: 0.2262
# Epoch 31/120
# 85946/85946 [==============================] - 12s 139us/sample - loss: 3.5307e-07 - mse: 0.0913 - mae: 0.2286 - val_loss: 3.4408e-07 - val_mse: 0.0926 - val_mae: 0.2288
# Epoch 32/120
# 85946/85946 [==============================] - 12s 135us/sample - loss: 3.4929e-07 - mse: 0.0914 - mae: 0.2286 - val_loss: 3.4484e-07 - val_mse: 0.0919 - val_mae: 0.2303
# Epoch 33/120
# 85946/85946 [==============================] - 12s 137us/sample - loss: 3.4864e-07 - mse: 0.0909 - mae: 0.2281 - val_loss: 3.3182e-07 - val_mse: 0.0871 - val_mae: 0.2246
# Epoch 34/120
# 85946/85946 [==============================] - 12s 137us/sample - loss: 3.4743e-07 - mse: 0.0899 - mae: 0.2269 - val_loss: 3.3412e-07 - val_mse: 0.0885 - val_mae: 0.2270
# Epoch 35/120
# 85946/85946 [==============================] - 12s 138us/sample - loss: 3.4530e-07 - mse: 0.0894 - mae: 0.2263 - val_loss: 3.3279e-07 - val_mse: 0.0876 - val_mae: 0.2249
# Epoch 36/120
# 85946/85946 [==============================] - 12s 139us/sample - loss: 3.4308e-07 - mse: 0.0888 - mae: 0.2258 - val_loss: 3.3261e-07 - val_mse: 0.0853 - val_mae: 0.2228
# Epoch 37/120
# 85946/85946 [==============================] - 12s 139us/sample - loss: 3.4107e-07 - mse: 0.0881 - mae: 0.2247 - val_loss: 3.3275e-07 - val_mse: 0.0863 - val_mae: 0.2242
# Epoch 38/120
# 85946/85946 [==============================] - 12s 141us/sample - loss: 3.4099e-07 - mse: 0.0874 - mae: 0.2240 - val_loss: 3.3235e-07 - val_mse: 0.0864 - val_mae: 0.2240
# Epoch 39/120
# 85946/85946 [==============================] - 12s 141us/sample - loss: 3.3848e-07 - mse: 0.0870 - mae: 0.2234 - val_loss: 3.2785e-07 - val_mse: 0.0863 - val_mae: 0.2222
# Epoch 40/120
# 85946/85946 [==============================] - 12s 141us/sample - loss: 3.3792e-07 - mse: 0.0868 - mae: 0.2234 - val_loss: 3.6529e-07 - val_mse: 0.0929 - val_mae: 0.2314
# Epoch 41/120
# 85946/85946 [==============================] - 14s 162us/sample - loss: 3.3557e-07 - mse: 0.0859 - mae: 0.2223 - val_loss: 3.2417e-07 - val_mse: 0.0825 - val_mae: 0.2181
# Epoch 42/120
# 85946/85946 [==============================] - 12s 138us/sample - loss: 3.3486e-07 - mse: 0.0855 - mae: 0.2217 - val_loss: 3.2794e-07 - val_mse: 0.0837 - val_mae: 0.2220
# Epoch 43/120
# 85946/85946 [==============================] - 12s 142us/sample - loss: 3.3430e-07 - mse: 0.0854 - mae: 0.2219 - val_loss: 3.1488e-07 - val_mse: 0.0813 - val_mae: 0.2178
# Epoch 44/120
# 85946/85946 [==============================] - 13s 146us/sample - loss: 3.3273e-07 - mse: 0.0852 - mae: 0.2215 - val_loss: 3.2463e-07 - val_mse: 0.0832 - val_mae: 0.2208
# Epoch 45/120
# 85946/85946 [==============================] - 13s 149us/sample - loss: 3.3126e-07 - mse: 0.0846 - mae: 0.2211 - val_loss: 3.2081e-07 - val_mse: 0.0819 - val_mae: 0.2184
# Epoch 46/120
# 85946/85946 [==============================] - 12s 141us/sample - loss: 3.2975e-07 - mse: 0.0845 - mae: 0.2206 - val_loss: 3.1632e-07 - val_mse: 0.0813 - val_mae: 0.2176
# Epoch 47/120
# 85946/85946 [==============================] - 12s 141us/sample - loss: 3.2871e-07 - mse: 0.0842 - mae: 0.2199 - val_loss: 3.2534e-07 - val_mse: 0.0824 - val_mae: 0.2193
# Epoch 48/120
# 85946/85946 [==============================] - 12s 143us/sample - loss: 3.2990e-07 - mse: 0.0839 - mae: 0.2197 - val_loss: 3.1533e-07 - val_mse: 0.0809 - val_mae: 0.2180
# Epoch 49/120
# 85946/85946 [==============================] - 12s 142us/sample - loss: 3.2703e-07 - mse: 0.0835 - mae: 0.2193 - val_loss: 3.2721e-07 - val_mse: 0.0840 - val_mae: 0.2191
# Epoch 50/120
# 85946/85946 [==============================] - 12s 142us/sample - loss: 3.2633e-07 - mse: 0.0832 - mae: 0.2189 - val_loss: 3.3421e-07 - val_mse: 0.0845 - val_mae: 0.2196
# Epoch 51/120
# 85946/85946 [==============================] - 12s 143us/sample - loss: 3.2574e-07 - mse: 0.0828 - mae: 0.2184 - val_loss: 3.2839e-07 - val_mse: 0.0852 - val_mae: 0.2202
# Epoch 52/120
# 85946/85946 [==============================] - 12s 141us/sample - loss: 3.2457e-07 - mse: 0.0828 - mae: 0.2182 - val_loss: 3.4163e-07 - val_mse: 0.0872 - val_mae: 0.2220
# Epoch 53/120
# 85946/85946 [==============================] - 12s 142us/sample - loss: 3.2577e-07 - mse: 0.0826 - mae: 0.2181 - val_loss: 3.1226e-07 - val_mse: 0.0808 - val_mae: 0.2146
# Epoch 54/120
# 85946/85946 [==============================] - 12s 143us/sample - loss: 3.2391e-07 - mse: 0.0823 - mae: 0.2178 - val_loss: 3.2866e-07 - val_mse: 0.0812 - val_mae: 0.2183
# Epoch 55/120
# 85946/85946 [==============================] - 12s 143us/sample - loss: 3.2364e-07 - mse: 0.0824 - mae: 0.2179 - val_loss: 3.0946e-07 - val_mse: 0.0793 - val_mae: 0.2146
# Epoch 56/120
# 85946/85946 [==============================] - 12s 141us/sample - loss: 3.2384e-07 - mse: 0.0823 - mae: 0.2175 - val_loss: 3.1117e-07 - val_mse: 0.0779 - val_mae: 0.2146
# Epoch 57/120
# 85946/85946 [==============================] - 12s 145us/sample - loss: 3.2295e-07 - mse: 0.0818 - mae: 0.2170 - val_loss: 3.2049e-07 - val_mse: 0.0828 - val_mae: 0.2197
# Epoch 58/120
# 85946/85946 [==============================] - 12s 141us/sample - loss: 3.2272e-07 - mse: 0.0813 - mae: 0.2165 - val_loss: 3.0976e-07 - val_mse: 0.0818 - val_mae: 0.2156
# Epoch 59/120
# 85946/85946 [==============================] - 12s 140us/sample - loss: 3.2145e-07 - mse: 0.0809 - mae: 0.2159 - val_loss: 3.2155e-07 - val_mse: 0.0822 - val_mae: 0.2178
# Epoch 60/120
# 85946/85946 [==============================] - 12s 141us/sample - loss: 3.2151e-07 - mse: 0.0809 - mae: 0.2160 - val_loss: 3.1401e-07 - val_mse: 0.0792 - val_mae: 0.2143
# Epoch 61/120
# 85946/85946 [==============================] - 12s 141us/sample - loss: 3.2045e-07 - mse: 0.0805 - mae: 0.2156 - val_loss: 3.2118e-07 - val_mse: 0.0826 - val_mae: 0.2164
# Epoch 62/120
# 85946/85946 [==============================] - 12s 142us/sample - loss: 3.1938e-07 - mse: 0.0804 - mae: 0.2155 - val_loss: 3.2176e-07 - val_mse: 0.0840 - val_mae: 0.2182
# Epoch 63/120
# 85946/85946 [==============================] - 13s 147us/sample - loss: 3.1913e-07 - mse: 0.0801 - mae: 0.2150 - val_loss: 3.0981e-07 - val_mse: 0.0762 - val_mae: 0.2122
# Epoch 64/120
# 85946/85946 [==============================] - 12s 144us/sample - loss: 3.1855e-07 - mse: 0.0799 - mae: 0.2145 - val_loss: 3.1135e-07 - val_mse: 0.0786 - val_mae: 0.2143
# Epoch 65/120
# 85946/85946 [==============================] - 12s 143us/sample - loss: 3.1758e-07 - mse: 0.0794 - mae: 0.2140 - val_loss: 3.2059e-07 - val_mse: 0.0778 - val_mae: 0.2132
# Epoch 66/120
# 85946/85946 [==============================] - 12s 142us/sample - loss: 3.1791e-07 - mse: 0.0796 - mae: 0.2145 - val_loss: 2.9904e-07 - val_mse: 0.0741 - val_mae: 0.2086
# Epoch 67/120
# 85946/85946 [==============================] - 13s 146us/sample - loss: 3.1696e-07 - mse: 0.0789 - mae: 0.2136 - val_loss: 3.1578e-07 - val_mse: 0.0798 - val_mae: 0.2149
# Epoch 68/120
# 85946/85946 [==============================] - 12s 139us/sample - loss: 3.1658e-07 - mse: 0.0793 - mae: 0.2140 - val_loss: 3.0390e-07 - val_mse: 0.0781 - val_mae: 0.2126
# Epoch 69/120
# 85946/85946 [==============================] - 12s 138us/sample - loss: 3.1601e-07 - mse: 0.0787 - mae: 0.2131 - val_loss: 3.0405e-07 - val_mse: 0.0756 - val_mae: 0.2104
# Epoch 70/120
# 85946/85946 [==============================] - 12s 139us/sample - loss: 3.1565e-07 - mse: 0.0786 - mae: 0.2128 - val_loss: 3.1008e-07 - val_mse: 0.0786 - val_mae: 0.2130
# Epoch 71/120
# 85946/85946 [==============================] - 12s 135us/sample - loss: 3.1557e-07 - mse: 0.0783 - mae: 0.2125 - val_loss: 3.0925e-07 - val_mse: 0.0785 - val_mae: 0.2117
# Epoch 72/120
# 85946/85946 [==============================] - 12s 142us/sample - loss: 3.1540e-07 - mse: 0.0786 - mae: 0.2132 - val_loss: 2.9867e-07 - val_mse: 0.0735 - val_mae: 0.2072
# Epoch 73/120
# 85946/85946 [==============================] - 12s 142us/sample - loss: 3.1448e-07 - mse: 0.0783 - mae: 0.2123 - val_loss: 3.2712e-07 - val_mse: 0.0807 - val_mae: 0.2157
# Epoch 74/120
# 85946/85946 [==============================] - 12s 140us/sample - loss: 3.1473e-07 - mse: 0.0783 - mae: 0.2123 - val_loss: 2.9609e-07 - val_mse: 0.0733 - val_mae: 0.2068
# Epoch 75/120
# 85946/85946 [==============================] - 12s 142us/sample - loss: 3.1309e-07 - mse: 0.0777 - mae: 0.2117 - val_loss: 3.0785e-07 - val_mse: 0.0764 - val_mae: 0.2097
# Epoch 76/120
# 85946/85946 [==============================] - 12s 141us/sample - loss: 3.1333e-07 - mse: 0.0775 - mae: 0.2113 - val_loss: 3.0039e-07 - val_mse: 0.0749 - val_mae: 0.2089
# Epoch 77/120
# 85946/85946 [==============================] - 12s 140us/sample - loss: 3.1235e-07 - mse: 0.0772 - mae: 0.2109 - val_loss: 2.9766e-07 - val_mse: 0.0748 - val_mae: 0.2082
# Epoch 78/120
# 85946/85946 [==============================] - 12s 142us/sample - loss: 3.1223e-07 - mse: 0.0771 - mae: 0.2108 - val_loss: 3.0666e-07 - val_mse: 0.0747 - val_mae: 0.2072
# Epoch 79/120
# 85946/85946 [==============================] - 12s 145us/sample - loss: 3.1169e-07 - mse: 0.0770 - mae: 0.2107 - val_loss: 3.0403e-07 - val_mse: 0.0738 - val_mae: 0.2081
# Epoch 80/120
# 85946/85946 [==============================] - 12s 142us/sample - loss: 3.1101e-07 - mse: 0.0771 - mae: 0.2109 - val_loss: 3.1366e-07 - val_mse: 0.0803 - val_mae: 0.2135
# Epoch 81/120
# 85946/85946 [==============================] - 12s 144us/sample - loss: 3.1143e-07 - mse: 0.0769 - mae: 0.2106 - val_loss: 3.0838e-07 - val_mse: 0.0779 - val_mae: 0.2132
# Epoch 82/120
# 85946/85946 [==============================] - 12s 144us/sample - loss: 3.1005e-07 - mse: 0.0767 - mae: 0.2102 - val_loss: 3.0982e-07 - val_mse: 0.0758 - val_mae: 0.2098
# Epoch 83/120
# 85946/85946 [==============================] - 12s 141us/sample - loss: 3.0943e-07 - mse: 0.0768 - mae: 0.2102 - val_loss: 3.0446e-07 - val_mse: 0.0748 - val_mae: 0.2076
# Epoch 84/120
# 85946/85946 [==============================] - 13s 146us/sample - loss: 3.1049e-07 - mse: 0.0768 - mae: 0.2104 - val_loss: 3.0108e-07 - val_mse: 0.0740 - val_mae: 0.2072
# Epoch 85/120
# 85946/85946 [==============================] - 12s 142us/sample - loss: 3.1031e-07 - mse: 0.0769 - mae: 0.2105 - val_loss: 3.0074e-07 - val_mse: 0.0737 - val_mae: 0.2078
# Epoch 86/120
# 85946/85946 [==============================] - 12s 141us/sample - loss: 3.0963e-07 - mse: 0.0765 - mae: 0.2100 - val_loss: 3.1330e-07 - val_mse: 0.0778 - val_mae: 0.2107

# %%
LAI_model.save('./models/LAI_models')
# Out:
# WARNING:tensorflow:From /opt/anaconda3/envs/eeALR/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: ./models/LAI_models/assets

# %%
print(max(cal_data_scaled['A1']))
print(min(cal_data_scaled['A1']))
# Out:
# 1.3485388024357525
# -2.1061824803859754

# %%
print(max(cal_data_scaled['A2']))
print(min(cal_data_scaled['A2']))
# Out:
# 1.3984151512355845
# -2.482717431098018

# %%
print(max(cal_data_scaled['A3']))
print(min(cal_data_scaled['A3']))
# Out:
# 1.2846023306530838
# -1.336023951152343
